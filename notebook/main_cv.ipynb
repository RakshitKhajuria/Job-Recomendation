# %%
# import pdfplumber
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict
import pandas as pd 
from nltk.collocations import *
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')

# %%
jd='''Role - Senior Big Data Engineer
Required Technical skills - Big Data, Python, Spark, Data brick, data Spark
Desired Experience Range - 5 + years
Location of Requirement - PAN India
Desired Competencies
Must-Have
Good hands on experience in Python programming
· Data Engineering experience using AWS core services (Lambda, Glue, EMR and RedShift)
· Required skill set- SQL, Airflow · Must – Have Experience with snowflake

· Responsibility – Will be accountable for build/test complex data pipelines (batch and near real time) · Expectation – Readable documentation of all the components being develop · Experience in writing SQLs and stored procedures · Working experience with RDBMS (Oracle / Teradata)
Good-to-Have
· Good understanding of Data warehouse
· Familiarize in ETL tools like Informatica
· Experience working with NoSQL database like DynamoDB or MongoDB .'''

# %%
def remove_stuff(jd):
    jd_clean = jd.replace("\xa0", "").replace("/", "").replace(".", ". ").replace("●", "")
    return jd_clean

# %%
def get_cv(): #cleaned, processed, nlped cv content
    url='cv.csv'
    return pd.read_csv(url) 
# db_expander = st.beta_expander(label='Submitted resume:')
# with db_expander:
df = get_cv()

# %% [markdown]
# # checking data

# %%
# cv data

# %%
df
# Out:
#     Unnamed: 0                 name                         email  \
# 0            0       Sukanya Jangra    Jangrasukanya066@gmail.com
# 1            1          Abhay Kumar       abhayownsthis@gmail.com
# 2            2    Abhijit Manepatil                           NaN
# 3            3     Abhinav Abhishek           abhi4navv@gmail.com
# 4            4       Aniket Kashyap         monu.aniket@gmail.com
# 5            5        Anirudh Anand      anirudhanand80@gmail.com
# 6            6         ASHRAY RAINA       ashrayraina22@gmail.com
# 7            7    Ramachandran Iyer          Ganesh2480@gmail.com
# 8            8       Himanshu Tyagi                           NaN
# 9            9           Jalpa Dave                           NaN
# 10          10   Kishore Ramiyengar        kishor.priya@gmail.com
# 11          11    Mohnish Chaudhary                           NaN
# 12          12        Pawan Kumar A           pawan9964@gmail.com
# 13          13      Prikshit Sharma  prikshitsharma8024@gmail.com
# 14          14  Priyanka Srivastava    priyankasrvstv16@gmail.com
# 15          15     Rakshit Khajuria    rakshitraina1234@gmail.com
# 16          16     Rakshit Khajuria    rakshitraina1234@gmail.com
# 17          17                  S W       swayamgupta74@gmail.com
#
#    mobile_number                                             skills  \
# 0            NaN  ['Data entry', 'Microsoft excel', 'Word', 'Htm...
# 1        9978045  ['Technical', 'R', 'Analytical', 'Keras', 'Ui'...
# 2            NaN  ['Marketing', 'R', 'Mining', 'Email', 'Keras',...
# 3     8757656959  ['Electronics', 'Spyder', 'Sales', 'Mining', '...
# 4     9691316944  ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...
# 5     8082366408  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...
# 6     7780995937  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...
# 7     9820463399  ['Technical', 'Crm', 'Itil', 'Sales', 'Project...
# 8     0800189689  ['Electronics', 'Sales', 'Analytical', 'Email'...
# 9            NaN  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...
# 10      007-2008  ['Technical', 'Analyze', 'Sales', 'Finance', '...
# 11           NaN  ['Technical', 'Gensim', 'Email', 'Mining', 'He...
# 12    8008636324  ['Technical', 'R', 'Analytical', 'Keras', 'Sec...
# 13    7780992150  ['Electronics', 'Analytical', 'Sql', 'Programm...
# 14    8948669980  ['Pandas', 'Analytics', 'System', 'Python', 'J...
# 15    9149556155  ['Electronics', 'Seaborn', 'Tensorflow', 'Metr...
# 16    9149556155  ['Electronics', 'Analyze', 'Textblob', 'Coding...
# 17    9797402957  ['Keras', 'Sql', 'Database', 'Programming', 'L...
#
#                                                degree  no_of_pages  \
# 0                                                None            1
# 1   ['e-commerce', 'Bachelor of Engineering,Comput...            4
# 2   ['Master of Engineering', 'Master in Computer ...            3
# 3                                                None            3
# 4   ['Bachelor of Engineering, Computer Science  n...            3
# 5                                                None            2
# 6                                          ['B.tech']            1
# 7                           ['Bachelors of Commerce']            2
# 8                            ['BTech in Electronics']            2
# 9                      ['B.E. in Computer', 'M.Tech']            3
# 10                 ['Bachelor of Technology (Civil)']            9
# 11                   ['BE in Information Technology']            3
# 12  ['Bachelor of Science (Btech) in Computer Scie...            2
# 13      ['B Tech, Shri Mata Vaishno Devi University']            2
# 14  ['PG certication in Data Science & MLnAcadgild...            1
# 15  ['Electronics and Communication nEngineering S...            1
# 16  ['Electronics and Communication, Engineering S...            2
# 17                        ['Bachelors of Technology']            1
#
#                                             file_path  \
# 0   cv_to_df/3bdfa685-56f1-4f83-866c-dbb20be51048.pdf
# 1   cv_to_df/abhay_kumar_visualcv_resume_with_GTC.pdf
# 2                      cv_to_df/Abhijit-Manepatil.pdf
# 3   cv_to_df/Abhinav_Abhishek_visualcv_resume (1).pdf
# 4                              cv_to_df/Aniket_cv.pdf
# 5                   cv_to_df/Anirudh_Anand_Resume.pdf
# 6   cv_to_df/ASHRAY_RAINA_Resume_13-02-2023-19-28-...
# 7   cv_to_df/fe826f24-8900-4317-959f-cb4689540997.pdf
# 8                         cv_to_df/Himanshu-Tyagi.pdf
# 9                             cv_to_df/Jalpa-Dave.pdf
# 10               cv_to_df/Kishore_Ramiyengar_L_CV.pdf
# 11                     cv_to_df/Mohnish-Chaudhary.pdf
# 12       cv_to_df/Pawan_DataScience_Resume (copy).pdf
# 13                                  cv_to_df/prik.pdf
# 14       cv_to_df/Priyanka_s Resume DataScientist.pdf
# 15                     cv_to_df/Rakshit's Resume2.pdf
# 16               cv_to_df/rakshit_khajuria_resume.pdf
# 17               cv_to_df/Swayam_Gupta_resume (1).pdf
#
#                                                   All
# 0   Sukanya JangraBhiwani, HaryanaJangrasukanya066...
# 1   Abhay KumarLead Data Scientist - Computer Visi...
# 2   Abhijit ManepatilData Scientist with Master in...
# 3   Abhinav AbhishekSenior Software Developer/Data...
# 4   Aniket KashyapSoftware Developer/Data Scientis...
# 5   Anirudh AnandMachine Learning Engineeranirudha...
# 6   ASHRAY RAINAashrayraina22@gmail.com 7780995937...
# 7   Ramachandran IyerIIM Ahmedabad Alumnus| SMP | ...
# 8   Himanshu TyagiPune, Maharashtra - Email me on ...
# 9   Jalpa DaveData Scientist - Elegant Microweb Te...
# 10  Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 11  Mohnish ChaudharyDECISION SCIENTIST - MU SIGMA...
# 12  Pawan Kumar Apawan9964@gmail.com#45, 8th cross...
# 13  Prikshit SharmaJammu,India prikshitsharma8024@...
# 14  Priyanka SrivastavaData ScientistData Science ...
# 15  Rakshit KhajuriaMachine Learning EngineerA 2+ ...
# 16  Rakshit KhajuriaMachine Learning EngineerTalab...
# 17  S W A Y A M G U P T A Jammu DOB: 9-Jan-2001 +9...

# %%
df["All"]
# Out:
# 0     Sukanya JangraBhiwani, HaryanaJangrasukanya066...
# 1     Abhay KumarLead Data Scientist - Computer Visi...
# 2     Abhijit ManepatilData Scientist with Master in...
# 3     Abhinav AbhishekSenior Software Developer/Data...
# 4     Aniket KashyapSoftware Developer/Data Scientis...
# 5     Anirudh AnandMachine Learning Engineeranirudha...
# 6     ASHRAY RAINAashrayraina22@gmail.com 7780995937...
# 7     Ramachandran IyerIIM Ahmedabad Alumnus| SMP | ...
# 8     Himanshu TyagiPune, Maharashtra - Email me on ...
# 9     Jalpa DaveData Scientist - Elegant Microweb Te...
# 10    Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 11    Mohnish ChaudharyDECISION SCIENTIST - MU SIGMA...
# 12    Pawan Kumar Apawan9964@gmail.com#45, 8th cross...
# 13    Prikshit SharmaJammu,India prikshitsharma8024@...
# 14    Priyanka SrivastavaData ScientistData Science ...
# 15    Rakshit KhajuriaMachine Learning EngineerA 2+ ...
# 16    Rakshit KhajuriaMachine Learning EngineerTalab...
# 17    S W A Y A M G U P T A Jammu DOB: 9-Jan-2001 +9...
# Name: All, dtype: object

# %%
# job discription entered by recuriter

# %%
jd
# Out:
# 'Role - Senior Big Data Engineer\nRequired Technical skills - Big Data, Python, Spark, Data brick, data Spark\nDesired Experience Range - 5 + years\nLocation of Requirement - PAN India\nDesired Competencies\nMust-Have\nGood hands on experience in Python programming\n· Data Engineering experience using AWS core services (Lambda, Glue, EMR and RedShift)\n· Required skill set- SQL, Airflow · Must – Have Experience with snowflake\n\n· Responsibility – Will be accountable for build/test complex data pipelines (batch and near real time) · Expectation – Readable documentation of all the components being develop · Experience in writing SQLs and stored procedures · Working experience with RDBMS (Oracle / Teradata)\nGood-to-Have\n· Good understanding of Data warehouse\n· Familiarize in ETL tools like Informatica\n· Experience working with NoSQL database like DynamoDB or MongoDB .'

# %%
def nlp(x):
    word_sent = word_tokenize(x.lower().replace("\n",""))
    _stopwords = set(stopwords.words('english') + list(punctuation)+list("●")+list('–')+list('’'))
    word_sent=[word for word in word_sent if word not in _stopwords]
    lemmatizer = WordNetLemmatizer()
    clean_text = [lemmatizer.lemmatize(word) for word in word_tokenize(" ".join(word_sent))]
#     return " ".join(NLP_Processed_CV)
    return clean_text

# %%
NLP_Processed_JD=nlp(jd)

# %%
NLP_Processed_JD
# Out:
# ['role',
#  'senior',
#  'big',
#  'data',
#  'engineerrequired',
#  'technical',
#  'skill',
#  'big',
#  'data',
#  'python',
#  'spark',
#  'data',
#  'brick',
#  'data',
#  'sparkdesired',
#  'experience',
#  'range',
#  '5',
#  'yearslocation',
#  'requirement',
#  'pan',
#  'indiadesired',
#  'competenciesmust-havegood',
#  'hand',
#  'experience',
#  'python',
#  'programming·',
#  'data',
#  'engineering',
#  'experience',
#  'using',
#  'aws',
#  'core',
#  'service',
#  'lambda',
#  'glue',
#  'emr',
#  'redshift',
#  '·',
#  'required',
#  'skill',
#  'set-',
#  'sql',
#  'airflow',
#  '·',
#  'must',
#  'experience',
#  'snowflake·',
#  'responsibility',
#  'accountable',
#  'build/test',
#  'complex',
#  'data',
#  'pipeline',
#  'batch',
#  'near',
#  'real',
#  'time',
#  '·',
#  'expectation',
#  'readable',
#  'documentation',
#  'component',
#  'develop',
#  '·',
#  'experience',
#  'writing',
#  'sqls',
#  'stored',
#  'procedure',
#  '·',
#  'working',
#  'experience',
#  'rdbms',
#  'oracle',
#  'teradata',
#  'good-to-have·',
#  'good',
#  'understanding',
#  'data',
#  'warehouse·',
#  'familiarize',
#  'etl',
#  'tool',
#  'like',
#  'informatica·',
#  'experience',
#  'working',
#  'nosql',
#  'database',
#  'like',
#  'dynamodb',
#  'mongodb']

# %%
################################################################################################################################

# %%
jd_df=pd.DataFrame()
# jd_df['hi']=['I']
jd_df['jd']=[' '.join(NLP_Processed_JD)]

# %%
jd_df['jd'].values[0]
# Out:
# 'role senior big data engineerrequired technical skill big data python spark data brick data sparkdesired experience range 5 yearslocation requirement pan indiadesired competenciesmust-havegood hand experience python programming· data engineering experience using aws core service lambda glue emr redshift · required skill set- sql airflow · must experience snowflake· responsibility accountable build/test complex data pipeline batch near real time · expectation readable documentation component develop · experience writing sqls stored procedure · working experience rdbms oracle teradata good-to-have· good understanding data warehouse· familiarize etl tool like informatica· experience working nosql database like dynamodb mongodb'

# %%
clean_jd=jd_df['jd'].values[0]

# %%
##############################################################################################################################

# %%
df["All"]
# Out:
# 0     Sukanya JangraBhiwani, HaryanaJangrasukanya066...
# 1     Abhay KumarLead Data Scientist - Computer Visi...
# 2     Abhijit ManepatilData Scientist with Master in...
# 3     Abhinav AbhishekSenior Software Developer/Data...
# 4     Aniket KashyapSoftware Developer/Data Scientis...
# 5     Anirudh AnandMachine Learning Engineeranirudha...
# 6     ASHRAY RAINAashrayraina22@gmail.com 7780995937...
# 7     Ramachandran IyerIIM Ahmedabad Alumnus| SMP | ...
# 8     Himanshu TyagiPune, Maharashtra - Email me on ...
# 9     Jalpa DaveData Scientist - Elegant Microweb Te...
# 10    Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 11    Mohnish ChaudharyDECISION SCIENTIST - MU SIGMA...
# 12    Pawan Kumar Apawan9964@gmail.com#45, 8th cross...
# 13    Prikshit SharmaJammu,India prikshitsharma8024@...
# 14    Priyanka SrivastavaData ScientistData Science ...
# 15    Rakshit KhajuriaMachine Learning EngineerA 2+ ...
# 16    Rakshit KhajuriaMachine Learning EngineerTalab...
# 17    S W A Y A M G U P T A Jammu DOB: 9-Jan-2001 +9...
# Name: All, dtype: object

# %%
cv_data=[]
for i in range(len(df["All"])):
    NLP_Processed_cv=nlp(df["All"].values[i])
    cv_data.append(NLP_Processed_cv)

# %%
cv_data
# Out:
# [['sukanya',
#   'jangrabhiwani',
#   'haryanajangrasukanya066',
#   'gmail.compersonal',
#   'detailsdate',
#   'birth',
#   '2003-11-24eligible',
#   'work',
#   'indiahighest',
#   'career',
#   'level',
#   'fresherindustry',
#   'internet',
#   'ecommercework',
#   'experiencecomputer',
#   'operatoreducationbachelorsskills',
#   'skill',
#   'computer',
#   'skill',
#   'data',
#   'entry',
#   'typing',
#   'customer',
#   'service',
#   'microsoft',
#   'word',
#   'microsoft',
#   'excel',
#   'microsoft',
#   'office',
#   'html',
#   'javascript',
#   'c',
#   'c++certifications',
#   'licensesdiploma',
#   'computer',
#   'applicationjanuary',
#   '2021',
#   'april',
#   '2022'],
#  ['abhay',
#   'kumarlead',
#   'data',
#   'scientist',
#   'computer',
#   'visionbangalore|+91-9731-812-812',
#   '|abhayownsthis',
#   'gmail.com',
#   'in.linkedin.com/in/abhay-kumar-99780458',
#   'abhaymise.github.io/summary',
#   'skillsi',
#   'applied',
#   'computer',
#   'vision',
#   'data',
#   'scientist',
#   'experience',
#   'leading',
#   'bunch',
#   'core',
#   'pythonother',
#   'data',
#   'scientist',
#   'used',
#   'leadership',
#   'applied',
#   'deep',
#   'learning',
#   'skill',
#   'successfullyexecute',
#   'various',
#   'computer',
#   'vision',
#   'project',
#   'highly',
#   'skilled',
#   'applied',
#   'deep',
#   'learning',
#   'computervision',
#   'good',
#   'understanding',
#   'various',
#   'computer',
#   'vision',
#   'technique',
#   'like',
#   'classification',
#   'boundingbox',
#   'classification',
#   'regression',
#   'object',
#   'detection',
#   'pixel',
#   'wise',
#   'prediction',
#   'segmentation',
#   'numpysequence',
#   'classification',
#   'lstms',
#   'video',
#   'classification',
#   'good',
#   'interpreter',
#   'businessrequirements',
#   'technical',
#   'term',
#   'vice',
#   'versa',
#   'excellent',
#   'use',
#   'case',
#   'identification',
#   'frombusiness',
#   'requirements.pandasachievements',
#   'include',
#   'execution',
#   'various',
#   'computer',
#   'vision',
#   'project',
#   'like',
#   'building',
#   'characteridentification',
#   'fashion',
#   'style',
#   'guide',
#   'recommender',
#   'fashion',
#   'attribute',
#   'predictor',
#   'activity',
#   'detection',
#   'image',
#   'search',
#   'engine.tensorflowmy',
#   'work',
#   'got',
#   'accepted',
#   'ai',
#   'deep',
#   'learning',
#   'conference',
#   'gtc',
#   '2018',
#   'nvidia.i',
#   'looking',
#   'role',
#   'leverage',
#   'skill',
#   'experience',
#   'betterment',
#   'theorganisation',
#   'improvement',
#   'learning.i',
#   'regular',
#   'ai/ml',
#   'blogger',
#   'firm',
#   'believer',
#   'andre',
#   'ng',
#   "'s",
#   'view',
#   'democratising',
#   'ai',
#   'pas',
#   'caffeon',
#   'knowledge',
#   'community',
#   'various',
#   'blogs.responsibilitiesopencvto',
#   'understand',
#   'business',
#   'use',
#   'case',
#   'client',
#   'convert',
#   'well',
#   'definedproblem',
#   'statement',
#   'explain',
#   'development',
#   'team',
#   'machine',
#   'learningto',
#   'identify',
#   'data',
#   'set',
#   'required',
#   'develop',
#   'predictive',
#   'model',
#   'solving',
#   'internal',
#   'externalbusiness',
#   'problemsto',
#   'fill',
#   'data',
#   'gap',
#   'gathering',
#   'data',
#   'designing',
#   'annotation',
#   'portal',
#   'conducting',
#   'dataannotation',
#   'human',
#   'annotator',
#   'deep',
#   'learningto',
#   'explore',
#   'data',
#   'set',
#   'identify',
#   'data',
#   'transformation',
#   'data',
#   'quality',
#   'need',
#   'targetedapplicationstodevelop',
#   'algorithm',
#   'predictive',
#   'model',
#   'derive',
#   'insight',
#   'business',
#   'value',
#   'fromdataothersto',
#   'provide',
#   'leadership',
#   'mentorship',
#   'member',
#   'team.identify',
#   'implement',
#   'use',
#   'case',
#   'might',
#   'help',
#   'organisation',
#   'business',
#   'developmentto',
#   'interpret',
#   'result',
#   'produce',
#   'actionable',
#   'business',
#   'insight',
#   'lead',
#   'measurablespark',
#   'rdd',
#   'dataframe',
#   'used',
#   'forbusiness',
#   'consumer',
#   'experience',
#   'performance',
#   'improvementsdata',
#   'transformationto',
#   'operationalize',
#   'publish',
#   'monitor',
#   'successful',
#   'model',
#   'shape',
#   'business',
#   'datamapreduce',
#   'used',
#   'datascience',
#   'strategyprocessing',
#   'engineto',
#   'partner',
#   'department',
#   'solve',
#   'problem',
#   'identify',
#   'trend',
#   'opportunitiesr',
#   'experimental',
#   'work',
#   'mainly',
#   'onto',
#   'define',
#   'develop',
#   'program',
#   'metric',
#   'creation',
#   'data',
#   'collection',
#   'modeling',
#   'andstructured',
#   'datareporting',
#   'operational',
#   'performanceto',
#   'work',
#   'cross-functionally',
#   'define',
#   'problem',
#   'statement',
#   'collect',
#   'data',
#   'build',
#   'analyticalmodels',
#   'make',
#   'recommendations.to',
#   'routinely',
#   'communicate',
#   'metric',
#   'progress',
#   'key',
#   'indicator',
#   'leadership.to',
#   'lead',
#   'support',
#   'various',
#   'ad',
#   'hoc',
#   'project',
#   'needed',
#   'support',
#   'organizationssbusiness',
#   'strategy.work',
#   'experiencelead',
#   'data',
#   'scientist',
#   'computer',
#   'vision',
#   '2017',
#   '2018cogknit',
#   'semanticshttps',
#   '//www.visualcv.com/abhaymiseleads',
#   'team',
#   '15',
#   'member',
#   'including',
#   'data',
#   'scientist',
#   'product',
#   'engineer',
#   'ui',
#   'engineers.data',
#   'scientist',
#   '2016',
#   '2017cogknit',
#   'semanticsfirst',
#   'member',
#   'computer',
#   'vision',
#   'team',
#   'organisationdata',
#   'engineer',
#   '2015',
#   '2016cogknit',
#   'semanticssenior',
#   'research',
#   'analyst',
#   '2013',
#   '2015edurekaeducationbachelor',
#   'engineering',
#   'computer',
#   'science',
#   '2009',
#   '2013visvesvaraya',
#   'technological',
#   'universitymachine',
#   'learning',
#   'stanford',
#   'university',
#   'june',
#   '15',
#   '2016',
#   'june',
#   '15',
#   '2016coursera',
#   '96.1',
#   'stanforda',
#   'machine',
#   'learning',
#   'course',
#   'one',
#   'pioneer',
#   'artificial',
#   'intelligencedeep',
#   'learning',
#   'specialisation',
#   '2017',
#   '2017deeplearning.aiit',
#   'carry',
#   '5',
#   'deep',
#   'learning',
#   'course',
#   'focus',
#   'neural',
#   'net',
#   'cnn',
#   'lstm',
#   'bi-lstmsattended',
#   'cs231n',
#   'cnn',
#   'visual',
#   'recognition',
#   'course',
#   '2016',
#   '2016stanfordattended',
#   'completed',
#   'assignment',
#   'courseachievementa',
#   'poster',
#   '``',
#   'domain',
#   'adaption',
#   'image',
#   'caption',
#   'model',
#   'video',
#   'description',
#   '``',
#   'acceptedat',
#   'ai',
#   'deep',
#   'learning',
#   'conference',
#   'gtc',
#   '2018',
#   'nvidiamultiple',
#   'blog',
#   'identified',
#   'best',
#   'read',
#   'across',
#   'various',
#   'ml/ai',
#   'forumsprojectsmen',
#   'style',
#   'guide',
#   'creation',
#   '2018',
#   'presentcogknit',
#   'semanticsrecommend',
#   'best',
#   'matching',
#   'attire',
#   'men',
#   'given',
#   'particular',
#   'attire',
#   'recommended',
#   'attire',
#   'iscreated',
#   'fly',
#   'inspiration',
#   'automated',
#   'style',
#   'guide',
#   'automated',
#   'styleguide',
#   'brings',
#   'trend',
#   'factor',
#   'following',
#   'feed',
#   'fashion',
#   'celebrity',
#   'accordinglycreate',
#   'combination',
#   'recommendation.built',
#   'panda',
#   'numpy',
#   'tensorflow',
#   'kerasmetadata',
#   'extraction',
#   'medium',
#   'content',
#   '2018',
#   'presentcogknit',
#   'semanticshttps',
#   '//www.visualcv.com/abhaymiseextract',
#   'attribute',
#   'like',
#   'scene',
#   'count',
#   'scene',
#   'boundary',
#   'scene',
#   'scene',
#   'identification',
#   'character',
#   'identification',
#   'character',
#   "'s",
#   'facial',
#   'feature',
#   'identification',
#   'activity',
#   'detection',
#   'objectionable',
#   'activity',
#   'flagging',
#   'speaker',
#   'identification',
#   'close',
#   'caption',
#   'generation',
#   'across',
#   'allscenes',
#   'extracted',
#   'attribute',
#   'exposed',
#   'micro',
#   'service',
#   'businessmonetisation.built',
#   'tensorflow',
#   'kaldi',
#   'kera',
#   'opencvface',
#   'voice',
#   'based',
#   'authenticated',
#   'wallet',
#   '2017',
#   '2018cogknit',
#   'semanticsan',
#   'authentication',
#   'system',
#   'provide',
#   'multi',
#   'modal',
#   'authentication',
#   'signal',
#   'fromface',
#   'voice',
#   'authentication',
#   'attached',
#   'payment',
#   'system',
#   'casewe',
#   'attached',
#   'payment',
#   'system',
#   'running',
#   'blockchain.automated',
#   'transcript',
#   'generation',
#   'advertisement',
#   'video',
#   '2017',
#   '2017e-retailcogknit',
#   'semanticsthe',
#   'project',
#   'aim',
#   'solving',
#   'business',
#   'case',
#   'e-retailers',
#   'website',
#   'accessible',
#   'avisually',
#   'impaired',
#   'person',
#   'aim',
#   'create',
#   'transcript',
#   'visual',
#   'audioinformation',
#   'given',
#   'video',
#   'transcript',
#   'would',
#   'contain',
#   'complete',
#   'informationincluding',
#   'action',
#   'emotion',
#   'clothing',
#   'attribute',
#   'spoken',
#   'sentence',
#   'transcriptwould',
#   'used',
#   'video',
#   'owner',
#   'explaining',
#   'product',
#   'visually',
#   'impaired',
#   'person.built',
#   'tensorflow',
#   'kaldi',
#   'kera',
#   'opencvscene',
#   'retrieval',
#   'using',
#   'tensorflow',
#   'opencv',
#   '2016',
#   '2017cogknit',
#   'semanticsthis',
#   'system',
#   'allows',
#   'retrieve',
#   'play',
#   'video',
#   'scene',
#   'desire.built',
#   'using',
#   'opencv',
#   'mean',
#   'io',
#   'inception-v3',
#   'cnn',
#   'encoder',
#   'tensorflow',
#   'toextract',
#   'feature',
#   'video.image',
#   'search',
#   'using',
#   'tensorflow',
#   '2016',
#   '2017cogknit',
#   'semanticsthis',
#   'system',
#   'trained',
#   'recognise',
#   'category',
#   'query',
#   'image',
#   'retrievethe',
#   'closest',
#   'match',
#   'identified',
#   'category',
#   'search',
#   'result.built',
#   'tensorflow',
#   'cnn',
#   'classifier',
#   'encoder',
#   'vectorised',
#   'search',
#   'system.automated',
#   'image',
#   'curation',
#   'system',
#   'using',
#   'tensorflow',
#   '2016',
#   '2017cogknit',
#   'semanticsthis',
#   'system',
#   'help',
#   'accelerating',
#   'cleaning',
#   'process',
#   'training',
#   'data',
#   'image',
#   'classifiers.it',
#   'brings',
#   'junk',
#   'training',
#   'data',
#   'provides',
#   'system',
#   'delete/move',
#   'thecategories.built',
#   'tensorflow',
#   'cnn',
#   'feature',
#   'extractor',
#   'vectorised',
#   'information',
#   'retrievaltechnique.auto',
#   'correction',
#   'e-commerce',
#   'catalogue',
#   'using',
#   'caffe',
#   '2016',
#   '2016cogknit',
#   'semanticsthis',
#   'system',
#   'try',
#   'find',
#   'mis-placed',
#   'item',
#   'category',
#   'e-commercecatalogue.once',
#   'find',
#   'misplaced',
#   'item',
#   'report',
#   'admin',
#   'suggest',
#   'thecorrect',
#   'category',
#   'product',
#   'actually',
#   'placed.built',
#   'caffe',
#   'cnn',
#   'classifier.automated',
#   'attendance',
#   'system',
#   '2017',
#   '2018cogknit',
#   'semanticsthis',
#   'mark',
#   'employee',
#   'presence',
#   'office',
#   'detecting',
#   'his/her',
#   'face',
#   'entry',
#   'office.https',
#   '//www.visualcv.com/abhaymisebuilt',
#   'tensorflow',
#   'cnn',
#   'classifier',
#   'opencv.auto',
#   'tagging',
#   'visual',
#   'content',
#   'indexing',
#   'using',
#   'tensorflow',
#   '2017',
#   '2017cogknit',
#   'semanticsthis',
#   'system',
#   'automatically',
#   'generates',
#   'textual',
#   'description',
#   'image.this',
#   'also',
#   'mark',
#   'image',
#   'multiple',
#   'tag',
#   'per',
#   'object',
#   'detected',
#   'image.captioning',
#   'system',
#   'built',
#   'cnn-lstm',
#   'encoder-decoder',
#   'system',
#   'meta',
#   'tag',
#   'generationis',
#   'built',
#   'using',
#   'faster-rcnn',
#   'network.recommendation',
#   'system',
#   'smart',
#   'learning',
#   'using',
#   'numpy',
#   '2015',
#   '2016cogknit',
#   'semanticsrecommends',
#   'learning',
#   'content',
#   'user',
#   'based',
#   'peer',
#   'activitiest.he',
#   'learningprocess',
#   'like',
#   'minded',
#   'learner',
#   'collaborated',
#   'suggest',
#   'new',
#   'useful',
#   'content',
#   'user.collaborative',
#   'filtering',
#   'user',
#   'item',
#   'attribute',
#   'used',
#   '.https',
#   '//www.visualcv.com/abhaymise'],
#  ['abhijit',
#   'manepatildata',
#   'scientist',
#   'master',
#   'computer',
#   'engineering',
#   '3+',
#   'year',
#   'ofexperience',
#   'using',
#   'predictive',
#   'modeling',
#   'data',
#   'processing',
#   'data',
#   'miningalgorithms',
#   'hands-on',
#   'experience',
#   'leveraging',
#   'machine',
#   'learning',
#   'modelsto',
#   'solve',
#   'challenging',
#   'business',
#   'problem',
#   'involved',
#   'python',
#   'open',
#   'sourcecommunity',
#   'passionate',
#   'deep',
#   'reinforcement',
#   'learning.pune',
#   'maharashtra',
#   'email',
#   'indeed',
#   'indeed.com/r/abhijit-manepatil/55dbd46d8fb95138willing',
#   'relocate',
#   'pune',
#   'maharashtrawork',
#   'experiencedata',
#   'scientistbluebox',
#   'technology',
#   '-2015',
#   'present2015',
#   'present',
#   'deep',
#   'learning',
#   'classification',
#   'image',
#   'online',
#   'product',
#   'buying',
#   'site',
#   'artificial',
#   'intelligence',
#   'convolutional',
#   'neural',
#   'network',
#   'model',
#   'cnn',
#   'classify',
#   'image',
#   'differentproducts',
#   'using',
#   'tensorflow',
#   'program',
#   'kera',
#   'high-level',
#   'data',
#   'cleansing',
#   'api',
#   'build',
#   'train',
#   'model',
#   'data',
#   'modeling',
#   'sentiment',
#   'analysis',
#   'political',
#   'campaign',
#   'analysis',
#   'helping',
#   'taking',
#   'natural',
#   'language',
#   'processing',
#   'decision',
#   'strategy',
#   'making',
#   'digital',
#   'marketing',
#   'detailedvirtualization',
#   'data',
#   'virtualization',
#   'using',
#   'matplotlib',
#   'data',
#   'mining',
#   'identifying',
#   'gi',
#   'functionality',
#   'using',
#   'natural',
#   'language',
#   'processing',
#   'sophisticated',
#   'way',
#   'define',
#   'google',
#   'gi',
#   'functionality',
#   'predictive',
#   'modelingcustomer',
#   'using',
#   'natural',
#   'language',
#   'processing',
#   'python',
#   'nltk',
#   'library',
#   'statistical',
#   'modeling',
#   'us',
#   'define',
#   'structure',
#   'project',
#   'data',
#   'analysis',
#   'predict',
#   'response',
#   'customer',
#   'specific',
#   'marketing',
#   'communication',
#   'skill',
#   'offer',
#   'using',
#   'various',
#   'machine',
#   'learning',
#   'algorithm',
#   'like',
#   'regression',
#   'andclassification',
#   'model',
#   'knn',
#   'k-means',
#   'nave',
#   'baise',
#   'svm',
#   'etc',
#   'team',
#   'managementsoftware',
#   'tool',
#   'document',
#   'classification',
#   'using',
#   'classification',
#   'machine',
#   'learningpython',
#   'algorithm',
#   'k-means',
#   'svm',
#   'excellent',
#   'tensorflow',
#   'kera',
#   'panda',
#   'numpy',
#   'cctc',
#   'footage',
#   'analysis',
#   'image',
#   'classification',
#   'using',
#   'convolutional',
#   'neuralscipy',
#   'matplotlib',
#   'scikit-learn',
#   'nltk',
#   'network',
#   'model',
#   'cnn',
#   'identification',
#   'customer',
#   'detail',
#   'count',
#   'ar',
#   'specific',
#   'period',
#   'visual',
#   'recognition.goodsql',
#   'good',
#   'predication',
#   'accident',
#   'basis',
#   'health',
#   'history',
#   'driver',
#   'usingmongodb',
#   'deep',
#   'learning',
#   'concept',
#   'artificial',
#   'neural',
#   'network',
#   'train',
#   'model',
#   'ongoodcassandra',
#   'available',
#   'dataset.goodjava',
#   'recommend',
#   'system',
#   'goodc',
#   'product',
#   'base',
#   'website',
#   'customer',
#   'support',
#   'using',
#   'recurrentvery',
#   'goodneural',
#   'network',
#   'rnn',
#   'cleaning',
#   'data',
#   'help',
#   'nltk.c++very',
#   'goodlanguages',
#   'face',
#   'detection',
#   'using',
#   'microsoft',
#   'cognitive',
#   'api.english',
#   'proficien',
#   'decide',
#   'period',
#   'foot',
#   'fall',
#   'shopping',
#   'mall',
#   'based',
#   'date',
#   'usinghindi',
#   'tensorflow',
#   'deep',
#   'learning',
#   'concepts.proficienmarathi',
#   'tmother',
#   'tongueeducationmaster',
#   'engineeringuniversity',
#   'puneskillsmachine',
#   'learning',
#   'data',
#   'science',
#   'python',
#   'artificial',
#   'intelience',
#   'neural',
#   'network',
#   'naturallanguage',
#   'processing',
#   'data',
#   'virtulization',
#   'predictive',
#   'modelling',
#   'statistical',
#   'modeling',
#   'dataanalysis',
#   'data',
#   'mining',
#   'data',
#   'cleaning',
#   'deep',
#   'learning',
#   'r',
#   'sql',
#   'nosql',
#   'mingodb',
#   'java',
#   'c',
#   'c++',
#   'communucation',
#   'skill',
#   'team',
#   'management',
#   '3',
#   'year',
#   'linkshttps',
#   '//github.com/abhijitmanepatiladditional',
#   'informationskills',
#   'machine',
#   'learning',
#   'data',
#   'analysis',
#   'artificial',
#   'intelligence',
#   'predictive',
#   'modeling',
#   'statistical',
#   'modeling',
#   'natural',
#   'language',
#   'processing',
#   'deep',
#   'learning',
#   'tensorflow',
#   'panda',
#   'scikit',
#   'learn',
#   'kera',
#   'matplotlib',
#   'python',
#   'r',
#   'c',
#   'c++',
#   'sql',
#   'mysql',
#   'java',
#   'mongodb',
#   'data',
#   'cleaning',
#   'data',
#   'virtualization',
#   'communication',
#   'skill',
#   'team',
#   'management'],
#  ['abhinav',
#   'abhisheksenior',
#   'software',
#   'developer/data',
#   'scientistbangalore',
#   '8757656959',
#   'abhi4navv',
#   'gmail.com',
#   'linkedin.com/in/abhinav-abhishek-22459154summary',
#   'skillsmore',
#   '5',
#   'year',
#   'experience',
#   'software',
#   'development',
#   'project',
#   'implementation',
#   'skills-out',
#   '3-years',
#   'experience',
#   'data',
#   'scientist',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'project',
#   'managementworking',
#   'experience',
#   'extensive',
#   'knowledge',
#   'python',
#   'natural',
#   'language',
#   'processing',
#   'team',
#   'managementlibraries',
#   'sklearn',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'nltk',
#   'sql',
#   'server',
#   'data',
#   'mining',
#   'data',
#   'analysismodel',
#   'buildingplatforms',
#   'misc',
#   'anaconda',
#   'enterprise',
#   'edition',
#   'jupyter',
#   'notebook',
#   'spyder',
#   'ide',
#   'sql',
#   'machine',
#   'learningserver',
#   'management',
#   'studio',
#   'visual',
#   'studio',
#   '2017',
#   'python',
#   'ii',
#   'window',
#   'xp/w7/w8',
#   'deep',
#   'learningother',
#   'skill',
#   'phase',
#   'software',
#   'development',
#   'life-cycle',
#   'requirement',
#   'design',
#   'data',
#   'pre-processingdevelopment',
#   'testing',
#   'release',
#   'support',
#   'utilizing',
#   'multiple',
#   'development',
#   'methodology',
#   'database',
#   'managementeducation',
#   'programming',
#   'skillsbachelor',
#   'engineering',
#   'electronics',
#   'communication',
#   '2013',
#   'pythonvisvesvaraya',
#   'technological',
#   'university',
#   'bangalorenlp/nltkcertification',
#   'program',
#   'data',
#   'science',
#   'deep',
#   'learning.acadgildpandasdiploma',
#   '.netniit',
#   'technology',
#   'limitednumpywork',
#   'experiencesenior',
#   'softare',
#   'developer',
#   '12/2017',
#   'till',
#   'date',
#   'matplotlibxl',
#   'solution',
#   'groupsoftware',
#   'programmer',
#   'ii',
#   '09/2015',
#   '09/2017',
#   'scikit',
#   'learnmsi',
#   'service',
#   'pvt',
#   'ltd.kerasproject',
#   'manager',
#   '01/2015',
#   '09/2015p',
#   'puneet',
#   'co.tensorflowdeveloper',
#   '03/2014',
#   '08/2014shreshtha',
#   'informatics',
#   'solution',
#   'pvt',
#   'ltd.sql',
#   'serverdatabase',
#   'administrator',
#   'programmer',
#   '08/2013',
#   '02/2014ematrix',
#   'technology',
#   'p',
#   'limitedprojectsxl',
#   'solution',
#   'groupinstitution',
#   'popularity',
#   'analysis-the',
#   'company',
#   'wanted',
#   'get',
#   'overview',
#   'feedback',
#   'given',
#   'student',
#   'generalpeople',
#   'giving',
#   'insurance',
#   'cover',
#   'used',
#   'nlp',
#   'find',
#   'institution',
#   'ishaving',
#   'positive',
#   'sentiment',
#   'provided',
#   'proper',
#   'visualization',
#   'using',
#   'plot',
#   'tohelp',
#   'concerned',
#   'team',
#   'taking',
#   'decision.claims',
#   'management',
#   'system-the',
#   'system',
#   'designed',
#   'assist',
#   'team',
#   'approval',
#   'claim',
#   'based',
#   'thecompany',
#   "'s",
#   'data',
#   'collected',
#   'different',
#   'type',
#   'claim',
#   'made',
#   'past',
#   'theircredibility',
#   'system',
#   'us',
#   'machine',
#   'learning',
#   'predict',
#   'class',
#   'good',
#   'forapproval',
#   'reject',
#   'verify',
#   'manually',
#   'claim',
#   'based',
#   'credibility.msi',
#   'service',
#   'pvt',
#   'ltd.inventory',
#   'stock',
#   'allocation',
#   'based',
#   'sale',
#   'prediction-the',
#   'application',
#   'provide',
#   'report',
#   'ale',
#   'projection',
#   'different',
#   'verity',
#   'stone',
#   'andtiles',
#   'state',
#   'u.s.',
#   'helped',
#   'inventory',
#   'team',
#   'warehouse',
#   'team',
#   'tomanage',
#   'supply',
#   'model',
#   'designed',
#   'using',
#   'sale',
#   'data',
#   'last',
#   '5',
#   'year',
#   'differentarea',
#   'based',
#   'model',
#   'tried',
#   'classify',
#   'product',
#   '3',
#   'class',
#   'high',
#   'moderate',
#   'andlow',
#   'sale',
#   'classes.technology',
#   'used-',
#   'panda',
#   'numpy',
#   'pca',
#   'matplotlib',
#   'random',
#   'forest',
#   'classifier',
#   'sql',
#   'server2012.sales',
#   'projection',
#   'stone',
#   'categories-there',
#   'different',
#   'type',
#   'stone',
#   'used',
#   'imported',
#   'different',
#   'country',
#   'socompany',
#   'wanted',
#   'sale',
#   'prediction',
#   'different',
#   'type',
#   'stone',
#   'national',
#   'wise',
#   'manageimports',
#   'accordingly',
#   'used',
#   'historical',
#   'sale',
#   'data',
#   'classified',
#   'type',
#   'ofstones',
#   'different',
#   'category',
#   'sales.technology',
#   'used-',
#   'panda',
#   'numpy',
#   'matplotlib',
#   'z-score',
#   'random',
#   'forest',
#   'classifier',
#   'sqlserver',
#   '2012.accounting-theapplication',
#   'generate',
#   'overall',
#   'daily',
#   'weekly',
#   'monthly',
#   'yearly',
#   'sale',
#   'accountingdata',
#   'accounting',
#   'team.p',
#   'puneet',
#   'co.expenditure',
#   'management',
#   'system-the',
#   'system',
#   'manage',
#   'payment',
#   '15types',
#   'beneficiary',
#   'district',
#   'generate',
#   'advice',
#   'basis',
#   'paymentwill',
#   'made',
#   'bank',
#   'earlier',
#   'done',
#   'manually',
#   'would',
#   'consume',
#   'time',
#   'andresources',
#   'developed',
#   'system',
#   'make',
#   'system',
#   'automated',
#   'centralized.ro',
#   'purchase',
#   'management-developed',
#   'software',
#   'ro',
#   'purchase',
#   'management',
#   'state',
#   'food',
#   'civil',
#   'supplycorporation.attendanceand',
#   'work',
#   'allocation',
#   'system-the',
#   'software',
#   'manage',
#   'attendance',
#   'system',
#   'allocate',
#   'work',
#   'employee',
#   'theirleads',
#   'also',
#   'reporting',
#   'system',
#   'keep',
#   'track',
#   'work',
#   'assigned',
#   'performance',
#   'ofemployees.the',
#   'software',
#   'manage',
#   'entire',
#   'functionality',
#   'medical',
#   'laboratory',
#   'like',
#   'patient',
#   'registration',
#   'select',
#   'test',
#   'generate',
#   'receipts.shreshtha',
#   'informatics',
#   'solution',
#   'pvt',
#   'ltd.medical',
#   'lab',
#   'software-the',
#   'software',
#   'manage',
#   'entire',
#   'functionality',
#   'medical',
#   'laboratory',
#   'like',
#   'patientregistration',
#   'select',
#   'test',
#   'generate',
#   'receipts.school',
#   'managementthe',
#   'application',
#   'manage',
#   'major',
#   'work',
#   'related',
#   'student',
#   'staff',
#   'includestudent',
#   'registration',
#   'fee',
#   'attendance',
#   'management',
#   'employee',
#   'salary',
#   'attendancesystem.ematrix',
#   'technology',
#   'p',
#   'limitedhr',
#   'management',
#   'system-created',
#   'application',
#   'hr',
#   'related',
#   'activity',
#   'company',
#   'main',
#   'module',
#   'itwas',
#   'salary',
#   'bonus',
#   'report',
#   'leaf',
#   'attendanceresponsibilitiesguide',
#   'team',
#   'member',
#   'understand',
#   'requirement',
#   'allocate',
#   'workaccordingly.communicate',
#   'client',
#   'understand',
#   'planning',
#   'project',
#   'provide',
#   'themprogress',
#   'report',
#   'modules.gather',
#   'complete',
#   'requirement',
#   'project',
#   'user.to',
#   'analyse',
#   'requirement',
#   'prepare',
#   'best',
#   'suited',
#   'database',
#   'structure',
#   'design',
#   'theproject.createthe',
#   'database',
#   'table',
#   'function',
#   'stored',
#   'procedure',
#   'project.work',
#   'code',
#   'develop',
#   'application',
#   'provide',
#   'support',
#   'system',
#   'team',
#   'forgo',
#   'live',
#   'process.educational',
#   'credentialswrote',
#   'paper',
#   'integrated',
#   'solution',
#   'ultrasonic',
#   'obstacle',
#   'avoidance',
#   'blindnavigation',
#   'system',
#   'using',
#   'rfid',
#   'indoor',
#   'environment',
#   'presented',
#   'nationalconference',
#   'held',
#   'b.t.l',
#   'institute',
#   'technology.obtained',
#   'extensive',
#   'knowledge',
#   'signal',
#   'processing',
#   'instrumentation',
#   'device',
#   'controlengineer',
#   'telecommunication',
#   'technologytraining',
#   'wireless',
#   'technology',
#   'networking',
#   'ofc',
#   'india',
#   'largest',
#   'communicationcompany',
#   'bsnl'],
#  ['aniket',
#   'kashyapsoftware',
#   'developer/data',
#   'scientistbengaluru',
#   '9691316944',
#   'monu.aniket',
#   'gmail.com',
#   'linkedin.com/in/aniket-kashyap-37456ba4/',
#   'github.com/aniket130590summary',
#   'skillsmore',
#   '4',
#   'year',
#   'experience',
#   'software',
#   'development',
#   'project',
#   'project',
#   'managementimplementation',
#   '2+years',
#   'experience',
#   'data',
#   'scientist',
#   'data',
#   'analysismachine',
#   'learning',
#   'deep',
#   'learning.working',
#   'experience',
#   'extensive',
#   'data',
#   'pre-processingknowledge',
#   'python',
#   'natural',
#   'language',
#   'processing',
#   'library',
#   'nlpsklearn',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'nltk',
#   'sql',
#   'server',
#   'data',
#   'mining',
#   '.platforms',
#   'database',
#   'managementmisc',
#   'anaconda',
#   'enterprise',
#   'edition',
#   'jupyter',
#   'notebook',
#   'spyder',
#   'ide',
#   'sql',
#   'server',
#   'model',
#   'buildingmanagement',
#   'studio',
#   'visual',
#   'studio',
#   '2017',
#   'python',
#   'ii',
#   'window',
#   'xp/w7/w8other',
#   'machine',
#   'learningskills',
#   'phase',
#   'software',
#   'development',
#   'life-cycle',
#   'requirement',
#   'deep',
#   'learningdesign',
#   'development',
#   'testing',
#   'release',
#   'support',
#   'utilizing',
#   'multiple',
#   'developmentmethodologies.programming',
#   'skillswork',
#   'experiencepythonsoftware',
#   'engineer',
#   '06/2017',
#   'till',
#   'datexl',
#   'solution',
#   'group',
#   'numpysoftware',
#   'engineer',
#   '09/2016',
#   '04/2017pandashewlett',
#   'packard',
#   'enterprisedeveloper',
#   '01/2014',
#   '08/2016matplotlibtouch',
#   'ideaeducation',
#   'scikit',
#   'learnbachelor',
#   'engineering',
#   'computer',
#   'science',
#   '2013npl/nltkswami',
#   'vivekananda',
#   'technical',
#   'university',
#   'bhilaicertification',
#   'program',
#   'data',
#   'science',
#   'deep',
#   'learning',
#   '2014',
#   'tensorflowacadgildnit',
#   'hyderabaddiploma',
#   'net',
#   '2014',
#   'kerasnit',
#   'hyderabadsql',
#   'serverprojectsxl',
#   'solution',
#   'groupunited',
#   'educators-',
#   'institution',
#   'popularity',
#   'analysis-the',
#   'company',
#   'wanted',
#   'get',
#   'overview',
#   'feedback',
#   'given',
#   'student',
#   'andgeneral',
#   'people',
#   'giving',
#   'insurance',
#   'cover',
#   'used',
#   'nlp',
#   'find',
#   'thatinstitution',
#   'positive',
#   'sentiment',
#   'provided',
#   'propervisualization',
#   'using',
#   'plot',
#   'help',
#   'concerned',
#   'team',
#   'taking',
#   'decision.ml',
#   'crane-',
#   'accessory',
#   'part',
#   'requirement',
#   'prediction',
#   'system-the',
#   'company',
#   'many',
#   'service',
#   'station',
#   'across',
#   'country',
#   'service',
#   'crane',
#   'andit',
#   'difficult',
#   'maintain',
#   'supply',
#   'part',
#   'across',
#   'service',
#   'center',
#   'asthey',
#   'different',
#   'demand',
#   'organize',
#   'supply',
#   'wanted',
#   'havepredicted',
#   'model',
#   'predict',
#   'part',
#   'needed',
#   'particularregion',
#   'used',
#   'provide',
#   'part',
#   'region',
#   'got',
#   'many',
#   'datarelated',
#   'climate',
#   'industrial',
#   'us',
#   'related',
#   'information',
#   'using',
#   'whichwe',
#   'prepared',
#   'model',
#   'tested',
#   'many',
#   'ml',
#   'algorithm',
#   'founddecision',
#   'tree',
#   'random',
#   'forest',
#   'similar',
#   'output',
#   'decided',
#   'putdecision',
#   'tree',
#   'needed',
#   'le',
#   'computation',
#   'time',
#   'le',
#   'computationalresources.technology',
#   'used-',
#   'panda',
#   'numpy',
#   'pca',
#   'matplotlib',
#   'random',
#   'forestclassifiers',
#   'sql',
#   'server',
#   '2012.hewlett',
#   'packard',
#   'enterprise.vfs',
#   'global',
#   'visa',
#   'approval',
#   'prediction-one',
#   'client',
#   'vfs',
#   'wanted',
#   'prediction',
#   'system',
#   'would',
#   'classifyapplications',
#   '3',
#   'category',
#   'based',
#   'chance',
#   'approval',
#   'high',
#   'medium',
#   'lowbased',
#   'used',
#   'either',
#   'process',
#   'application',
#   'concernedcountrys',
#   'cid:73',
#   'ice',
#   'helpful',
#   'mainly',
#   'student',
#   'work',
#   'visa',
#   'theirapproval',
#   'depends',
#   'trend',
#   'mostly',
#   'got',
#   'previous',
#   'data',
#   'like',
#   'course',
#   'detail',
#   'highest',
#   'qualification',
#   'year',
#   'stay',
#   'etc',
#   'build',
#   'model',
#   'using',
#   'builtmodel',
#   'case',
#   'got',
#   'one',
#   'best',
#   'accuracy',
#   'using',
#   'decision',
#   'tree',
#   'sofinalized',
#   'model.touch',
#   'idea',
#   '.my',
#   'hrwizard',
#   'project',
#   'mainly',
#   'deal',
#   'providing',
#   'efficient',
#   'accuratepayroll',
#   'service',
#   'company',
#   'company',
#   'ranging',
#   'single',
#   'employee',
#   'tothousands',
#   'employee',
#   'use',
#   'service',
#   'effective',
#   'management',
#   'ofemployee',
#   'payroll',
#   'service',
#   'one',
#   'main',
#   'feature',
#   'project',
#   'reportgeneration',
#   'based',
#   'wide',
#   'variety',
#   'base',
#   'report',
#   'useful',
#   'payroll',
#   'processing',
#   'maintenance',
#   'time',
#   'attendance',
#   'hr',
#   'service',
#   'maintenance',
#   'insurance',
#   'andaccess',
#   'worker',
#   'compensation',
#   'etc.this',
#   'system',
#   'provides',
#   'broad',
#   'range',
#   'time',
#   'keeping',
#   'allow',
#   'employer',
#   'toeffectively',
#   'track',
#   'employee',
#   'hour',
#   'feature',
#   'offered',
#   'assist',
#   'convenientlyorganizing',
#   'quantifying',
#   'employee',
#   "'s",
#   'work',
#   'day',
#   'key',
#   'feature',
#   'include',
#   'jobcosting',
#   'automated',
#   'overtime',
#   'calculation',
#   'holiday',
#   'tracking',
#   'payment',
#   'onlinetime-card',
#   'editing',
#   'daily',
#   'auto',
#   'email',
#   'report',
#   'etc.taf',
#   'route',
#   'management',
#   'bicycle',
#   'riding',
#   'event',
#   'objective',
#   'tomanage',
#   'whole',
#   'route',
#   'bicycle',
#   'riding',
#   'event',
#   'different',
#   'module',
#   'likeregistration',
#   'rider',
#   'well',
#   'volunteer',
#   'creation',
#   'management',
#   'routemap',
#   'task',
#   'assignment',
#   'tracking',
#   'rider',
#   'location',
#   'showing',
#   'themap',
#   'helping',
#   'assisting',
#   'rider',
#   'etc.responsibilitiesguide',
#   'team',
#   'member',
#   'understand',
#   'requirement',
#   'allocate',
#   'thework',
#   'accordingly.communicate',
#   'client',
#   'understand',
#   'planning',
#   'project',
#   'providethem',
#   'progress',
#   'report',
#   'modules.gather',
#   'complete',
#   'requirement',
#   'project',
#   'userto',
#   'analyse',
#   'requirement',
#   'prepare',
#   'best',
#   'suited',
#   'database',
#   'structuredesign',
#   'project.create',
#   'database',
#   'table',
#   'function',
#   'stored',
#   'procedure',
#   'project.work',
#   'code',
#   'develop',
#   'application',
#   'provide',
#   'support',
#   'systemteam',
#   'fro',
#   'go',
#   'live',
#   'process.educational',
#   'credentialsonline',
#   'pc',
#   'builder',
#   'customized',
#   'configure',
#   'pc',
#   'online',
#   'project',
#   'canmake',
#   'easy',
#   'configure',
#   'purchase',
#   'pc',
#   'online',
#   'provide',
#   'online',
#   'orderingenvironment',
#   'personal',
#   'computer',
#   'user',
#   'project',
#   'completed',
#   'threetire',
#   'architecture',
#   'project',
#   'used',
#   'asp.net',
#   'technology',
#   'making',
#   'aweb',
#   'application',
#   'jquery',
#   'validation',
#   'bootstrap',
#   'responsive',
#   'web',
#   'page',
#   'mysql',
#   'database',
#   'backend',
#   'project',
#   'developed',
#   'two',
#   'moduleswhich',
#   'based',
#   'user',
#   'admin',
#   'module.worked',
#   'project',
#   'leader',
#   'work',
#   'designing',
#   'requirement',
#   'analysisphase',
#   'software',
#   'development',
#   'life',
#   'cycle',
#   'sdlc',
#   'followed',
#   'waterfallmodel',
#   'along',
#   'helped',
#   'programming',
#   'different',
#   'modules.animated',
#   'website',
#   'design'],
#  ['anirudh',
#   'anandmachine',
#   'learning',
#   'engineeranirudhanand80',
#   'gmail.com',
#   '8082366408',
#   'jammu',
#   'india',
#   'anand-anirudh',
#   'anirudh',
#   'anandprofilea',
#   'scrupulous',
#   'computer',
#   'science',
#   'undergraduate',
#   'coordinated',
#   'individual',
#   'seeking',
#   'entry-level',
#   'position',
#   'thefield',
#   'data',
#   'science',
#   'machine',
#   'learning',
#   'envision',
#   'tell',
#   'insight',
#   'raw',
#   'data',
#   'utilizingvarious',
#   'technology',
#   'would',
#   'assist',
#   'bringing',
#   'change',
#   'way',
#   'look',
#   'upon',
#   'data',
#   'furthermoreforesee',
#   'happening',
#   'using',
#   'machine',
#   'learning',
#   'models.professional',
#   'experience09/2022',
#   '10/2022',
#   'machine',
#   'learning',
#   'internestartuplabunderstandthe',
#   'data',
#   'obtained',
#   'research',
#   'team',
#   'conductcomprehensive',
#   'data',
#   'cleaning',
#   'meticulous',
#   'eda.build',
#   'ml',
#   'model',
#   'utilizing',
#   'various',
#   'technique',
#   'tools.skillstools',
#   'python',
#   'v',
#   'code',
#   'jupyter',
#   'notebook.packages',
#   'scikit-learn',
#   'panda',
#   'numpy',
#   'seaborn',
#   'matplotlib.machine',
#   'learning',
#   'exploratory',
#   'data',
#   'analysis',
#   'statistical',
#   'analysis',
#   'predictive',
#   'modelling',
#   'regression',
#   'classification',
#   'clustering',
#   'algorithm',
#   'regularization.soft',
#   'skillstime',
#   'management',
#   'problem',
#   'solving',
#   'leadership',
#   'teamwork',
#   'adaptability',
#   'work',
#   'ethicsprojectsdiabetes',
#   'predictionanalyzed',
#   'performed',
#   'exponential',
#   'data',
#   'analysis',
#   'national',
#   'institute',
#   'diabetes',
#   'digestive',
#   'andkidney',
#   'disease',
#   'objective',
#   'dataset',
#   'diagnostically',
#   'predict',
#   'whether',
#   'patient',
#   'diabetes',
#   'based',
#   'certain',
#   'diagnostic',
#   'measurement',
#   'included',
#   'dataset.built',
#   'prediction',
#   'model',
#   'based',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'knn',
#   'svm',
#   'different',
#   'onset',
#   'type2',
#   'diabetes',
#   'prediction.uses',
#   'blood',
#   'pressure',
#   'glucose',
#   'pregnancy',
#   'various',
#   'marker',
#   'predict',
#   'outcome',
#   'comparetheir',
#   'performance',
#   'metrics.sms',
#   'spam',
#   'classifierml',
#   'model',
#   'classifies',
#   'message',
#   'spam',
#   'spam.used',
#   'logistic',
#   'regression',
#   'decision',
#   'tree',
#   'random',
#   'forest',
#   'gave',
#   'accuracy',
#   '96.1',
#   ',94.4',
#   '97.5',
#   'respectively.education07/2019',
#   '07/2023',
#   'b.tech',
#   'computer',
#   'science',
#   'engineering',
#   'jammu',
#   'india',
#   'shri',
#   'mata',
#   'vaishno',
#   'devi',
#   'university',
#   'reasi',
#   'j',
#   'k',
#   'organisationsa.i',
#   'circlecollaboratedwith',
#   'team',
#   'mate',
#   'making',
#   'various',
#   'ml',
#   'models.taught',
#   'provided',
#   'guidance',
#   'juniorscoursesmachine',
#   'learningsimplilearngotto',
#   'know',
#   'various',
#   'machine',
#   'learning',
#   'algorithm',
#   'implementations.developed',
#   'various',
#   'machine',
#   'learning',
#   'project'],
#  ['ashray',
#   'rainaashrayraina22',
#   'gmail.com',
#   '7780995937',
#   'ashray',
#   'raina',
#   'ashray22profilea',
#   'meticulous',
#   'computer',
#   'science',
#   'undergraduate',
#   'organized',
#   'individual',
#   'seeking',
#   'entry-level',
#   'position',
#   'field',
#   'ofdata',
#   'science',
#   'machine',
#   'learning',
#   'visualize',
#   'tell',
#   'insight',
#   'raw',
#   'data',
#   'using',
#   'various',
#   'technologieswhich',
#   'would',
#   'help',
#   'bringing',
#   'change',
#   'way',
#   'look',
#   'upon',
#   'data',
#   'also',
#   'predict',
#   'happening',
#   'using',
#   'themachine',
#   'learning',
#   'models.skillstools',
#   'python',
#   'v',
#   'code',
#   'jupyter',
#   'notebook.packages',
#   'scikit-learn',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'seaborn',
#   'jupyter',
#   'notebook.machine',
#   'learning',
#   'statistical',
#   'analysis',
#   'exploratory',
#   'data',
#   'analysis',
#   'predictive',
#   'modelling',
#   'regression',
#   'classification',
#   'clustering',
#   'algorithm',
#   'regularizationsoft',
#   'skillsteam',
#   'management',
#   'problem',
#   'solving',
#   'teamwork',
#   'leadership',
#   'confidenceprojectssentiment',
#   'analysis',
#   'webapp',
#   'senttextused',
#   'python',
#   'script',
#   'extract',
#   'tweet',
#   'comment',
#   'data',
#   'twitter.analyzed',
#   'performed',
#   'nlp',
#   'based',
#   'tokenization',
#   'lemmatization',
#   'vectorization',
#   'processed',
#   'data',
#   'using',
#   'neattext',
#   'inmachine',
#   'understandable',
#   'language.designed',
#   'multi-class',
#   'classification',
#   'model',
#   'modeled',
#   'logistic',
#   'regression',
#   'text',
#   'vectorization',
#   'pipeline',
#   'forpredicting',
#   'sentiment.used',
#   'simplified',
#   'python',
#   'framework',
#   'streamlit',
#   'make',
#   'webapp.diabetes',
#   'predictionanalyzed',
#   'performed',
#   'exponential',
#   'data',
#   'analysis',
#   'national',
#   'institute',
#   'diabetes',
#   'digestive',
#   'kidneydiseases',
#   'objective',
#   'dataset',
#   'diagnostically',
#   'predict',
#   'whether',
#   'patient',
#   'diabetes',
#   'based',
#   'oncertain',
#   'diagnostic',
#   'measurement',
#   'included',
#   'dataset.built',
#   'prediction',
#   'model',
#   'based',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'knn',
#   'svm',
#   'different',
#   'onset',
#   'type',
#   '2diabetes',
#   'prediction.uses',
#   'blood',
#   'pressure',
#   'glucose',
#   'pregnancy',
#   'various',
#   'marker',
#   'predict',
#   'outcome',
#   'compare',
#   'theirperformance',
#   'metrics.loan',
#   'predictionworked',
#   'loan',
#   'prediction',
#   'dataset',
#   'problem',
#   'clear',
#   'classification',
#   'problem',
#   'need',
#   'classify',
#   'whether',
#   'theloan',
#   'status',
#   'yes',
#   'no.used',
#   'logistic',
#   'regression',
#   'random',
#   'forest',
#   'decision',
#   'tree',
#   'classifier',
#   'gave',
#   'accuracy',
#   '82.2',
#   '86.3',
#   ',81.7',
#   'respectively.education07/2019',
#   '07/2023',
#   'b.tech',
#   'computer',
#   'science',
#   'katra',
#   'india',
#   'shri',
#   'mata',
#   'vaishno',
#   'devi',
#   'universitycgpa',
#   '7.13coursesmachine',
#   'learning',
#   'allcourseragotto',
#   'know',
#   'various',
#   'machine',
#   'learning',
#   'algorithm',
#   'mathematical',
#   'implementation.developed',
#   'end',
#   'end',
#   'machine',
#   'learning',
#   'projectsinterestsvideo',
#   'editing',
#   'graphic',
#   'designing',
#   'cricket',
#   'football'],
#  ['ramachandran',
#   'iyeriim',
#   'ahmedabad',
#   'alumnus|',
#   'smp',
#   'csm',
#   'itilphone',
#   '+91',
#   '9820463399address',
#   'nandan',
#   'prospera',
#   'a4-301',
#   'baner',
#   'road',
#   'balewadi',
#   'pune',
#   '411045website',
#   'http',
#   '//www.linkedin.com/in/iyer-ramachandran/email',
#   'ganesh2480',
#   'gmail.com19',
#   'year',
#   'experience',
#   'managing',
#   'large',
#   'global',
#   'client',
#   'across',
#   'different',
#   'vertical',
#   'building',
#   'operation',
#   'creating',
#   'customersuccess',
#   'story',
#   'strong',
#   'focus',
#   'deliveryled',
#   'strategic',
#   'initiative',
#   'centered',
#   'customer',
#   'experience',
#   'operational',
#   'efficiency',
#   'sla',
#   'management',
#   'streamliningprocesses',
#   'coordination',
#   'stakeholder',
#   'like',
#   'product',
#   'revenue',
#   'design',
#   'support',
#   'teams.led',
#   'talent',
#   'management',
#   'strategy',
#   'career',
#   'framework',
#   'competency',
#   'mapping',
#   'skill',
#   'gap',
#   'analysis',
#   'succession',
#   'planning',
#   'retention',
#   'performance',
#   'managementexperienced',
#   'setting',
#   'operationalizing',
#   'delivery',
#   'center',
#   'right',
#   'scratchexpertise',
#   'handling',
#   'itil',
#   'operation',
#   'including',
#   'incident',
#   'problem',
#   'change',
#   'managementskillsstrategy',
#   'planning',
#   'leadershipproduct',
#   'project',
#   'managementapplication',
#   'support',
#   'sla',
#   'management',
#   'continuous',
#   'service',
#   'improvementclient',
#   'relationship',
#   'managementresource',
#   'managementvendor',
#   'managementit',
#   'infrastructure',
#   'networksservice',
#   'jira',
#   'confluenceexperiencenectarium',
#   'pvt',
#   'ltd.',
#   'june',
#   '2021',
#   'april',
#   '2022directorled',
#   'business',
#   'operation',
#   '2',
#   'diverse',
#   'domain',
#   'software',
#   'development',
#   'vfx',
#   'hired',
#   'managed',
#   '150',
#   'resource',
#   'pre-sales',
#   'delivery',
#   'product',
#   'human',
#   'resource',
#   'teamssetup',
#   'new',
#   'delivery',
#   'center',
#   'indore',
#   'hired',
#   '50+',
#   'resource',
#   'project',
#   'delivery',
#   'le',
#   'two',
#   'month',
#   '0.5',
#   'million',
#   'business',
#   'acquired',
#   'several',
#   'round',
#   'negotiation',
#   'client',
#   'hot',
#   'lead',
#   'market',
#   'place',
#   'using',
#   'structuredplanning',
#   'pre',
#   'sale',
#   'deliveryset',
#   'employee',
#   'performance',
#   'career',
#   'pathing',
#   'process',
#   'right',
#   'setting',
#   'goal',
#   'tracking',
#   'kpi',
#   "'s",
#   'conducting',
#   'review',
#   'anddoing',
#   'appraisal',
#   'promotionsautomated',
#   'process',
#   'lifecycle',
#   'sale',
#   'lead',
#   'right',
#   'inception',
#   'closure',
#   'within',
#   'crm',
#   'portal',
#   'saving',
#   'precioustime',
#   'also',
#   'available',
#   'real',
#   'time',
#   'status',
#   'anytime',
#   'anywherebny',
#   'mellon',
#   'technology',
#   'january',
#   '2010',
#   'june',
#   '2021vice',
#   'presidentled',
#   'multiple',
#   'team',
#   'across',
#   'new',
#   'client',
#   'onboarding',
#   'technical',
#   'operation',
#   'manager',
#   'application',
#   'support',
#   'saas',
#   'productmanagement',
#   'daily',
#   'operation',
#   'support100',
#   'contract',
#   'retention',
#   'client',
#   'boarded',
#   'year',
#   'effective',
#   'client',
#   'relationship',
#   'management',
#   'upselling',
#   'cross',
#   'selling',
#   'improved',
#   'version',
#   'existing',
#   'product',
#   'new',
#   'product',
#   'offeringstransitioned',
#   'support',
#   'process',
#   'boston',
#   'pune',
#   'build',
#   '24',
#   '7',
#   'support',
#   'team',
#   'phase-2',
#   'setup',
#   'follow',
#   'sun',
#   'model',
#   'bybuilding',
#   'team',
#   'strategic',
#   'location',
#   'i.e',
#   'sydney',
#   'singapore50+',
#   'client',
#   'boarded',
#   'around',
#   'globe',
#   'helping',
#   'setup',
#   'development',
#   'test',
#   'prod',
#   'region',
#   'enabling',
#   'support',
#   'modelsand',
#   'handling',
#   'escalationsworking',
#   'rotational',
#   'shift',
#   'handling',
#   'client',
#   'query',
#   'triaging',
#   'issue',
#   'installation',
#   'upgrade',
#   'service',
#   'pack',
#   'migration',
#   'database',
#   'refreshes',
#   'dr',
#   'testing',
#   'capacity',
#   'testing',
#   'setting',
#   'vpn',
#   'tunnelsimplemented',
#   'itil',
#   'best',
#   'practice',
#   'including',
#   'continuous',
#   'service',
#   'improvement',
#   'csi',
#   'incident',
#   'problem',
#   'change',
#   'release',
#   'stakeholder',
#   'vendor',
#   'management.achieved',
#   'optimal',
#   'operational',
#   'efficiency',
#   '35',
#   'client',
#   'sla',
#   "'s",
#   'met',
#   '100',
#   'fine-tuned',
#   'tat',
#   '40',
#   'overallsubstantial',
#   'saving',
#   'span',
#   'timeachieved',
#   '30',
#   'reduction',
#   'year',
#   'year',
#   'number',
#   'incident',
#   'eliminated',
#   'repeat',
#   'issue',
#   'timely',
#   'product',
#   'change',
#   'bycollaborating',
#   'product',
#   'engineering',
#   'teamsdelivered',
#   '99.5',
#   'average',
#   'uptime',
#   'system',
#   'throughout',
#   'year',
#   'annual',
#   'saving',
#   'close',
#   '2',
#   'million',
#   'resourcecostsparticipated',
#   'vendor',
#   'management',
#   'activity',
#   'including',
#   'requirement',
#   'gathering',
#   'feasibility',
#   'check',
#   'uat',
#   'signoff',
#   'third',
#   'partyintegration',
#   'area',
#   'like',
#   'client',
#   'reporting',
#   'business',
#   'intelligence',
#   'bi',
#   'single',
#   'sign',
#   'sso',
#   'drs',
#   'firewall',
#   'securityas',
#   'business',
#   'analyst',
#   'acted',
#   'bridge',
#   'technology',
#   'team',
#   'business',
#   'client',
#   'ensure',
#   'requirement',
#   'areunderstood',
#   'transformed',
#   'tool',
#   'help',
#   'product',
#   'team',
#   'wherever',
#   'feasibleresource',
#   'planning',
#   'based',
#   'business',
#   'projection',
#   'tracking',
#   'utilization',
#   'ensuring',
#   'compliance',
#   'related',
#   'billing',
#   'timesheet.published',
#   'metric',
#   'related',
#   'headcount',
#   'attrition',
#   'utilization',
#   'stats',
#   'quantifiable',
#   'analysis',
#   'ensured',
#   'resourcedemand',
#   'fulfilment',
#   'cross-skilling',
#   're-skilling',
#   'talent.won',
#   'multiple',
#   'award',
#   'past',
#   'decade',
#   'including',
#   'yearly',
#   'outstanding',
#   'leadership',
#   'award',
#   '2019',
#   'andquarterly',
#   'award',
#   'client',
#   'production',
#   'application',
#   'supportdeputations',
#   'boston',
#   'usa',
#   'brisbane',
#   'australiasyntel',
#   'ltd.',
#   'november',
#   '2007',
#   'november',
#   '2009project',
#   'leadproject',
#   'lead',
#   'role',
#   'edw',
#   'production',
#   'support',
#   'processbusiness',
#   'analyst',
#   'role',
#   'onboarding',
#   '5',
#   'client',
#   'transaction',
#   'lifecycle',
#   'management',
#   'processrequirement',
#   'gathering',
#   'data',
#   'mapping',
#   'time',
#   'evaluation',
#   'resource',
#   'requirement',
#   'analysis',
#   'complete',
#   'project',
#   'planningprovide',
#   'post',
#   'implementation',
#   'supportbank',
#   'nova',
#   'scotia',
#   'may',
#   '2003',
#   'october',
#   '2007consultantcompleted',
#   'due',
#   'diligence',
#   'documentation',
#   'pertaining',
#   'gold',
#   'silver',
#   'sale',
#   'customer',
#   'across',
#   'mumbai',
#   'new',
#   'delhicentersconduct',
#   'data',
#   'reconciliation',
#   'sale',
#   'document',
#   'export',
#   'receipt',
#   'customerscreated',
#   'sop',
#   'document',
#   'compilation',
#   'submission',
#   'competent',
#   'authority',
#   'ensured',
#   'requisite',
#   'procedure',
#   'followedfor',
#   'bond',
#   'cancellationdriven',
#   'process',
#   'efficiency',
#   'measure',
#   'improve',
#   'tat',
#   'data',
#   'reconciliation',
#   'availabilityeducationiim',
#   'ahmedabadsenior',
#   'management',
#   'program',
#   'smp',
#   'general',
#   'managementuniversity',
#   'mumbaibachelors',
#   'commercecertificationscertified',
#   'scrum',
#   'master',
#   'csm',
#   'itil',
#   'v4',
#   'foundation',
#   'itil',
#   'six',
#   'sigma',
#   'master',
#   'black',
#   'belt'],
#  ['himanshu',
#   'tyagipune',
#   'maharashtra',
#   'email',
#   'indeed',
#   'indeed.com/r/himanshu-tyagi/1c1abc0800189689',
#   'data',
#   'science',
#   'professional',
#   'experience',
#   'stage',
#   'data',
#   'processing',
#   'insightsdelivery',
#   'data',
#   'mining',
#   'statistical',
#   'analysis',
#   'identify',
#   'insight',
#   'pattern',
#   'complex',
#   'datasets',
#   'experience',
#   'insight',
#   'delivery',
#   'insurance',
#   'related',
#   'vertical',
#   'competent',
#   'working',
#   'artificial',
#   'neural',
#   'network',
#   'know',
#   'machine',
#   'learning',
#   'python',
#   'efficient',
#   'developing',
#   'supervised/unsupervised',
#   'learning',
#   'models.willing',
#   'relocate',
#   'delhi',
#   'delhi',
#   'bengaluru',
#   'karnataka',
#   'pune',
#   'maharashtrawork',
#   'experiencecapgemini',
#   'pune',
#   'maharashtra',
#   '-march',
#   '2017',
#   'presentclient',
#   '-sunlife',
#   'financials',
#   'data',
#   'insight',
#   'project',
#   'overview',
#   'developed',
#   'churn',
#   'analysis',
#   'fraud',
#   'claim',
#   'detection',
#   'real',
#   'time',
#   'data/back-office',
#   'data',
#   'currently',
#   'working',
#   'neural',
#   'network',
#   'deep',
#   'learning',
#   'prediction',
#   'system.responsibilities',
#   '-1.',
#   'data',
#   'understanding',
#   'process',
#   'formation',
#   'clients.2',
#   'extensive',
#   'hands-on',
#   'regression',
#   'classification',
#   'techniques.3',
#   'building',
#   'baseline',
#   'model',
#   'requirement',
#   'necessary',
#   'data',
#   'preparation.4',
#   'parameter',
#   'tuning',
#   'process',
#   'optimal',
#   'model',
#   'hyperparametrs.5',
#   'ensembling',
#   'learning',
#   'method',
#   'tuned',
#   'models.6',
#   'implemented',
#   'customer',
#   'churn',
#   'analysis',
#   'models.7',
#   'recommended',
#   'product',
#   'market-basket',
#   'analysis',
#   'technique',
#   'lead',
#   'increase',
#   'insales',
#   '17',
#   '.8',
#   'developed',
#   'customer',
#   'churn',
#   'analysis',
#   'sytem',
#   'led',
#   'growth',
#   'retention',
#   'highvalued',
#   'potential',
#   'customers.capgemini',
#   'pune',
#   'maharashtra',
#   '-may',
#   '2016',
#   'february',
#   '2017client',
#   '-sunlife',
#   'financials',
#   'group',
#   'fact',
#   'project',
#   'overview',
#   'mainframe',
#   'development',
#   'support',
#   'project',
#   'worked',
#   'insurance',
#   'vertical.handled',
#   'claim',
#   'premium',
#   'commission',
#   'processing',
#   'via',
#   'batch',
#   'cycles.responsibilities',
#   '-1.',
#   'handling',
#   'production',
#   'batch',
#   'cycle.2',
#   'mainframe',
#   'development',
#   'jcl',
#   'cobol',
#   'db2',
#   'ims',
#   'vsam',
#   'ca7',
#   'etc3',
#   'enhancement',
#   'cobol',
#   'easytrieve.4',
#   'claim',
#   'processing',
#   'disbursements.5',
#   'unit',
#   'testing',
#   'code',
#   'validation',
#   'reviews.6',
#   'compliance',
#   'check',
#   'client',
#   'inputs.7',
#   'automation',
#   'delivery',
#   'responsibilities.8.data',
#   'scientistcapgemini1',
#   'data',
#   'understanding',
#   'process',
#   'formation',
#   'clients.2',
#   'extensive',
#   'hands-on',
#   'regression',
#   'classification',
#   'techniques.3',
#   'building',
#   'baseline',
#   'model',
#   'requirement',
#   'necessary',
#   'data',
#   'preparation.4',
#   'parameter',
#   'tuning',
#   'process',
#   'optimal',
#   'model',
#   'hyperparametrs.5',
#   'ensembling',
#   'learning',
#   'method',
#   'tuned',
#   'models.6',
#   'implemented',
#   'customer',
#   'churn',
#   'analysis',
#   'models.7',
#   'recommended',
#   'product',
#   'market-basket',
#   'analysis',
#   'technique',
#   'lead',
#   'increase',
#   'insales',
#   '17',
#   '.8',
#   'developed',
#   'customer',
#   'churn',
#   'analysis',
#   'sytem',
#   'led',
#   'growth',
#   'retention',
#   'high',
#   'valuedpotential',
#   'customers.educationbtech',
#   'electronicsuptu',
#   'noida',
#   'uttar',
#   'pradesh2010',
#   '2011assisi',
# ...
#   'lucknow08/2012',
#   '08/2016',
#   'lucknow',
#   'classication',
#   'problemthis',
#   'project',
#   'identify',
#   'image',
#   'person',
#   'certain',
#   'number',
#   'ofimages',
#   'two',
#   'person',
#   'using',
#   'convolutional',
#   'neural',
#   'networkalgorithm',
#   'technology',
#   'kera',
#   'panda',
#   'numpywork',
#   'experiencehuman',
#   'activity',
#   'recognitiondata',
#   'internusing',
#   'machine',
#   'learning',
#   'project',
#   'use',
#   'machine',
#   'learning',
#   'tozenapt',
#   'solution',
#   'private',
#   'limited',
#   'recognise',
#   'various',
#   'activity',
#   'taking',
#   'activity',
#   'recognition',
#   'data',
#   'set.the',
#   'dataset',
#   'includes',
#   'sensor',
#   'reading',
#   '30',
#   'dierent',
#   'individual',
#   'and01/2019',
#   'present',
#   'bangalorethe',
#   'type',
#   'activity',
#   'recorded',
#   'data',
#   'extractedzenapt',
#   'building',
#   'solution',
#   'complicated',
#   'problem',
#   'related',
#   'data',
#   'kaggle',
#   'classify',
#   'various',
#   'activity',
#   'algorithm',
#   'logisticinformation',
#   'automate',
#   'optimize',
#   'complex',
#   'data',
#   'analytics',
#   'ai',
#   'regression',
#   'kneighborsclassier',
#   'randomforestclassierbased',
#   'systems.achievements/tasksthe',
#   'intelligent',
#   'bank',
#   'developed',
#   'designed',
#   'ai',
#   'enabledadvanced',
#   'banking',
#   'system',
#   'completely',
#   'redene',
#   'algorithmsbanks',
#   'work',
#   'transform',
#   'customerexperiences',
#   'machine',
#   'learning',
#   'pythonextract',
#   'text',
#   'image',
#   'module',
#   'using',
#   'ocr.deep',
#   'learning',
#   'tensorow',
#   'kera',
#   'pandasjson',
#   'parser.depth',
#   'knowledge',
#   'probability',
#   'statisticscontact',
#   'sudhanshu',
#   'kumar',
#   '9176072251regression',
#   'linear',
#   'logistic',
#   'data',
#   'internzenapt',
#   'solution',
#   'private',
#   'limited',
#   'decision',
#   'tree',
#   'random',
#   'forest10/2018',
#   '12/2018',
#   'bangaloreknn',
#   'bayesian',
#   'k-meanszenapt',
#   'building',
#   'solution',
#   'complicated',
#   'problem',
#   'related',
#   'data',
#   'information',
#   'automate',
#   'optimize',
#   'complex',
#   'data',
#   'analytics',
#   'aibased',
#   'system',
#   'neural',
#   'network',
#   'cnnachievements/taskshelmetdetection',
#   'tensorflow',
#   'objectdetectionlanguagescontact',
#   'sudhanshu',
#   'kumar',
#   '9176072251english',
#   'hindipython',
#   'developerfull',
#   'professional',
#   'prociency',
#   'native',
#   'bilingual',
#   'prociencyuttrakhand',
#   'trektrip10/2016',
#   '12/2017',
#   'gurgaonuttrakhand',
#   'trektrip',
#   'online',
#   'platform',
#   'help',
#   'trekker',
#   'planinterestsand',
#   'execute',
#   'trekking',
#   'trip',
#   'uttrakhand',
#   'regionachievements/taskspython',
#   'developer',
#   'developed',
#   'maintained',
#   'module',
#   'tovollyball',
#   'badminton',
#   'travelingsupport',
#   'internet',
#   'based',
#   'travel',
#   'platform.contact',
#   'santosh',
#   'joshi',
#   '9910664917'],
#  ['rakshit',
#   'khajuriamachine',
#   'learning',
#   'engineera',
#   '2+',
#   'year',
#   'experienced',
#   'machine',
#   'learning',
#   'enthusiast',
#   'design',
#   'build',
#   'deploy',
#   'enterprise',
#   'level',
#   'machine',
#   'learning',
#   'solutions.rakshitraina1234',
#   'gmail.com',
#   '9149556155jammu',
#   'india',
#   'linkedin.com/in/rakshit-khajuria-3627781b8github.com/ryzxxl',
#   'stackoverow.com/users/14526226/rakshit-khajuriainstagram.com/_x.rakshit_swork',
#   'experience',
#   'skillsmachine',
#   'learning',
#   'tarineepython',
#   'c/c++',
#   'data',
#   'structure',
#   'mathematicsineuron.ai11/2020',
#   '08/2021',
#   'bangalore',
#   'statistic',
#   'machine',
#   'learning',
#   'data',
#   'analysisneuron',
#   'product-driven',
#   'organization',
#   'working',
#   'state',
#   'art',
#   'project',
#   'forour',
#   'domestic',
#   'international',
#   'client',
#   'data',
#   'visualization',
#   'heroku',
#   'html+css3',
#   'flaskachievements/tasksgot',
#   'learn',
#   'various',
#   'thing',
#   'beginning',
#   'like',
#   'python',
#   'api',
#   'streamlit',
#   'nlp',
#   'deep',
#   'learningdeployment',
#   'aws',
#   'azure',
#   'gcp',
#   'heroku.got',
#   'know',
#   'dierent',
#   'database',
#   'various',
#   'module',
#   'instatistics',
#   'machine',
#   'learning',
#   'algorithm',
#   'mathematicalimplementation',
#   'numpy',
#   'mathematics',
#   'heroku',
#   'html+css3personal',
#   'projectspandas.developed',
#   'end',
#   'end',
#   'machine',
#   'learning',
#   'projects.content-based',
#   'recommender',
#   'system',
#   'movie',
#   'website',
#   '05/2022',
#   '06/2022',
#   'deep',
#   'learning',
#   'computer',
#   'vision',
#   'nlpanalyzed',
#   'perform',
#   'eda',
#   'tmdb',
#   'dataset',
#   'made',
#   'full',
#   'end-to-endtraineemachine',
#   'learning',
#   'model',
#   'using',
#   'bag',
#   'word',
#   'nlp.ineuron.ai',
#   'streamlit',
#   'used',
#   'frontend',
#   'easy',
#   'making',
#   'websiteenabled',
#   'user',
#   'recommended',
#   'movie',
#   'based',
#   '50+',
#   'data',
#   'point',
#   '10/2021',
#   'present',
#   'bangaloreneuron',
#   'product-driven',
#   'organization',
#   'working',
#   'state',
#   'art',
#   'project',
#   'forindia',
#   "'s",
#   'suicide',
#   'predictor',
#   'model',
#   'using',
#   'djangoour',
#   'domestic',
#   'international',
#   'client',
#   '07/2021',
#   '08/2021',
#   'achievements/tasksa',
#   'simple',
#   'machine',
#   'learning',
#   'model',
#   'converted',
#   'webapp',
#   'useslearning',
#   'advance',
#   'nlp',
#   'deep-learning',
#   'overview',
#   'tensorflow',
#   'year',
#   'input',
#   'give',
#   'total',
#   'number',
#   'suicide',
#   'happened',
#   'orpytorch',
#   'neural',
#   'network',
#   'cnn',
#   'overview',
#   'happening',
#   'year',
#   'deployment',
#   'model',
#   'performance',
#   'tuning',
#   'analyzed',
#   'performed',
#   'eda',
#   'given',
#   'dataset.made',
#   'end-to-end',
#   'django',
#   'webapp',
#   'using',
#   'html+css3.used',
#   'linear',
#   'regression',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'django',
#   'seaborndata',
#   'science',
#   'internlets',
#   'grow',
#   'diabetes',
#   'prediction',
#   'using',
#   'flask',
#   '02/2022',
#   '03/2022',
#   'analyzed',
#   'performed',
#   'exponential',
#   'data',
#   'analysis',
#   'national',
#   'institute08/2021',
#   '09/2021',
#   'uttar',
#   'pardeshof',
#   'diabetes',
#   'digestive',
#   'kidney',
#   'diseasesachievements/tasks',
#   'objective',
#   'dataset',
#   'diagnostically',
#   'predict',
#   'whether',
#   'aworked',
#   'exploratory',
#   'data',
#   'analysis',
#   'dataset',
#   'terrorism',
#   'patient',
#   'diabetes',
#   'based',
#   'certain',
#   'diagnostic',
#   'measurement',
#   'includediris',
#   'flower',
#   'classication',
#   'machine',
#   'learning',
#   'project',
#   'dataset.built',
#   'prediction',
#   'model',
#   'based',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'knn',
#   'converted',
#   'data',
#   'actionable',
#   'insight',
#   'predicting',
#   'andand',
#   'svm',
#   'dierent',
#   'onset',
#   'type',
#   '2',
#   'diabetes',
#   'prediction.modeling',
#   'future',
#   'outcomes.uses',
#   'blood',
#   'pressure',
#   'glucose',
#   'pregnancy',
#   'various',
#   'marker',
#   'toused',
#   'dierent',
#   'library',
#   'framework',
#   'like',
#   'panda',
#   'numpy',
#   'plotly',
#   'predict',
#   'outcome',
#   'compare',
#   'performance',
#   'metrics.seabom',
#   'matplotlib',
#   'plotly',
#   'sklearn',
#   'svm',
#   'logistic',
#   'knn.languageseducationpython',
#   'c/c++electronics',
#   'communication',
#   'full',
#   'professional',
#   'prociency',
#   'limited',
#   'working',
#   'prociencyengineering',
#   'smvd',
#   'university',
#   'reasi',
#   'j',
#   'k',
#   '07/2019',
#   'present',
#   'jammuwork',
#   'interestscollaborating',
#   'teammate',
#   'a.i',
#   'circle',
#   'wemake',
#   'project',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'footballdiscussions',
#   'regarding',
#   'theeld',
#   'machine',
#   'learningmathematics',
#   'sketchingwith',
#   'python'],
#  ['rakshit',
#   'khajuriamachine',
#   'learning',
#   'engineertalab',
#   'tillo',
#   'gole',
#   'gujral',
#   '180002',
#   'jammu',
#   'india',
#   'rakshitraina1234',
#   'gmail.com',
#   '914955615514',
#   'aug',
#   '2001',
#   'http',
#   '//www.linkedin.com/in/rakshit-khajuria-3627781b8/',
#   'http',
#   '//github.com/ryzxxl9149556155summaryskilled',
#   'developing',
#   'implementing',
#   'data-driven',
#   'solution',
#   'real-world',
#   'problem',
#   'utilizing',
#   'range',
#   'tool',
#   'andtechniques',
#   'extract',
#   'valuable',
#   'insight',
#   'large',
#   'complex',
#   'data',
#   'set',
#   'posse',
#   'diverse',
#   'experience',
#   'cleaningand',
#   'analyzing',
#   'data',
#   'enhancing',
#   'existing',
#   'model',
#   'continuously',
#   'seeking',
#   'enhance',
#   'skill',
#   'broaden',
#   'myknowledge',
#   'dynamic',
#   'eld',
#   'data',
#   'science.skillstools',
#   'python',
#   'git',
#   'github',
#   'jupyter',
#   'notebook',
#   'anaconda',
#   'v',
#   'codepackages',
#   'scikit-learn',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'nltk',
#   'tensorflow',
#   'flask',
#   'streamlit',
#   'spacy',
#   'text',
#   'blob',
#   'vader.machine',
#   'learning',
#   'supervised',
#   'learning',
#   'unsupervised',
#   'learning',
#   'clustering',
#   'algorithm',
#   'decision',
#   'tree',
#   'randomforests',
#   'neural',
#   'networks.nlp',
#   'sentiment',
#   'analysis',
#   'text',
#   'classication',
#   'named',
#   'entity',
#   'recognition',
#   'word',
#   'embedding',
#   'topic',
#   'modeling',
#   'deeplearning',
#   'nlp',
#   'model',
#   'e.g',
#   '.',
#   'transformer',
#   'bert',
#   'lstms',
#   'soft',
#   'skillstime',
#   'management',
#   'problem-solving',
#   'leadership',
#   'teamwork',
#   'presentation',
#   'skill',
#   'condenceprofessional',
#   'experienceresearch',
#   'intern',
#   'jul',
#   '2022',
#   'presentjammu',
#   'indiadeveloped',
#   'implemented',
#   'sentiment',
#   'analysis',
#   'model',
#   'extract',
#   'classifyemotional',
#   'context',
#   'scraped',
#   'reddit',
#   'data',
#   'suicidal',
#   'discussions.utilized',
#   'advanced',
#   'technique',
#   'including',
#   'unsupervised',
#   'pre-trained',
#   'model',
#   'e.g',
#   'vader',
#   'textblob',
#   'clustering',
#   'algorithm',
#   'e.g',
#   'kmeans',
#   'dbscan',
#   'accurately',
#   'analyze',
#   'andinterpret',
#   'sentiment.enhanced',
#   'model',
#   'performance',
#   'use',
#   'deep',
#   'learning',
#   'technique',
#   'aslstm',
#   'bilstm',
#   'etc',
#   'ne-tuning',
#   'pre-trained',
#   'word',
#   'embeddings',
#   'e.g',
#   'glove',
#   '.improved',
#   'model',
#   'accuracy',
#   'applying',
#   'different',
#   'bert',
#   'models.machine',
#   'learning',
#   'tarinee',
#   'nov',
#   '2020',
#   'aug',
#   '2021became',
#   'procient',
#   'wide',
#   'range',
#   'machine',
#   'learning',
#   'algorithm',
#   'including',
#   'bangalore',
#   'indiaunderlying',
#   'mathematical',
#   'principles.hands-on',
#   'experience',
#   'end-to-end',
#   'machine',
#   'learning',
#   'project',
#   'development',
#   'dataacquisition',
#   'model',
#   'deployment.demonstrated',
#   'expertise',
#   'using',
#   'cloud',
#   'platform',
#   'heroku',
#   'streamlit',
#   'aws',
#   'efciently',
#   'deploy',
#   'machine',
#   'learning',
#   'model',
#   'solutions.rakshitraina1234',
#   'gmail.com',
#   '1',
#   '2projectsmulti',
#   'purpose',
#   'nlp',
#   'application',
#   'nlpify',
#   'nov',
#   '2022',
#   'nov',
#   '2022developed',
#   'sophisticated',
#   'ai',
#   'platform',
#   'extract',
#   'various',
#   'nlp',
#   'feature',
#   'includingsentiment',
#   'analysis',
#   'named',
#   'entity',
#   'recognition',
#   'text',
#   'summarization',
#   'appreview',
#   'data.performed',
#   'extensive',
#   'data',
#   'preprocessing',
#   'using',
#   'technique',
#   'tokenization',
#   'lemmatization',
#   'vectorization',
#   'transform',
#   'raw',
#   'data',
#   'machine-readableformat.createda',
#   'multi-class',
#   'classication',
#   'model',
#   'using',
#   'logistic',
#   'regression',
#   'textvectorization',
#   'pipeline',
#   'predict',
#   'sentiment',
#   'deployed',
#   'platform',
#   'user-friendly',
#   'web',
#   'app',
#   'using',
#   'streamlit',
#   'framework.political',
#   'spectrum',
#   'detection',
#   'medium',
#   'news',
#   'using',
#   'deep-learning',
#   'shap',
#   'oct',
#   '2022',
#   'oct',
#   '2022pythonbuilta',
#   'political',
#   'spectrum',
#   'detection',
#   'deep',
#   'learning',
#   'sequential',
#   'model.performed',
#   'nlp',
#   'based',
#   'tokenization',
#   'lemmatization',
#   'vectorization',
#   'processed',
#   'datausing',
#   'neattext',
#   'machine',
#   'understandable',
#   'language.simplied',
#   'code',
#   'library',
#   'shap',
#   'built',
#   'theoretic',
#   'approach',
#   'explain',
#   'output',
#   'ofsequential',
#   'deep',
#   'learning',
#   'model.diabetes',
#   'prediction',
#   'using',
#   'flask',
#   'dec',
#   '2021',
#   'jan',
#   '2022conducted',
#   'in-depth',
#   'data',
#   'analysis',
#   'national',
#   'institute',
#   'diabetes',
#   'digestiveand',
#   'kidney',
#   'disease',
#   'datasetbuilt',
#   'multiple',
#   'machine',
#   'learning',
#   'model',
#   'including',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'knn',
#   'svm',
#   'prediction',
#   'various',
#   'onset',
#   'type',
#   '2',
#   'diabetescreated',
#   'full-stack',
#   'application',
#   'using',
#   'flask',
#   'deployed',
#   'heroku',
#   'publicaccess',
#   'http',
#   '//diabetes-prediction-app02.herokuapp.com/certificatesibm',
#   'data',
#   'science',
#   'specialization',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'traineeineuron.aimathematics',
#   'machine',
#   'learningdata',
#   'sciencestatistics',
#   'foundation',
#   'linkedinmachine',
#   'learning',
#   'pythoneducationelectronics',
#   'communication',
#   'engineering',
#   'smvd',
#   'university',
#   'reasi',
#   'j',
#   'k',
#   'jul',
#   '2019',
#   'jul',
#   '2023jammu',
#   'indiaorganisationsa.i',
#   'circleactivelyparticipated',
#   'a.i',
#   'circle',
#   'collaborating',
#   'team',
#   'member',
#   'machine',
#   'learning',
#   'project',
#   'mentoringjunior',
#   'member',
#   'machine',
#   'learning',
#   'potential',
#   'applicationsinterestscoding',
#   'football',
#   'sketching',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'mathematicsrakshitraina1234',
#   'gmail.com',
#   '2',
#   '2'],
#  ['w',
#   'g',
#   'u',
#   'p',
#   'jammu',
#   'dob',
#   '9-jan-2001',
#   '+91',
#   '9797402957',
#   'swayamgupta74',
#   'gmail.com',
#   'in/swa',
#   'yam-gupta-1ba7971b2',
#   'swayamgupta',
#   '74educationcourse',
#   'institute',
#   'year',
#   'passing',
#   'resultbachelors',
#   'technology',
#   'shri',
#   'mata',
#   'vaishno',
#   'devi',
#   'university',
#   '2023',
#   '7.9',
#   'cgpa12th',
#   'standard',
#   'delhi',
#   'public',
#   'school',
#   'jammu',
#   '2019',
#   '83',
#   '10th',
#   'standard',
#   'delhi',
#   'public',
#   'school',
#   'jammu',
#   '2017',
#   '10',
#   'cgpascholastic',
#   'achievementsscored',
#   'three',
#   'semester',
#   'scholarship',
#   'smvdu',
#   'katrasecured',
#   '91.85',
#   'percentile',
#   'jee',
#   'mainprojectsface',
#   'recognition',
#   'attendance',
#   'system',
#   'using',
#   'pythonpersonal',
#   'project',
#   'oct',
#   '2021',
#   'present',
#   'module',
#   'used',
#   'opencv',
#   'face_recognitionfood',
#   'ordering',
#   'apppersonal',
#   'project',
#   'jun',
#   '2021',
#   'aug',
#   '2021',
#   'worked',
#   'frontend',
#   'databasetechnologies',
#   'used',
#   'html',
#   'cs',
#   'java',
#   'script',
#   'php',
#   'mysqlnlp',
#   'data',
#   'pre-processingpersonal',
#   'project',
#   'jun',
#   '2021',
#   'worked',
#   'movie',
#   'review',
#   'data',
#   'collection',
#   'movie',
#   'review',
#   'imdb.com',
#   'website.preprocessed',
#   'data',
#   'used',
#   'nlp',
#   'task.modules',
#   'used',
#   'kera',
#   'numpy.skillsprogramming',
#   'language',
#   'python',
#   'sql',
#   'javamodules',
#   'panda',
#   'numpy',
#   'matplotlibweb',
#   'development',
#   'html',
#   'csstools',
#   'git',
#   'githubplatform',
#   'window',
#   'linuxadditional',
#   'detailsprofessional',
#   'developmentfront',
#   'end',
#   'web',
#   'development',
#   'ultimate',
#   'course',
#   'udemy',
#   'python',
#   'class',
#   'inheritance',
#   'coursera',
#   'python',
#   'function',
#   'file',
#   'dictionary',
#   'coursera',
#   'python',
#   'basic',
#   'coursera',
#   'programming',
#   'everybody',
#   'coursera',
#   'workshop',
#   'training',
#   'attendedadvanced',
#   'excel',
#   'workshop',
#   'conducted',
#   'microsoft',
#   'certified',
#   'trainer',
#   'founder',
#   'ceo',
#   'j',
#   'academyartificial',
#   'intelligence',
#   'workshop',
#   'iit',
#   "bombay'svolunteering",
#   'vikalp',
#   'student',
#   "'s",
#   'initiative',
#   'july',
#   '2019-present',
#   'taught',
#   'student',
#   'various',
#   'subject',
#   'even',
#   'covid',
#   'time',
#   'via',
#   'online',
#   'platformsorganized',
#   'various',
#   'development',
#   'activity',
#   'studentsconvinced',
#   'near',
#   'people',
#   'village',
#   'send',
#   'kid',
#   'take',
#   'advantage',
#   'initiative',
#   'education',
#   'important.organized',
#   'event',
#   'donate',
#   'food',
#   'stationary',
#   'clothes',
#   'etc',
#   'needy']]

# %%
cv_=[]
for i in cv_data:
    cv_.append([' '.join(i)])

# %%
cv_
# Out:
# [['sukanya jangrabhiwani haryanajangrasukanya066 gmail.compersonal detailsdate birth 2003-11-24eligible work indiahighest career level fresherindustry internet ecommercework experiencecomputer operatoreducationbachelorsskills skill computer skill data entry typing customer service microsoft word microsoft excel microsoft office html javascript c c++certifications licensesdiploma computer applicationjanuary 2021 april 2022'],
#  ["abhay kumarlead data scientist computer visionbangalore|+91-9731-812-812 |abhayownsthis gmail.com in.linkedin.com/in/abhay-kumar-99780458 abhaymise.github.io/summary skillsi applied computer vision data scientist experience leading bunch core pythonother data scientist used leadership applied deep learning skill successfullyexecute various computer vision project highly skilled applied deep learning computervision good understanding various computer vision technique like classification boundingbox classification regression object detection pixel wise prediction segmentation numpysequence classification lstms video classification good interpreter businessrequirements technical term vice versa excellent use case identification frombusiness requirements.pandasachievements include execution various computer vision project like building characteridentification fashion style guide recommender fashion attribute predictor activity detection image search engine.tensorflowmy work got accepted ai deep learning conference gtc 2018 nvidia.i looking role leverage skill experience betterment theorganisation improvement learning.i regular ai/ml blogger firm believer andre ng 's view democratising ai pas caffeon knowledge community various blogs.responsibilitiesopencvto understand business use case client convert well definedproblem statement explain development team machine learningto identify data set required develop predictive model solving internal externalbusiness problemsto fill data gap gathering data designing annotation portal conducting dataannotation human annotator deep learningto explore data set identify data transformation data quality need targetedapplicationstodevelop algorithm predictive model derive insight business value fromdataothersto provide leadership mentorship member team.identify implement use case might help organisation business developmentto interpret result produce actionable business insight lead measurablespark rdd dataframe used forbusiness consumer experience performance improvementsdata transformationto operationalize publish monitor successful model shape business datamapreduce used datascience strategyprocessing engineto partner department solve problem identify trend opportunitiesr experimental work mainly onto define develop program metric creation data collection modeling andstructured datareporting operational performanceto work cross-functionally define problem statement collect data build analyticalmodels make recommendations.to routinely communicate metric progress key indicator leadership.to lead support various ad hoc project needed support organizationssbusiness strategy.work experiencelead data scientist computer vision 2017 2018cogknit semanticshttps //www.visualcv.com/abhaymiseleads team 15 member including data scientist product engineer ui engineers.data scientist 2016 2017cogknit semanticsfirst member computer vision team organisationdata engineer 2015 2016cogknit semanticssenior research analyst 2013 2015edurekaeducationbachelor engineering computer science 2009 2013visvesvaraya technological universitymachine learning stanford university june 15 2016 june 15 2016coursera 96.1 stanforda machine learning course one pioneer artificial intelligencedeep learning specialisation 2017 2017deeplearning.aiit carry 5 deep learning course focus neural net cnn lstm bi-lstmsattended cs231n cnn visual recognition course 2016 2016stanfordattended completed assignment courseachievementa poster `` domain adaption image caption model video description `` acceptedat ai deep learning conference gtc 2018 nvidiamultiple blog identified best read across various ml/ai forumsprojectsmen style guide creation 2018 presentcogknit semanticsrecommend best matching attire men given particular attire recommended attire iscreated fly inspiration automated style guide automated styleguide brings trend factor following feed fashion celebrity accordinglycreate combination recommendation.built panda numpy tensorflow kera ...
#  ['abhijit manepatildata scientist master computer engineering 3+ year ofexperience using predictive modeling data processing data miningalgorithms hands-on experience leveraging machine learning modelsto solve challenging business problem involved python open sourcecommunity passionate deep reinforcement learning.pune maharashtra email indeed indeed.com/r/abhijit-manepatil/55dbd46d8fb95138willing relocate pune maharashtrawork experiencedata scientistbluebox technology -2015 present2015 present deep learning classification image online product buying site artificial intelligence convolutional neural network model cnn classify image differentproducts using tensorflow program kera high-level data cleansing api build train model data modeling sentiment analysis political campaign analysis helping taking natural language processing decision strategy making digital marketing detailedvirtualization data virtualization using matplotlib data mining identifying gi functionality using natural language processing sophisticated way define google gi functionality predictive modelingcustomer using natural language processing python nltk library statistical modeling us define structure project data analysis predict response customer specific marketing communication skill offer using various machine learning algorithm like regression andclassification model knn k-means nave baise svm etc team managementsoftware tool document classification using classification machine learningpython algorithm k-means svm excellent tensorflow kera panda numpy cctc footage analysis image classification using convolutional neuralscipy matplotlib scikit-learn nltk network model cnn identification customer detail count ar specific period visual recognition.goodsql good predication accident basis health history driver usingmongodb deep learning concept artificial neural network train model ongoodcassandra available dataset.goodjava recommend system goodc product base website customer support using recurrentvery goodneural network rnn cleaning data help nltk.c++very goodlanguages face detection using microsoft cognitive api.english proficien decide period foot fall shopping mall based date usinghindi tensorflow deep learning concepts.proficienmarathi tmother tongueeducationmaster engineeringuniversity puneskillsmachine learning data science python artificial intelience neural network naturallanguage processing data virtulization predictive modelling statistical modeling dataanalysis data mining data cleaning deep learning r sql nosql mingodb java c c++ communucation skill team management 3 year linkshttps //github.com/abhijitmanepatiladditional informationskills machine learning data analysis artificial intelligence predictive modeling statistical modeling natural language processing deep learning tensorflow panda scikit learn kera matplotlib python r c c++ sql mysql java mongodb data cleaning data virtualization communication skill team management'],
#  ["abhinav abhisheksenior software developer/data scientistbangalore 8757656959 abhi4navv gmail.com linkedin.com/in/abhinav-abhishek-22459154summary skillsmore 5 year experience software development project implementation skills-out 3-years experience data scientist machine learning deep learning project managementworking experience extensive knowledge python natural language processing team managementlibraries sklearn numpy panda matplotlib nltk sql server data mining data analysismodel buildingplatforms misc anaconda enterprise edition jupyter notebook spyder ide sql machine learningserver management studio visual studio 2017 python ii window xp/w7/w8 deep learningother skill phase software development life-cycle requirement design data pre-processingdevelopment testing release support utilizing multiple development methodology database managementeducation programming skillsbachelor engineering electronics communication 2013 pythonvisvesvaraya technological university bangalorenlp/nltkcertification program data science deep learning.acadgildpandasdiploma .netniit technology limitednumpywork experiencesenior softare developer 12/2017 till date matplotlibxl solution groupsoftware programmer ii 09/2015 09/2017 scikit learnmsi service pvt ltd.kerasproject manager 01/2015 09/2015p puneet co.tensorflowdeveloper 03/2014 08/2014shreshtha informatics solution pvt ltd.sql serverdatabase administrator programmer 08/2013 02/2014ematrix technology p limitedprojectsxl solution groupinstitution popularity analysis-the company wanted get overview feedback given student generalpeople giving insurance cover used nlp find institution ishaving positive sentiment provided proper visualization using plot tohelp concerned team taking decision.claims management system-the system designed assist team approval claim based thecompany 's data collected different type claim made past theircredibility system us machine learning predict class good forapproval reject verify manually claim based credibility.msi service pvt ltd.inventory stock allocation based sale prediction-the application provide report ale projection different verity stone andtiles state u.s. helped inventory team warehouse team tomanage supply model designed using sale data last 5 year differentarea based model tried classify product 3 class high moderate andlow sale classes.technology used- panda numpy pca matplotlib random forest classifier sql server2012.sales projection stone categories-there different type stone used imported different country socompany wanted sale prediction different type stone national wise manageimports accordingly used historical sale data classified type ofstones different category sales.technology used- panda numpy matplotlib z-score random forest classifier sqlserver 2012.accounting-theapplication generate overall daily weekly monthly yearly sale accountingdata accounting team.p puneet co.expenditure management system-the system manage payment 15types beneficiary district generate advice basis paymentwill made bank earlier done manually would consume time andresources developed system make system automated centralized.ro purchase management-developed software ro purchase management state food civil supplycorporation.attendanceand work allocation system-the software manage attendance system allocate work employee theirleads also reporting system keep track work assigned performance ofemployees.the software manage entire functionality medical laboratory like patient registration select test generate receipts.shreshtha informatics solution pvt ltd.medical lab software-the software manage entire functionality medical laboratory like patientregistration select test generate receipts.school managementthe application manage major work related student staff includestudent registration fee attendance management employee salary attendancesystem.ematrix technology p limitedhr management system-created application hr related activity company main module itwas salary bo ...
#  ["aniket kashyapsoftware developer/data scientistbengaluru 9691316944 monu.aniket gmail.com linkedin.com/in/aniket-kashyap-37456ba4/ github.com/aniket130590summary skillsmore 4 year experience software development project project managementimplementation 2+years experience data scientist data analysismachine learning deep learning.working experience extensive data pre-processingknowledge python natural language processing library nlpsklearn numpy panda matplotlib nltk sql server data mining .platforms database managementmisc anaconda enterprise edition jupyter notebook spyder ide sql server model buildingmanagement studio visual studio 2017 python ii window xp/w7/w8other machine learningskills phase software development life-cycle requirement deep learningdesign development testing release support utilizing multiple developmentmethodologies.programming skillswork experiencepythonsoftware engineer 06/2017 till datexl solution group numpysoftware engineer 09/2016 04/2017pandashewlett packard enterprisedeveloper 01/2014 08/2016matplotlibtouch ideaeducation scikit learnbachelor engineering computer science 2013npl/nltkswami vivekananda technical university bhilaicertification program data science deep learning 2014 tensorflowacadgildnit hyderabaddiploma net 2014 kerasnit hyderabadsql serverprojectsxl solution groupunited educators- institution popularity analysis-the company wanted get overview feedback given student andgeneral people giving insurance cover used nlp find thatinstitution positive sentiment provided propervisualization using plot help concerned team taking decision.ml crane- accessory part requirement prediction system-the company many service station across country service crane andit difficult maintain supply part across service center asthey different demand organize supply wanted havepredicted model predict part needed particularregion used provide part region got many datarelated climate industrial us related information using whichwe prepared model tested many ml algorithm founddecision tree random forest similar output decided putdecision tree needed le computation time le computationalresources.technology used- panda numpy pca matplotlib random forestclassifiers sql server 2012.hewlett packard enterprise.vfs global visa approval prediction-one client vfs wanted prediction system would classifyapplications 3 category based chance approval high medium lowbased used either process application concernedcountrys cid:73 ice helpful mainly student work visa theirapproval depends trend mostly got previous data like course detail highest qualification year stay etc build model using builtmodel case got one best accuracy using decision tree sofinalized model.touch idea .my hrwizard project mainly deal providing efficient accuratepayroll service company company ranging single employee tothousands employee use service effective management ofemployee payroll service one main feature project reportgeneration based wide variety base report useful payroll processing maintenance time attendance hr service maintenance insurance andaccess worker compensation etc.this system provides broad range time keeping allow employer toeffectively track employee hour feature offered assist convenientlyorganizing quantifying employee 's work day key feature include jobcosting automated overtime calculation holiday tracking payment onlinetime-card editing daily auto email report etc.taf route management bicycle riding event objective tomanage whole route bicycle riding event different module likeregistration rider well volunteer creation management routemap task assignment tracking rider location showing themap helping assisting rider etc.responsibilitiesguide team member understand requirement allocate thework accordingly.communicate client understand planning project providethem progress report modules.gather complete requirement project userto analyse requirement prepare best suited database structuredesign project.create database table ...
#  ['anirudh anandmachine learning engineeranirudhanand80 gmail.com 8082366408 jammu india anand-anirudh anirudh anandprofilea scrupulous computer science undergraduate coordinated individual seeking entry-level position thefield data science machine learning envision tell insight raw data utilizingvarious technology would assist bringing change way look upon data furthermoreforesee happening using machine learning models.professional experience09/2022 10/2022 machine learning internestartuplabunderstandthe data obtained research team conductcomprehensive data cleaning meticulous eda.build ml model utilizing various technique tools.skillstools python v code jupyter notebook.packages scikit-learn panda numpy seaborn matplotlib.machine learning exploratory data analysis statistical analysis predictive modelling regression classification clustering algorithm regularization.soft skillstime management problem solving leadership teamwork adaptability work ethicsprojectsdiabetes predictionanalyzed performed exponential data analysis national institute diabetes digestive andkidney disease objective dataset diagnostically predict whether patient diabetes based certain diagnostic measurement included dataset.built prediction model based random forest logistic regression knn svm different onset type2 diabetes prediction.uses blood pressure glucose pregnancy various marker predict outcome comparetheir performance metrics.sms spam classifierml model classifies message spam spam.used logistic regression decision tree random forest gave accuracy 96.1 ,94.4 97.5 respectively.education07/2019 07/2023 b.tech computer science engineering jammu india shri mata vaishno devi university reasi j k organisationsa.i circlecollaboratedwith team mate making various ml models.taught provided guidance juniorscoursesmachine learningsimplilearngotto know various machine learning algorithm implementations.developed various machine learning project'],
#  ['ashray rainaashrayraina22 gmail.com 7780995937 ashray raina ashray22profilea meticulous computer science undergraduate organized individual seeking entry-level position field ofdata science machine learning visualize tell insight raw data using various technologieswhich would help bringing change way look upon data also predict happening using themachine learning models.skillstools python v code jupyter notebook.packages scikit-learn numpy panda matplotlib seaborn jupyter notebook.machine learning statistical analysis exploratory data analysis predictive modelling regression classification clustering algorithm regularizationsoft skillsteam management problem solving teamwork leadership confidenceprojectssentiment analysis webapp senttextused python script extract tweet comment data twitter.analyzed performed nlp based tokenization lemmatization vectorization processed data using neattext inmachine understandable language.designed multi-class classification model modeled logistic regression text vectorization pipeline forpredicting sentiment.used simplified python framework streamlit make webapp.diabetes predictionanalyzed performed exponential data analysis national institute diabetes digestive kidneydiseases objective dataset diagnostically predict whether patient diabetes based oncertain diagnostic measurement included dataset.built prediction model based random forest logistic regression knn svm different onset type 2diabetes prediction.uses blood pressure glucose pregnancy various marker predict outcome compare theirperformance metrics.loan predictionworked loan prediction dataset problem clear classification problem need classify whether theloan status yes no.used logistic regression random forest decision tree classifier gave accuracy 82.2 86.3 ,81.7 respectively.education07/2019 07/2023 b.tech computer science katra india shri mata vaishno devi universitycgpa 7.13coursesmachine learning allcourseragotto know various machine learning algorithm mathematical implementation.developed end end machine learning projectsinterestsvideo editing graphic designing cricket football'],
#  ["ramachandran iyeriim ahmedabad alumnus| smp csm itilphone +91 9820463399address nandan prospera a4-301 baner road balewadi pune 411045website http //www.linkedin.com/in/iyer-ramachandran/email ganesh2480 gmail.com19 year experience managing large global client across different vertical building operation creating customersuccess story strong focus deliveryled strategic initiative centered customer experience operational efficiency sla management streamliningprocesses coordination stakeholder like product revenue design support teams.led talent management strategy career framework competency mapping skill gap analysis succession planning retention performance managementexperienced setting operationalizing delivery center right scratchexpertise handling itil operation including incident problem change managementskillsstrategy planning leadershipproduct project managementapplication support sla management continuous service improvementclient relationship managementresource managementvendor managementit infrastructure networksservice jira confluenceexperiencenectarium pvt ltd. june 2021 april 2022directorled business operation 2 diverse domain software development vfx hired managed 150 resource pre-sales delivery product human resource teamssetup new delivery center indore hired 50+ resource project delivery le two month 0.5 million business acquired several round negotiation client hot lead market place using structuredplanning pre sale deliveryset employee performance career pathing process right setting goal tracking kpi 's conducting review anddoing appraisal promotionsautomated process lifecycle sale lead right inception closure within crm portal saving precioustime also available real time status anytime anywherebny mellon technology january 2010 june 2021vice presidentled multiple team across new client onboarding technical operation manager application support saas productmanagement daily operation support100 contract retention client boarded year effective client relationship management upselling cross selling improved version existing product new product offeringstransitioned support process boston pune build 24 7 support team phase-2 setup follow sun model bybuilding team strategic location i.e sydney singapore50+ client boarded around globe helping setup development test prod region enabling support modelsand handling escalationsworking rotational shift handling client query triaging issue installation upgrade service pack migration database refreshes dr testing capacity testing setting vpn tunnelsimplemented itil best practice including continuous service improvement csi incident problem change release stakeholder vendor management.achieved optimal operational efficiency 35 client sla 's met 100 fine-tuned tat 40 overallsubstantial saving span timeachieved 30 reduction year year number incident eliminated repeat issue timely product change bycollaborating product engineering teamsdelivered 99.5 average uptime system throughout year annual saving close 2 million resourcecostsparticipated vendor management activity including requirement gathering feasibility check uat signoff third partyintegration area like client reporting business intelligence bi single sign sso drs firewall securityas business analyst acted bridge technology team business client ensure requirement areunderstood transformed tool help product team wherever feasibleresource planning based business projection tracking utilization ensuring compliance related billing timesheet.published metric related headcount attrition utilization stats quantifiable analysis ensured resourcedemand fulfilment cross-skilling re-skilling talent.won multiple award past decade including yearly outstanding leadership award 2019 andquarterly award client production application supportdeputations boston usa brisbane australiasyntel ltd. november 2007 november 2009project leadproject lead role edw production support processbusiness analyst role onboarding 5 client transaction ...
#  ['himanshu tyagipune maharashtra email indeed indeed.com/r/himanshu-tyagi/1c1abc0800189689 data science professional experience stage data processing insightsdelivery data mining statistical analysis identify insight pattern complex datasets experience insight delivery insurance related vertical competent working artificial neural network know machine learning python efficient developing supervised/unsupervised learning models.willing relocate delhi delhi bengaluru karnataka pune maharashtrawork experiencecapgemini pune maharashtra -march 2017 presentclient -sunlife financials data insight project overview developed churn analysis fraud claim detection real time data/back-office data currently working neural network deep learning prediction system.responsibilities -1. data understanding process formation clients.2 extensive hands-on regression classification techniques.3 building baseline model requirement necessary data preparation.4 parameter tuning process optimal model hyperparametrs.5 ensembling learning method tuned models.6 implemented customer churn analysis models.7 recommended product market-basket analysis technique lead increase insales 17 .8 developed customer churn analysis sytem led growth retention highvalued potential customers.capgemini pune maharashtra -may 2016 february 2017client -sunlife financials group fact project overview mainframe development support project worked insurance vertical.handled claim premium commission processing via batch cycles.responsibilities -1. handling production batch cycle.2 mainframe development jcl cobol db2 ims vsam ca7 etc3 enhancement cobol easytrieve.4 claim processing disbursements.5 unit testing code validation reviews.6 compliance check client inputs.7 automation delivery responsibilities.8.data scientistcapgemini1 data understanding process formation clients.2 extensive hands-on regression classification techniques.3 building baseline model requirement necessary data preparation.4 parameter tuning process optimal model hyperparametrs.5 ensembling learning method tuned models.6 implemented customer churn analysis models.7 recommended product market-basket analysis technique lead increase insales 17 .8 developed customer churn analysis sytem led growth retention high valuedpotential customers.educationbtech electronicsuptu noida uttar pradesh2010 2011assisi convent school noida noida uttar pradesh2008 2009skillsneural network deep learning python machine learning data analysisadditional informationskills strong background python scripting oops concept competent writing sql query strong communication presentation skill relevant delivery experience financial service organization excellent organizational analytical skill'],
#  ['jalpa davedata scientist elegant microweb technology private limitedahmedabad gujarat email indeed indeed.com/r/jalpa-dave/039f38cb1d68c0c6seeking position utilize skill ability industry offer professional growthwhilebeing resourceful innovative flexible.work experiencedata scientistelegant microweb technology private limited ahmedabad gujarat -march 2017 presentahmedabadjob responsibility develop statistical model various predictive method forecasting classification clustering regression analyze large datasets provide strategic direction client business handling client issue related elegantj bi tool plug amp play predictive generating actionable insight client data creating presentation dashboard tomake recommendation improvement scripting using r language well apache spark java predictive algorithm asforecasting classification clustering association mining regression decision tree correlation automating amp integrating predictive algorithm r script plug amp play predictiveanalytics module elegantj bi automating amp integrating predictive algorithm spark script smarten module ofelegantjbi preparing conducting demonstration predictive analytics module bi along withmarketing team.web analysttatvic analytics private limited ahmedabad gujarat -may 2016 december 2016ahmedabadjob responsibility perform research carry new statistical analysis r language handling google bigquery related issue client generating actionable insight client data creating monthly report presentationsand dashboard make recommendation improvement solving client issue related google analytics website application data performing analysis namely forecasting customer lifetime value measuring long-term valueof campaign churn analysis product banner/brand sequence analysis recency frequencymonetary analysis sentiment analysis navigation menu analysis net promoter scoreanalysis market basket analysis tv advertisement analysis site search analysis marketingchannel attribution analysis markov chain analysis related product analysis time seriesdecomposition product demand index analysis scroll depth tracking analysis anomalydetection analysis causal impact analysis working machine learning predictive analytics using r language amp googlepredictionapi blog writing.educationm.techcomputer2016b.e computersaurashtra university2007skillsalgorithms 1 year apache 1 year java 1 year scripting 1 year api le 1year additional informationcore competency strategic thinking expertise data science software r python amp apache spark google analytics amp google bigquery consultant statistical modelling amp analytic ability big data analytics machine learning amp predictive algorithm communication amp project management c /java database web technologies.technical skillsoperating system window unix linux.programming language r python sql c .net visual basic.net java.database m excel m access oracle sql server 2000.mark scriptinghtml asp asp.net core java amp advanced javalanguage/webprogramming.technologiespackages/tools apache spark google analytics google bigquery googleprediction api r studio rattle shiny xlminer weka rapidminer tanagra.theories data mining object oriented analysis amp design managementinformation system data structure amp algorithm advanceddatabase management system operating system systemanalysis design amp unified modelling language softwareengineering .net platform technical writing'],
#  ["kishore ramiyengar lakshmipprasannac 404 gaana reagent channasandra village.bangalore-560098kishor.priya gmail.comexperience summary1 professional 15 year experience python machine learning deep learningdata science big data mobile application data staging testing web applicationdevelopment testing production deployment support insight ibmcloud infrastructure solution finance life general insurance telecom hrmsdatabase payroll domains.2 data science professional experience stage data processing insight delivery.3 understand business use case requirement client convert wellarticulated problem statement explain project teams.4 analyze unorganized data assessing quality cleansing structuring managementreview design accurate scalable prediction algorithms.5 identify relevant data set required develop predictive model solving internal andexternal business problems.6 explore data set identify data transformation data mining need targetedinsurance applications.7 develop algorithm predictive model derive analysis business value datasets classification clustering regression.8 provide mentorship required team member team.9 identify use case help team implement might help organizationbusiness development.10 define develop program data collection modelling reporting theoperational performance.11 responsible budget planning schedule planning resource profiling projectphases.12 lead support various adhoc project needed support organization businessstrategy.skills knowledge areascategory software/ proficiency experience yearstool/technologydata science python algorithm intermediate 4 yearsdata cleansing using machine learningdata mining tensor flowdata modelling pandasdata analysis numpyscikit learnk mean svm 3+ yearsmachine learninglstm tensor flow intermediatelinear logisticregression classification- knn naive bayes.clustering k meanssupervised learning unsupervised learningover fitting parametric andnon-parametricmodellingdeep learningcnn rnnoperating system window 98 2000 server expert 14+ yearsxp window 8,10 android iosoffice tool m office application expert 14+yearslanguages c java vb python intermediate 4+ yearspl/sql sql intermediate 2+ yearsverification tool alm quality centre working 5+ years8.0,8.2 knowledgeselenium 2.0 web driver java qtp 8.0,8.2 uft 12.5 achievement recognised contribution developing automated chatbot concept forclaims part cost saving project european insurance giant tryg received highest level customer appreciation successfully delivering regularcontribution isas insurance work save pension trust master trust project product themarket legal general client within tc demonstrated excellent working skill performed project critical andreceived appreciation customer legal general united kingdom awarded best performance form spot award fidelity 2007-2008. recognized one best associate onsite client coordination.professional experience summarycurrently associated delivery project executive ibm india pvt limited since april 2017previously associated tata consultancy service india ltd jun 2008 march 2017 associate consultant april 2012 march 2017 analyst jun 008 april 2012previously associated test engineer fidelity business service india pvt ltd feb 2006 may2008previously associated software engineer verizon data service india chennai may 2005 -feb 2006previously associated technical support engineer dell international service pvt ltd nov2002 apr 2005project summary1 ibm india pvt limitedclient apac client 711 nesa hannon iag insurance project title name cloud solution watson data analysisproject duration april 2017 till date.project location bangalore.team size 15project description project rebuild existing platform infrastructure legacy nature necloud based big data based platform enable cost efficiency using big datatechnology implementations.classification operational data csv format unorganized data using liner regression kmeans naive bayes algorithm also coming linear regression logisticregression model readi ...
#  ['mohnish chaudharydecision scientist mu sigmabangalore urban karnataka email indeed indeed.com/r/mohnish-chaudhary/1cec1af1dac07b17data scientist three year experience predictive modelling data processing datamining algorithm tosolve challenging business problem strong background computer programming language knowledge ofvarious type machine learning natural language processing techniques.willing relocate pune maharashtra hyderabad telangana bangalore urban karnatakawork experiencedecision scientistmu sigma bengaluru karnataka -2015 presentprojectstext analytics mufusion mu sigma developed text analysis engine used fortune 500 client text analysis enginedeveloped python supportingenglish japanese text leverage sentiment analysis theme identification categorisation named entity recognition clustering word co-occurrence module generate insight decision making.data quality value assessment u based asset management company designed developed comprehensive versatile data quality value assessmentmodule u based assetmanagement company module developed jupyter notebook python kernel broughtdown time dataquality assessment 500 million row data 60hours 50mins wascompatible different type datasets transaction health-care geolocation etc andgenerated 2 report allowed flexibility user tailor theconditions check according business ass quality data.the energy insight app top energy firm developed one stop application hosted predix platform fortune 100 energy firm whichhelps businessdevelopment manager throughout customer engagement journey leveraging dataavailable multiple source richer conversation customer help intaking better decision achieve energy efficiency goal generating realistic project roadmap using mixed integer optimisation linearprogramming handled entirebackend application using python.finding donor udacity ml basic nano-degree project applied evaluated supervised learning technique like gaussian naivebayes svm random forest data collected u.s. census help charityml fictitiouscharity organisation identify people likely donate totheir cause afterwards optimised random forest model presented solutionto charityml github customer segment udacity ml basic nano-degree project analysed dataset containing data various customer annual spendingamounts diverse productcategories internal structure using pca gaussian mixture model clustering algorithmto best describe variation different type customer wholesale distributorinteracts provide insight best structure theirdelivery service meet need customer github data scientistmu sigma -july 2015 june 2018educationbe information technologyuniversity pune pune maharashtra2015skillsnlp ml deep learning predictive modellingadditional informationtechnical skill certification amp awardspython nlp machine learningdecision scientistdata mining linux scala mu sigma university jun 2017spark git ibm docloud machine leaning nano-degreeudacity may 2018libraries data miningnptel may 2018nltk sk-learn numpyimpact award mu sigma apr 2018mllib panda gensimspot award mu sigma jan 2018spacy pattern pulp'],
#  ['pawan kumar apawan9964 gmail.com 45 8th cross road ramamurthy nagar bengaluru-560016 +91-8008636324career objective career objective succeed environment growth excellence earn job whichprovides job satisfaction self-development help achieve personal well organizationgoals.education bachelor science btech computer science engineering ap iiit kadapa ap.gpa 8.07/10may 2018puc ap iiit kadapa ap.gpa 7.10/10may 201410th class s puram nagalapuram chittoor ap.gpa 9.7/10may 2012technical skill operating system window 7/8.1/10 linux.programming language python r c java c++.knowledge technology completed data science master acadgild data analysis python data visualization python machine learning python linear regression logistic regression knn k meansclustering pca decision tree random forest svm bayesian recommender system deep learning tensorflow kera depth knowledge probability statistic image processing opencv python c++ knowledge html cs jsp jdbc mysql connection m excel m word .projects ml problem sentiment analysisalgorithms naive bayes linear classifier tree classifier simple deeplearningtechnologies sklearn nltk request bs4data http //www.yelp.com reviewsgithub http //github.com/pawankumara/sentiment-analysis-.gitml problem classification problemalgorithms convolutional neural networktechnologies kera panda numpydata http //drive.google.com/openid=18btphi6zusrzqcwh0nje2kpv6nehb8eqgithub http //github.com/pawankumara/classification.gittitle third eyelanguage python open cv description third eye automatic attendance system student byrecognizing face use application college school alsocompanies implemented using opencv python.title cloud computing security single multi clouds.team size 1description risk facing single cloud problem tomove single multi cloud implementation multi cloud submitted asinternship project.title automated vehicle counting system based blob analysis fortraffic surveillanceteam size 1description project real-time detection tracking vehicle countingsystem automatically submitted final project degree.strengths excellent coding skill good conceptual analytical logical skill computer/technology flexible/adaptable problem-solving decision-making capable working hard complete workdeclaration hereby certify detail mentioned true best myknowledge belief pawan kumar'],
#  ['prikshit sharmajammu india prikshitsharma8024 gmail.com7780992150 www.linkedin.com/in/prikshit7766https //github.com/prikshit7766profileskilled machine learning developing ml model posse diverse experience cleaning analyzing data enhancing existing model fully procient python .educationb tech shri mata vaishno devi university 07/2019 presentelectronics communication engineering ece katra indiasenior secondary education army public school bd bari 2019percentage 85.6 bari brahmana jammu kashmirsecondary education army public school bd bar 2017cgpa 9.8 bari brahmana jammu kashmirskillstools v code pycharm postmanprogramming language pythondatabase mysql mongodbmachine learning statistical analysis exploratory data analysis feature engineering regression classicationand clustering algorithmsprofessional experienceproject intern 07/2022 08/2022internship project rp-126 `` setting high-end computing ai deeplearning lab `` smvdu dr. baijnath kaushik .worked image dataset image classication medical domain.application various cnn architecture .projectspython projectyoutube scraper project using python-flask youtube api snowlake mongodb.deployed project local serverinputyoutube channel link number videosoutput -youtube umbnail uploaded mogodb base64 format.all information regarding channel individual video uploaded snowlake.videos rst download local system uploaded google drive automatically using driveapi v3movie recommender systemin machine learning project build recommendation system suggests movie user based onhis/her preferences.datasets imdb 5000 movie dataset e movie dataset list movie 2018-2021 wikipediae movie recommended based similarity scoressome feature extracted fetched using api tmdbmodel deployment using streamlitair pressure system failure scania trucksis machine learning project come classication .e main task predict failure minimize costsbased sensor readingscreated training pipeline batch prediction pipeline .used ci/ct/cd pipeline used github action docker airlow awsnlpifydeveloped sophisticated ai platform extract various nlp feature including sentiment analysis namedentity recognition text summarization app review data.performed extensive data preprocessing using technique tokenization lemmatization vectorization totransform raw data machinereadable format.created binary classication model using logistic regression text vectorization pipeline predictsentiment deployed platform user-friendly web app using streamlit framework.certificatessql data science programming everybody getting started withpython introduction html5machine learning foundation case studymachine learning regressionapproachsoft skillstime management leadership teamwork analytical inkinghobbiesvideo editing'],
#  ['priyanka srivastavadata scientistdata science enthusiastpriyankasrvstv16 gmail.com 8948669980sobha dream acer apt . panathur road 560087 banglore linkedin.com/in/priyanka-srivastava-3b29447bindiagithub.com/spriyabhi16education skillspg certication data science mlpython3 machine learning ai pyspark numpyacadgild institute data science07/2018 12/2018 panda scikit-learnb.tech information technologybabu banarasi da northern indian institutepersonal projectsof technology lucknow08/2012 08/2016 lucknow classication problemthis project identify image person certain number ofimages two person using convolutional neural networkalgorithm technology kera panda numpywork experiencehuman activity recognitiondata internusing machine learning project use machine learning tozenapt solution private limited recognise various activity taking activity recognition data set.the dataset includes sensor reading 30 dierent individual and01/2019 present bangalorethe type activity recorded data extractedzenapt building solution complicated problem related data kaggle classify various activity algorithm logisticinformation automate optimize complex data analytics ai regression kneighborsclassier randomforestclassierbased systems.achievements/tasksthe intelligent bank developed designed ai enabledadvanced banking system completely redene algorithmsbanks work transform customerexperiences machine learning pythonextract text image module using ocr.deep learning tensorow kera pandasjson parser.depth knowledge probability statisticscontact sudhanshu kumar 9176072251regression linear logistic data internzenapt solution private limited decision tree random forest10/2018 12/2018 bangaloreknn bayesian k-meanszenapt building solution complicated problem related data information automate optimize complex data analytics aibased system neural network cnnachievements/taskshelmetdetection tensorflow objectdetectionlanguagescontact sudhanshu kumar 9176072251english hindipython developerfull professional prociency native bilingual prociencyuttrakhand trektrip10/2016 12/2017 gurgaonuttrakhand trektrip online platform help trekker planinterestsand execute trekking trip uttrakhand regionachievements/taskspython developer developed maintained module tovollyball badminton travelingsupport internet based travel platform.contact santosh joshi 9910664917'],
#  ["rakshit khajuriamachine learning engineera 2+ year experienced machine learning enthusiast design build deploy enterprise level machine learning solutions.rakshitraina1234 gmail.com 9149556155jammu india linkedin.com/in/rakshit-khajuria-3627781b8github.com/ryzxxl stackoverow.com/users/14526226/rakshit-khajuriainstagram.com/_x.rakshit_swork experience skillsmachine learning tarineepython c/c++ data structure mathematicsineuron.ai11/2020 08/2021 bangalore statistic machine learning data analysisneuron product-driven organization working state art project forour domestic international client data visualization heroku html+css3 flaskachievements/tasksgot learn various thing beginning like python api streamlit nlp deep learningdeployment aws azure gcp heroku.got know dierent database various module instatistics machine learning algorithm mathematicalimplementation numpy mathematics heroku html+css3personal projectspandas.developed end end machine learning projects.content-based recommender system movie website 05/2022 06/2022 deep learning computer vision nlpanalyzed perform eda tmdb dataset made full end-to-endtraineemachine learning model using bag word nlp.ineuron.ai streamlit used frontend easy making websiteenabled user recommended movie based 50+ data point 10/2021 present bangaloreneuron product-driven organization working state art project forindia 's suicide predictor model using djangoour domestic international client 07/2021 08/2021 achievements/tasksa simple machine learning model converted webapp useslearning advance nlp deep-learning overview tensorflow year input give total number suicide happened orpytorch neural network cnn overview happening year deployment model performance tuning analyzed performed eda given dataset.made end-to-end django webapp using html+css3.used linear regression numpy panda matplotlib django seaborndata science internlets grow diabetes prediction using flask 02/2022 03/2022 analyzed performed exponential data analysis national institute08/2021 09/2021 uttar pardeshof diabetes digestive kidney diseasesachievements/tasks objective dataset diagnostically predict whether aworked exploratory data analysis dataset terrorism patient diabetes based certain diagnostic measurement includediris flower classication machine learning project dataset.built prediction model based random forest logistic regression knn converted data actionable insight predicting andand svm dierent onset type 2 diabetes prediction.modeling future outcomes.uses blood pressure glucose pregnancy various marker toused dierent library framework like panda numpy plotly predict outcome compare performance metrics.seabom matplotlib plotly sklearn svm logistic knn.languageseducationpython c/c++electronics communication full professional prociency limited working prociencyengineering smvd university reasi j k 07/2019 present jammuwork interestscollaborating teammate a.i circle wemake project machine learning deep learning footballdiscussions regarding theeld machine learningmathematics sketchingwith python"],
#  ['rakshit khajuriamachine learning engineertalab tillo gole gujral 180002 jammu india rakshitraina1234 gmail.com 914955615514 aug 2001 http //www.linkedin.com/in/rakshit-khajuria-3627781b8/ http //github.com/ryzxxl9149556155summaryskilled developing implementing data-driven solution real-world problem utilizing range tool andtechniques extract valuable insight large complex data set posse diverse experience cleaningand analyzing data enhancing existing model continuously seeking enhance skill broaden myknowledge dynamic eld data science.skillstools python git github jupyter notebook anaconda v codepackages scikit-learn numpy panda matplotlib nltk tensorflow flask streamlit spacy text blob vader.machine learning supervised learning unsupervised learning clustering algorithm decision tree randomforests neural networks.nlp sentiment analysis text classication named entity recognition word embedding topic modeling deeplearning nlp model e.g . transformer bert lstms soft skillstime management problem-solving leadership teamwork presentation skill condenceprofessional experienceresearch intern jul 2022 presentjammu indiadeveloped implemented sentiment analysis model extract classifyemotional context scraped reddit data suicidal discussions.utilized advanced technique including unsupervised pre-trained model e.g vader textblob clustering algorithm e.g kmeans dbscan accurately analyze andinterpret sentiment.enhanced model performance use deep learning technique aslstm bilstm etc ne-tuning pre-trained word embeddings e.g glove .improved model accuracy applying different bert models.machine learning tarinee nov 2020 aug 2021became procient wide range machine learning algorithm including bangalore indiaunderlying mathematical principles.hands-on experience end-to-end machine learning project development dataacquisition model deployment.demonstrated expertise using cloud platform heroku streamlit aws efciently deploy machine learning model solutions.rakshitraina1234 gmail.com 1 2projectsmulti purpose nlp application nlpify nov 2022 nov 2022developed sophisticated ai platform extract various nlp feature includingsentiment analysis named entity recognition text summarization appreview data.performed extensive data preprocessing using technique tokenization lemmatization vectorization transform raw data machine-readableformat.createda multi-class classication model using logistic regression textvectorization pipeline predict sentiment deployed platform user-friendly web app using streamlit framework.political spectrum detection medium news using deep-learning shap oct 2022 oct 2022pythonbuilta political spectrum detection deep learning sequential model.performed nlp based tokenization lemmatization vectorization processed datausing neattext machine understandable language.simplied code library shap built theoretic approach explain output ofsequential deep learning model.diabetes prediction using flask dec 2021 jan 2022conducted in-depth data analysis national institute diabetes digestiveand kidney disease datasetbuilt multiple machine learning model including random forest logistic regression knn svm prediction various onset type 2 diabetescreated full-stack application using flask deployed heroku publicaccess http //diabetes-prediction-app02.herokuapp.com/certificatesibm data science specialization machine learning deep learning traineeineuron.aimathematics machine learningdata sciencestatistics foundation linkedinmachine learning pythoneducationelectronics communication engineering smvd university reasi j k jul 2019 jul 2023jammu indiaorganisationsa.i circleactivelyparticipated a.i circle collaborating team member machine learning project mentoringjunior member machine learning potential applicationsinterestscoding football sketching machine learning deep learning mathematicsrakshitraina1234 gmail.com 2 2'],
#  ["w g u p jammu dob 9-jan-2001 +91 9797402957 swayamgupta74 gmail.com in/swa yam-gupta-1ba7971b2 swayamgupta 74educationcourse institute year passing resultbachelors technology shri mata vaishno devi university 2023 7.9 cgpa12th standard delhi public school jammu 2019 83 10th standard delhi public school jammu 2017 10 cgpascholastic achievementsscored three semester scholarship smvdu katrasecured 91.85 percentile jee mainprojectsface recognition attendance system using pythonpersonal project oct 2021 present module used opencv face_recognitionfood ordering apppersonal project jun 2021 aug 2021 worked frontend databasetechnologies used html cs java script php mysqlnlp data pre-processingpersonal project jun 2021 worked movie review data collection movie review imdb.com website.preprocessed data used nlp task.modules used kera numpy.skillsprogramming language python sql javamodules panda numpy matplotlibweb development html csstools git githubplatform window linuxadditional detailsprofessional developmentfront end web development ultimate course udemy python class inheritance coursera python function file dictionary coursera python basic coursera programming everybody coursera workshop training attendedadvanced excel workshop conducted microsoft certified trainer founder ceo j academyartificial intelligence workshop iit bombay'svolunteering vikalp student 's initiative july 2019-present taught student various subject even covid time via online platformsorganized various development activity studentsconvinced near people village send kid take advantage initiative education important.organized event donate food stationary clothes etc needy"]]

# %%
df["clean_all"]=pd.DataFrame(cv_)

# %% [markdown]
# # Recomendation Function

# %%
df.head(1)
# Out:
#    Unnamed: 0            name                       email mobile_number  \
# 0           0  Sukanya Jangra  Jangrasukanya066@gmail.com           NaN
#
#                                               skills degree  no_of_pages  \
# 0  ['Data entry', 'Microsoft excel', 'Word', 'Htm...   None            1
#
#                                            file_path  \
# 0  cv_to_df/3bdfa685-56f1-4f83-866c-dbb20be51048.pdf
#
#                                                  All  \
# 0  Sukanya JangraBhiwani, HaryanaJangrasukanya066...
#
#                                            clean_all
# 0  sukanya jangrabhiwani haryanajangrasukanya066 ...

# %%
def get_recommendation(top, df_all, scores):
    recommendation = pd.DataFrame(columns = ['name', 'degree',"email",'Unnamed: 0','mobile_number','skills','no_of_pages','score'])
    count = 0
    for i in top:
#         recommendation.at[count, 'ApplicantID'] = u
        
        recommendation.at[count, 'name'] = df['name'][i]
        recommendation.at[count, 'degree'] = df['degree'][i]
        recommendation.at[count, 'email'] = df['email'][i]
        recommendation.at[count, 'Unnamed: 0'] = df.index[i]
        recommendation.at[count, 'mobile_number'] = df['mobile_number'][i]
        recommendation.at[count, 'skills'] = df['skills'][i]
        recommendation.at[count, 'no_of_pages'] = df['no_of_pages'][i]
        recommendation.at[count, 'score'] =  scores[count]
        count += 1
    return recommendation

# %% [markdown]
# # cosine_similarity + TfidfVectorizer function

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer


def TFIDF(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # TF-IDF Scraped data
    tfidf_jobid = tfidf_vectorizer.fit_transform(scraped_data)

    # TF-IDF CV
    user_tfidf = tfidf_vectorizer.transform(cv)

    # Using cosine_similarity on (Scraped data) & (CV)
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)

    output2 = list(cos_similarity_tfidf)
    return output2

# %%
output2 = TFIDF(df["clean_all"],jd_df['jd'])

# %%
output2
# Out:
# [array([[0.04568556]]),
#  array([[0.1143695]]),
#  array([[0.16075353]]),
#  array([[0.14300357]]),
#  array([[0.15321865]]),
#  array([[0.06769716]]),
#  array([[0.06834925]]),
#  array([[0.08622348]]),
#  array([[0.17343765]]),
#  array([[0.12146198]]),
#  array([[0.15960294]]),
#  array([[0.08172688]]),
#  array([[0.07650771]]),
#  array([[0.10592518]]),
#  array([[0.07856661]]),
#  array([[0.09510244]]),
#  array([[0.1168029]]),
#  array([[0.05733861]])]

# %%
top = sorted(range(len(output2)), key=lambda i: output2[i], reverse=True)[:100]
list_scores = [output2[i][0][0] for i in top]
TF=get_recommendation(top,df, list_scores)
TF
# Out:
#                    name                                             degree  \
# 0        Himanshu Tyagi                           ['BTech in Electronics']
# 1     Abhijit Manepatil  ['Master of Engineering', 'Master in Computer ...
# 2    Kishore Ramiyengar                 ['Bachelor of Technology (Civil)']
# 3        Aniket Kashyap  ['Bachelor of Engineering, Computer Science  n...
# 4      Abhinav Abhishek                                               None
# 5            Jalpa Dave                     ['B.E. in Computer', 'M.Tech']
# 6      Rakshit Khajuria  ['Electronics and Communication, Engineering S...
# 7           Abhay Kumar  ['e-commerce', 'Bachelor of Engineering,Comput...
# 8       Prikshit Sharma      ['B Tech, Shri Mata Vaishno Devi University']
# 9      Rakshit Khajuria  ['Electronics and Communication nEngineering S...
# 10    Ramachandran Iyer                          ['Bachelors of Commerce']
# 11    Mohnish Chaudhary                   ['BE in Information Technology']
# 12  Priyanka Srivastava  ['PG certication in Data Science & MLnAcadgild...
# 13        Pawan Kumar A  ['Bachelor of Science (Btech) in Computer Scie...
# 14         ASHRAY RAINA                                         ['B.tech']
# 15        Anirudh Anand                                               None
# 16                  S W                        ['Bachelors of Technology']
# 17       Sukanya Jangra                                               None
#
#                            email Unnamed: 0 mobile_number  \
# 0                            NaN          8    0800189689
# 1                            NaN          2           NaN
# 2         kishor.priya@gmail.com         10      007-2008
# 3          monu.aniket@gmail.com          4    9691316944
# 4            abhi4navv@gmail.com          3    8757656959
# 5                            NaN          9           NaN
# 6     rakshitraina1234@gmail.com         16    9149556155
# 7        abhayownsthis@gmail.com          1       9978045
# 8   prikshitsharma8024@gmail.com         13    7780992150
# 9     rakshitraina1234@gmail.com         15    9149556155
# 10          Ganesh2480@gmail.com          7    9820463399
# 11                           NaN         11           NaN
# 12    priyankasrvstv16@gmail.com         14    8948669980
# 13           pawan9964@gmail.com         12    8008636324
# 14       ashrayraina22@gmail.com          6    7780995937
# 15      anirudhanand80@gmail.com          5    8082366408
# 16       swayamgupta74@gmail.com         17    9797402957
# 17    Jangrasukanya066@gmail.com          0           NaN
#
#                                                skills no_of_pages     score
# 0   ['Electronics', 'Sales', 'Analytical', 'Email'...           2  0.173438
# 1   ['Marketing', 'R', 'Mining', 'Email', 'Keras',...           3  0.160754
# 2   ['Technical', 'Analyze', 'Sales', 'Finance', '...           9  0.159603
# 3   ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...           3  0.153219
# 4   ['Electronics', 'Spyder', 'Sales', 'Mining', '...           3  0.143004
# 5   ['Technical', 'Analyze', 'Marketing', 'R', 'Em...           3  0.121462
# 6   ['Electronics', 'Analyze', 'Textblob', 'Coding...           2  0.116803
# 7   ['Technical', 'R', 'Analytical', 'Keras', 'Ui'...           4  0.114369
# 8   ['Electronics', 'Analytical', 'Sql', 'Programm...           2  0.105925
# 9   ['Electronics', 'Seaborn', 'Tensorflow', 'Metr...           1  0.095102
# 10  ['Technical', 'Crm', 'Itil', 'Sales', 'Project...           2  0.086223
# 11  ['Technical', 'Gensim', 'Email', 'Mining', 'He...           3  0.081727
# 12  ['Pandas', 'Analytics', 'System', 'Python', 'J...           1  0.078567
# 13  ['Technical', 'R', 'Analytical', 'Keras', 'Sec...           2  0.076508
# 14  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...           1  0.068349
# 15  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...           2  0.067697
# 16  ['Keras', 'Sql', 'Database', 'Programming', 'L...           1  0.057339
# 17  ['Data entry', 'Microsoft excel', 'Word', 'Htm...           1  0.045686

# %%
df
# Out:
#     Unnamed: 0                 name                         email  \
# 0            0       Sukanya Jangra    Jangrasukanya066@gmail.com
# 1            1          Abhay Kumar       abhayownsthis@gmail.com
# 2            2    Abhijit Manepatil                           NaN
# 3            3     Abhinav Abhishek           abhi4navv@gmail.com
# 4            4       Aniket Kashyap         monu.aniket@gmail.com
# 5            5        Anirudh Anand      anirudhanand80@gmail.com
# 6            6         ASHRAY RAINA       ashrayraina22@gmail.com
# 7            7    Ramachandran Iyer          Ganesh2480@gmail.com
# 8            8       Himanshu Tyagi                           NaN
# 9            9           Jalpa Dave                           NaN
# 10          10   Kishore Ramiyengar        kishor.priya@gmail.com
# 11          11    Mohnish Chaudhary                           NaN
# 12          12        Pawan Kumar A           pawan9964@gmail.com
# 13          13      Prikshit Sharma  prikshitsharma8024@gmail.com
# 14          14  Priyanka Srivastava    priyankasrvstv16@gmail.com
# 15          15     Rakshit Khajuria    rakshitraina1234@gmail.com
# 16          16     Rakshit Khajuria    rakshitraina1234@gmail.com
# 17          17                  S W       swayamgupta74@gmail.com
#
#    mobile_number                                             skills  \
# 0            NaN  ['Data entry', 'Microsoft excel', 'Word', 'Htm...
# 1        9978045  ['Technical', 'R', 'Analytical', 'Keras', 'Ui'...
# 2            NaN  ['Marketing', 'R', 'Mining', 'Email', 'Keras',...
# 3     8757656959  ['Electronics', 'Spyder', 'Sales', 'Mining', '...
# 4     9691316944  ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...
# 5     8082366408  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...
# 6     7780995937  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...
# 7     9820463399  ['Technical', 'Crm', 'Itil', 'Sales', 'Project...
# 8     0800189689  ['Electronics', 'Sales', 'Analytical', 'Email'...
# 9            NaN  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...
# 10      007-2008  ['Technical', 'Analyze', 'Sales', 'Finance', '...
# 11           NaN  ['Technical', 'Gensim', 'Email', 'Mining', 'He...
# 12    8008636324  ['Technical', 'R', 'Analytical', 'Keras', 'Sec...
# 13    7780992150  ['Electronics', 'Analytical', 'Sql', 'Programm...
# 14    8948669980  ['Pandas', 'Analytics', 'System', 'Python', 'J...
# 15    9149556155  ['Electronics', 'Seaborn', 'Tensorflow', 'Metr...
# 16    9149556155  ['Electronics', 'Analyze', 'Textblob', 'Coding...
# 17    9797402957  ['Keras', 'Sql', 'Database', 'Programming', 'L...
#
#                                                degree  no_of_pages  \
# 0                                                None            1
# 1   ['e-commerce', 'Bachelor of Engineering,Comput...            4
# 2   ['Master of Engineering', 'Master in Computer ...            3
# 3                                                None            3
# 4   ['Bachelor of Engineering, Computer Science  n...            3
# 5                                                None            2
# 6                                          ['B.tech']            1
# 7                           ['Bachelors of Commerce']            2
# 8                            ['BTech in Electronics']            2
# 9                      ['B.E. in Computer', 'M.Tech']            3
# 10                 ['Bachelor of Technology (Civil)']            9
# 11                   ['BE in Information Technology']            3
# 12  ['Bachelor of Science (Btech) in Computer Scie...            2
# 13      ['B Tech, Shri Mata Vaishno Devi University']            2
# 14  ['PG certication in Data Science & MLnAcadgild...            1
# 15  ['Electronics and Communication nEngineering S...            1
# 16  ['Electronics and Communication, Engineering S...            2
# 17                        ['Bachelors of Technology']            1
#
#                                             file_path  \
# 0   cv_to_df/3bdfa685-56f1-4f83-866c-dbb20be51048.pdf
# 1   cv_to_df/abhay_kumar_visualcv_resume_with_GTC.pdf
# 2                      cv_to_df/Abhijit-Manepatil.pdf
# 3   cv_to_df/Abhinav_Abhishek_visualcv_resume (1).pdf
# 4                              cv_to_df/Aniket_cv.pdf
# 5                   cv_to_df/Anirudh_Anand_Resume.pdf
# 6   cv_to_df/ASHRAY_RAINA_Resume_13-02-2023-19-28-...
# 7   cv_to_df/fe826f24-8900-4317-959f-cb4689540997.pdf
# 8                         cv_to_df/Himanshu-Tyagi.pdf
# 9                             cv_to_df/Jalpa-Dave.pdf
# 10               cv_to_df/Kishore_Ramiyengar_L_CV.pdf
# 11                     cv_to_df/Mohnish-Chaudhary.pdf
# 12       cv_to_df/Pawan_DataScience_Resume (copy).pdf
# 13                                  cv_to_df/prik.pdf
# 14       cv_to_df/Priyanka_s Resume DataScientist.pdf
# 15                     cv_to_df/Rakshit's Resume2.pdf
# 16               cv_to_df/rakshit_khajuria_resume.pdf
# 17               cv_to_df/Swayam_Gupta_resume (1).pdf
#
#                                                   All  \
# 0   Sukanya JangraBhiwani, HaryanaJangrasukanya066...
# 1   Abhay KumarLead Data Scientist - Computer Visi...
# 2   Abhijit ManepatilData Scientist with Master in...
# 3   Abhinav AbhishekSenior Software Developer/Data...
# 4   Aniket KashyapSoftware Developer/Data Scientis...
# 5   Anirudh AnandMachine Learning Engineeranirudha...
# 6   ASHRAY RAINAashrayraina22@gmail.com 7780995937...
# 7   Ramachandran IyerIIM Ahmedabad Alumnus| SMP | ...
# 8   Himanshu TyagiPune, Maharashtra - Email me on ...
# 9   Jalpa DaveData Scientist - Elegant Microweb Te...
# 10  Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 11  Mohnish ChaudharyDECISION SCIENTIST - MU SIGMA...
# 12  Pawan Kumar Apawan9964@gmail.com#45, 8th cross...
# 13  Prikshit SharmaJammu,India prikshitsharma8024@...
# 14  Priyanka SrivastavaData ScientistData Science ...
# 15  Rakshit KhajuriaMachine Learning EngineerA 2+ ...
# 16  Rakshit KhajuriaMachine Learning EngineerTalab...
# 17  S W A Y A M G U P T A Jammu DOB: 9-Jan-2001 +9...
#
#                                             clean_all
# 0   sukanya jangrabhiwani haryanajangrasukanya066 ...
# 1   abhay kumarlead data scientist computer vision...
# 2   abhijit manepatildata scientist master compute...
# 3   abhinav abhisheksenior software developer/data...
# 4   aniket kashyapsoftware developer/data scientis...
# 5   anirudh anandmachine learning engineeranirudha...
# 6   ashray rainaashrayraina22 gmail.com 7780995937...
# 7   ramachandran iyeriim ahmedabad alumnus| smp cs...
# 8   himanshu tyagipune maharashtra email indeed in...
# 9   jalpa davedata scientist elegant microweb tech...
# 10  kishore ramiyengar lakshmipprasannac 404 gaana...
# 11  mohnish chaudharydecision scientist mu sigmaba...
# 12  pawan kumar apawan9964 gmail.com 45 8th cross ...
# 13  prikshit sharmajammu india prikshitsharma8024 ...
# 14  priyanka srivastavadata scientistdata science ...
# 15  rakshit khajuriamachine learning engineera 2+ ...
# 16  rakshit khajuriamachine learning engineertalab...
# 17  w g u p jammu dob 9-jan-2001 +91 9797402957 sw...

# %% [markdown]
# # cosine_similarity + CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(df["clean_all"]) #converting job data into vectors using count vectorizers
count_jobid
# Out:
# <18x2933 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5018 stored elements in Compressed Sparse Row format>

# %%
user_count = count_vectorizer.transform(jd_df['jd'])#converting user cv data into vectors using count vectorizers
user_count
# Out:
# <1x2933 sparse matrix of type '<class 'numpy.int64'>'
# 	with 45 stored elements in Compressed Sparse Row format>

# %%
print(user_count)
# Out:
#   (0, 439)	1
#   (0, 474)	1
#   (0, 493)	2
#   (0, 529)	1
#   (0, 697)	1
#   (0, 754)	1
#   (0, 812)	7
#   (0, 817)	1
#   (0, 893)	1
#   (0, 934)	1
#   (0, 1007)	1
#   (0, 1054)	7
#   (0, 1231)	2
#   (0, 1574)	2
#   (0, 1750)	1
#   (0, 1768)	1
#   (0, 1793)	1
#   (0, 1829)	1
#   (0, 1903)	1
#   (0, 1991)	1
#   (0, 2079)	1
#   (0, 2110)	1
#   (0, 2146)	2
#   (0, 2173)	1
#   (0, 2187)	1
#   (0, 2237)	1
#   (0, 2238)	1
#   (0, 2252)	1
#   (0, 2280)	1
#   (0, 2374)	1
#   (0, 2377)	1
#   (0, 2411)	2
#   (0, 2457)	1
#   (0, 2469)	1
#   (0, 2501)	1
#   (0, 2602)	1
#   (0, 2626)	1
#   (0, 2674)	1
#   (0, 2683)	1
#   (0, 2694)	1
#   (0, 2764)	1
#   (0, 2795)	1
#   (0, 2865)	1
#   (0, 2908)	2
#   (0, 2914)	1

# %%
cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
output3 = list(cos_similarity_countv)
#output3

# %%
output3
# Out:
# [array([[0.13197176]]),
#  array([[0.2605031]]),
#  array([[0.35294448]]),
#  array([[0.24849157]]),
#  array([[0.25715623]]),
#  array([[0.20724366]]),
#  array([[0.19682149]]),
#  array([[0.1398248]]),
#  array([[0.36661899]]),
#  array([[0.1749611]]),
#  array([[0.2923324]]),
#  array([[0.26077853]]),
#  array([[0.17305804]]),
#  array([[0.22971696]]),
#  array([[0.2469171]]),
#  array([[0.19962292]]),
#  array([[0.21822742]]),
#  array([[0.15192354]])]

# %%
top = sorted(range(len(output3)), key=lambda i: output3[i], reverse=True)[:100]
list_scores = [output3[i][0][0] for i in top]
cv=get_recommendation(top, df, list_scores)
cv
# Out:
#                    name                                             degree  \
# 0        Himanshu Tyagi                           ['BTech in Electronics']
# 1     Abhijit Manepatil  ['Master of Engineering', 'Master in Computer ...
# 2    Kishore Ramiyengar                 ['Bachelor of Technology (Civil)']
# 3     Mohnish Chaudhary                   ['BE in Information Technology']
# 4           Abhay Kumar  ['e-commerce', 'Bachelor of Engineering,Comput...
# 5        Aniket Kashyap  ['Bachelor of Engineering, Computer Science  n...
# 6      Abhinav Abhishek                                               None
# 7   Priyanka Srivastava  ['PG certication in Data Science & MLnAcadgild...
# 8       Prikshit Sharma      ['B Tech, Shri Mata Vaishno Devi University']
# 9      Rakshit Khajuria  ['Electronics and Communication, Engineering S...
# 10        Anirudh Anand                                               None
# 11     Rakshit Khajuria  ['Electronics and Communication nEngineering S...
# 12         ASHRAY RAINA                                         ['B.tech']
# 13           Jalpa Dave                     ['B.E. in Computer', 'M.Tech']
# 14        Pawan Kumar A  ['Bachelor of Science (Btech) in Computer Scie...
# 15                  S W                        ['Bachelors of Technology']
# 16    Ramachandran Iyer                          ['Bachelors of Commerce']
# 17       Sukanya Jangra                                               None
#
#                            email Unnamed: 0 mobile_number  \
# 0                            NaN          8    0800189689
# 1                            NaN          2           NaN
# 2         kishor.priya@gmail.com         10      007-2008
# 3                            NaN         11           NaN
# 4        abhayownsthis@gmail.com          1       9978045
# 5          monu.aniket@gmail.com          4    9691316944
# 6            abhi4navv@gmail.com          3    8757656959
# 7     priyankasrvstv16@gmail.com         14    8948669980
# 8   prikshitsharma8024@gmail.com         13    7780992150
# 9     rakshitraina1234@gmail.com         16    9149556155
# 10      anirudhanand80@gmail.com          5    8082366408
# 11    rakshitraina1234@gmail.com         15    9149556155
# 12       ashrayraina22@gmail.com          6    7780995937
# 13                           NaN          9           NaN
# 14           pawan9964@gmail.com         12    8008636324
# 15       swayamgupta74@gmail.com         17    9797402957
# 16          Ganesh2480@gmail.com          7    9820463399
# 17    Jangrasukanya066@gmail.com          0           NaN
#
#                                                skills no_of_pages     score
# 0   ['Electronics', 'Sales', 'Analytical', 'Email'...           2  0.366619
# 1   ['Marketing', 'R', 'Mining', 'Email', 'Keras',...           3  0.352944
# 2   ['Technical', 'Analyze', 'Sales', 'Finance', '...           9  0.292332
# 3   ['Technical', 'Gensim', 'Email', 'Mining', 'He...           3  0.260779
# 4   ['Technical', 'R', 'Analytical', 'Keras', 'Ui'...           4  0.260503
# 5   ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...           3  0.257156
# 6   ['Electronics', 'Spyder', 'Sales', 'Mining', '...           3  0.248492
# 7   ['Pandas', 'Analytics', 'System', 'Python', 'J...           1  0.246917
# 8   ['Electronics', 'Analytical', 'Sql', 'Programm...           2  0.229717
# 9   ['Electronics', 'Analyze', 'Textblob', 'Coding...           2  0.218227
# 10  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...           2  0.207244
# 11  ['Electronics', 'Seaborn', 'Tensorflow', 'Metr...           1  0.199623
# 12  ['Pandas', 'Python', 'Algorithms', 'Numpy', 'S...           1  0.196821
# 13  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...           3  0.174961
# 14  ['Technical', 'R', 'Analytical', 'Keras', 'Sec...           2  0.173058
# 15  ['Keras', 'Sql', 'Database', 'Programming', 'L...           1  0.151924
# 16  ['Technical', 'Crm', 'Itil', 'Sales', 'Project...           2  0.139825
# 17  ['Data entry', 'Microsoft excel', 'Word', 'Htm...           1  0.131972

# %% [markdown]
# # TfidfVectorizer + NearestNeighbors

# %%
from sklearn.neighbors import NearestNeighbors

def KNN(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    
    KNN = NearestNeighbors(n_neighbors=7,p=2)
    KNN.fit(tfidf_vectorizer.fit_transform(scraped_data))
#     NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv), return_distance=True)
    NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv))
    top = NNs[1][0][1:]
    index_score = NNs[0][0][1:]

    knn = get_recommendation(top, df, index_score)
    return knn

knn = KNN(df['clean_all'], jd_df['jd'])
knn
# Out:
#                  name                                             degree  \
# 0   Abhijit Manepatil  ['Master of Engineering', 'Master in Computer ...
# 1  Kishore Ramiyengar                 ['Bachelor of Technology (Civil)']
# 2      Aniket Kashyap  ['Bachelor of Engineering, Computer Science  n...
# 3    Abhinav Abhishek                                               None
# 4          Jalpa Dave                     ['B.E. in Computer', 'M.Tech']
# 5    Rakshit Khajuria  ['Electronics and Communication, Engineering S...
#
#                         email Unnamed: 0 mobile_number  \
# 0                         NaN          2           NaN
# 1      kishor.priya@gmail.com         10      007-2008
# 2       monu.aniket@gmail.com          4    9691316944
# 3         abhi4navv@gmail.com          3    8757656959
# 4                         NaN          9           NaN
# 5  rakshitraina1234@gmail.com         16    9149556155
#
#                                               skills no_of_pages     score
# 0  ['Marketing', 'R', 'Mining', 'Email', 'Keras',...           3  1.295567
# 1  ['Technical', 'Analyze', 'Sales', 'Finance', '...           9  1.296454
# 2  ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...           3   1.30137
# 3  ['Electronics', 'Spyder', 'Sales', 'Mining', '...           3  1.309196
# 4  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...           3  1.325547
# 5  ['Electronics', 'Analyze', 'Textblob', 'Coding...           2  1.329058

# %%
knn.to_csv('knn_cv.csv', index=False)

# %% [markdown]
# # Combined TFIDF, CV and KNN result together, to make a dataframe "final"

# %%
knn.columns
# Out:
# Index(['name', 'degree', 'email', 'Unnamed: 0', 'mobile_number', 'skills',
#        'no_of_pages', 'score'],
#       dtype='object')

# %%
merge1 = knn[['Unnamed: 0','name', 'score']].merge(TF[['Unnamed: 0','score']], on= "Unnamed: 0")
final = merge1.merge(cv[['Unnamed: 0','score']], on = 'Unnamed: 0')
final = final.rename(columns={"score_x": "KNN", "score_y": "TF-IDF","score": "CV"})
final.head()
# Out:
#   Unnamed: 0                name       KNN    TF-IDF        CV
# 0          2   Abhijit Manepatil  1.295567  0.160754  0.352944
# 1         10  Kishore Ramiyengar  1.296454  0.159603  0.292332
# 2          4      Aniket Kashyap   1.30137  0.153219  0.257156
# 3          3    Abhinav Abhishek  1.309196  0.143004  0.248492
# 4          9          Jalpa Dave  1.325547  0.121462  0.174961

# %%
final
# Out:
#   Unnamed: 0                name       KNN    TF-IDF        CV
# 0          2   Abhijit Manepatil  1.295567  0.160754  0.352944
# 1         10  Kishore Ramiyengar  1.296454  0.159603  0.292332
# 2          4      Aniket Kashyap   1.30137  0.153219  0.257156
# 3          3    Abhinav Abhishek  1.309196  0.143004  0.248492
# 4          9          Jalpa Dave  1.325547  0.121462  0.174961
# 5         16    Rakshit Khajuria  1.329058  0.116803  0.218227

# %%
# Scale it
from sklearn.preprocessing import MinMaxScaler
slr = MinMaxScaler()
final[["KNN", "TF-IDF", 'CV']] = slr.fit_transform(final[["KNN", "TF-IDF", 'CV']])

# Multiply by weights
final['KNN'] = (1-final['KNN'])/3
final['TF-IDF'] = final['TF-IDF']/3
final['CV'] = final['CV']/3
final['Final'] = final['KNN']+final['TF-IDF']+final['CV']
final.sort_values(by="Final", ascending=False)
# Out:
#   Unnamed: 0                name       KNN    TF-IDF        CV     Final
# 0          2   Abhijit Manepatil  0.333333  0.333333  0.333333  1.000000
# 1         10  Kishore Ramiyengar  0.324497  0.324607  0.219817  0.868921
# 2          4      Aniket Kashyap  0.275577  0.276187  0.153938  0.705702
# 3          3    Abhinav Abhishek  0.197686  0.198713  0.137710  0.534110
# 5         16    Rakshit Khajuria  0.000000  0.000000  0.081031  0.081031
# 4          9          Jalpa Dave  0.034937  0.035336  0.000000  0.070272

# %%
# final.to_csv('final.csv', index=False)
final2 = final.sort_values(by="Final", ascending=False).copy()
final2
# Out:
#   Unnamed: 0                name       KNN    TF-IDF        CV     Final
# 0          2   Abhijit Manepatil  0.333333  0.333333  0.333333  1.000000
# 1         10  Kishore Ramiyengar  0.324497  0.324607  0.219817  0.868921
# 2          4      Aniket Kashyap  0.275577  0.276187  0.153938  0.705702
# 3          3    Abhinav Abhishek  0.197686  0.198713  0.137710  0.534110
# 5         16    Rakshit Khajuria  0.000000  0.000000  0.081031  0.081031
# 4          9          Jalpa Dave  0.034937  0.035336  0.000000  0.070272

# %%
# final2.merge(df, on="JobID")
final_df = df.merge(final2, on='Unnamed: 0')
final_df
# Out:
#   Unnamed: 0              name_x                       email mobile_number  \
# 0          2   Abhijit Manepatil                         NaN           NaN
# 1          3    Abhinav Abhishek         abhi4navv@gmail.com    8757656959
# 2          4      Aniket Kashyap       monu.aniket@gmail.com    9691316944
# 3          9          Jalpa Dave                         NaN           NaN
# 4         10  Kishore Ramiyengar      kishor.priya@gmail.com      007-2008
# 5         16    Rakshit Khajuria  rakshitraina1234@gmail.com    9149556155
#
#                                               skills  \
# 0  ['Marketing', 'R', 'Mining', 'Email', 'Keras',...
# 1  ['Electronics', 'Spyder', 'Sales', 'Mining', '...
# 2  ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...
# 3  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...
# 4  ['Technical', 'Analyze', 'Sales', 'Finance', '...
# 5  ['Electronics', 'Analyze', 'Textblob', 'Coding...
#
#                                               degree  no_of_pages  \
# 0  ['Master of Engineering', 'Master in Computer ...            3
# 1                                               None            3
# 2  ['Bachelor of Engineering, Computer Science  n...            3
# 3                     ['B.E. in Computer', 'M.Tech']            3
# 4                 ['Bachelor of Technology (Civil)']            9
# 5  ['Electronics and Communication, Engineering S...            2
#
#                                            file_path  \
# 0                     cv_to_df/Abhijit-Manepatil.pdf
# 1  cv_to_df/Abhinav_Abhishek_visualcv_resume (1).pdf
# 2                             cv_to_df/Aniket_cv.pdf
# 3                            cv_to_df/Jalpa-Dave.pdf
# 4               cv_to_df/Kishore_Ramiyengar_L_CV.pdf
# 5               cv_to_df/rakshit_khajuria_resume.pdf
#
#                                                  All  \
# 0  Abhijit ManepatilData Scientist with Master in...
# 1  Abhinav AbhishekSenior Software Developer/Data...
# 2  Aniket KashyapSoftware Developer/Data Scientis...
# 3  Jalpa DaveData Scientist - Elegant Microweb Te...
# 4  Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 5  Rakshit KhajuriaMachine Learning EngineerTalab...
#
#                                            clean_all              name_y  \
# 0  abhijit manepatildata scientist master compute...   Abhijit Manepatil
# 1  abhinav abhisheksenior software developer/data...    Abhinav Abhishek
# 2  aniket kashyapsoftware developer/data scientis...      Aniket Kashyap
# 3  jalpa davedata scientist elegant microweb tech...          Jalpa Dave
# 4  kishore ramiyengar lakshmipprasannac 404 gaana...  Kishore Ramiyengar
# 5  rakshit khajuriamachine learning engineertalab...    Rakshit Khajuria
#
#         KNN    TF-IDF        CV     Final
# 0  0.333333  0.333333  0.333333  1.000000
# 1  0.197686  0.198713  0.137710  0.534110
# 2  0.275577  0.276187  0.153938  0.705702
# 3  0.034937  0.035336  0.000000  0.070272
# 4  0.324497  0.324607  0.219817  0.868921
# 5  0.000000  0.000000  0.081031  0.081031

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'email', 'mobile_number', 'skills', 'degree',
#        'no_of_pages', 'file_path', 'All', 'clean_all'],
#       dtype='object')

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0', 'name_x', 'email', 'mobile_number', 'skills', 'degree',
#        'no_of_pages', 'file_path', 'All', 'clean_all', 'name_y', 'KNN',
#        'TF-IDF', 'CV', 'Final'],
#       dtype='object')

# %%
final_df
# Out:
#   Unnamed: 0              name_x                       email mobile_number  \
# 0          2   Abhijit Manepatil                         NaN           NaN
# 1          3    Abhinav Abhishek         abhi4navv@gmail.com    8757656959
# 2          4      Aniket Kashyap       monu.aniket@gmail.com    9691316944
# 3          9          Jalpa Dave                         NaN           NaN
# 4         10  Kishore Ramiyengar      kishor.priya@gmail.com      007-2008
# 5         16    Rakshit Khajuria  rakshitraina1234@gmail.com    9149556155
#
#                                               skills  \
# 0  ['Marketing', 'R', 'Mining', 'Email', 'Keras',...
# 1  ['Electronics', 'Spyder', 'Sales', 'Mining', '...
# 2  ['Technical', 'Spyder', 'Mining', 'Keras', 'Em...
# 3  ['Technical', 'Analyze', 'Marketing', 'R', 'Em...
# 4  ['Technical', 'Analyze', 'Sales', 'Finance', '...
# 5  ['Electronics', 'Analyze', 'Textblob', 'Coding...
#
#                                               degree  no_of_pages  \
# 0  ['Master of Engineering', 'Master in Computer ...            3
# 1                                               None            3
# 2  ['Bachelor of Engineering, Computer Science  n...            3
# 3                     ['B.E. in Computer', 'M.Tech']            3
# 4                 ['Bachelor of Technology (Civil)']            9
# 5  ['Electronics and Communication, Engineering S...            2
#
#                                            file_path  \
# 0                     cv_to_df/Abhijit-Manepatil.pdf
# 1  cv_to_df/Abhinav_Abhishek_visualcv_resume (1).pdf
# 2                             cv_to_df/Aniket_cv.pdf
# 3                            cv_to_df/Jalpa-Dave.pdf
# 4               cv_to_df/Kishore_Ramiyengar_L_CV.pdf
# 5               cv_to_df/rakshit_khajuria_resume.pdf
#
#                                                  All  \
# 0  Abhijit ManepatilData Scientist with Master in...
# 1  Abhinav AbhishekSenior Software Developer/Data...
# 2  Aniket KashyapSoftware Developer/Data Scientis...
# 3  Jalpa DaveData Scientist - Elegant Microweb Te...
# 4  Kishore Ramiyengar LakshmipprasannaC 404, Gaan...
# 5  Rakshit KhajuriaMachine Learning EngineerTalab...
#
#                                            clean_all              name_y  \
# 0  abhijit manepatildata scientist master compute...   Abhijit Manepatil
# 1  abhinav abhisheksenior software developer/data...    Abhinav Abhishek
# 2  aniket kashyapsoftware developer/data scientis...      Aniket Kashyap
# 3  jalpa davedata scientist elegant microweb tech...          Jalpa Dave
# 4  kishore ramiyengar lakshmipprasannac 404 gaana...  Kishore Ramiyengar
# 5  rakshit khajuriamachine learning engineertalab...    Rakshit Khajuria
#
#         KNN    TF-IDF        CV     Final
# 0  0.333333  0.333333  0.333333  1.000000
# 1  0.197686  0.198713  0.137710  0.534110
# 2  0.275577  0.276187  0.153938  0.705702
# 3  0.034937  0.035336  0.000000  0.070272
# 4  0.324497  0.324607  0.219817  0.868921
# 5  0.000000  0.000000  0.081031  0.081031
