# %%
cd /content/drive/MyDrive/job recommender
# Out:
# /content/drive/MyDrive/job recommender

# %%
# importing the required modules
import glob
import pandas as pd
  
# specifying the path to csv files
path = "data/"
  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
count=0
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    df = pd.read_csv(filename, index_col=None)
    content.append(df)
    count=count+1
  
# converting content to data frame
data_frame = pd.concat(content)
print("Total data frame -",count)
# Out:
# Total data frame - 11

# %%
data_frame=data_frame.drop(['companyLogo','id','jobType','scrapedAt'],axis=1)

# %%
data_frame.columns
# Out:
# Index(['company', 'companyLogo', 'description', 'externalApplyLink', 'id',
#        'jobType', 'location', 'positionName', 'postedAt', 'rating',
#        'reviewsCount', 'salary', 'scrapedAt', 'url'],
#       dtype='object')

# %%
# Out:
#                                         company  \
# 0                                       Rambøll
# 1                                          AT&T
# 2                     JPMorgan Chase Bank, N.A.
# 3                           Moody's Corporation
# 4                     JPMorgan Chase Bank, N.A.
# ..                                          ...
# 497                                      Emurgo
# 498  App Incubator Technologies Private Limited
# 499                                       ZigUp
# 500                         DIFX Technology LLC
# 501                      Parsh Technologies LLP
#
#                                            description  \
# 0    \n\n \n  \n   Company Description\n  \n  \n   ...
# 1    Security and compliance analyst that supports ...
# 2    \n Primary Responsibilities: \n \n \n  Run mul...
# 3    \n \n  \n   \n    \n     As a Financial Data A...
# 4    \n Description for Internal & External Candida...
# ..                                                 ...
# 497  \n **We are hiring for Front End Mid-Level and...
# 498  AppIncubator Technologies  - is an award-winni...
# 499  \n\n PlotX New Delhi | 4~8y \n \n  \n   Full S...
# 500  Job Opportunity – QA Engineer\nDIFX\nDIFX is t...
# 501  We are looking for a highly capable blockchain...
#
#                                      externalApplyLink              location  \
# 0    https://in.indeed.com/applystart?jk=cc96b53863...      Gurgaon, Haryana
# 1    https://in.indeed.com/applystart?jk=5922b50e70...  Hyderabad, Telangana
# 2    https://in.indeed.com/applystart?jk=fdcc6c2892...   Mumbai, Maharashtra
# 3    https://in.indeed.com/applystart?jk=21d74dd3fd...      Gurgaon, Haryana
# 4    https://in.indeed.com/applystart?jk=0236f8792c...  Bengaluru, Karnataka
# ..                                                 ...                   ...
# 497                                                NaN  Bengaluru, Karnataka
# 498                                                NaN  Hyderabad, Telangana
# 499  https://in.indeed.com/applystart?jk=05a01b83b3...      New Delhi, Delhi
# 500                                                NaN  Bengaluru, Karnataka
# 501                                                NaN       Rajkot, Gujarat
#
#                              positionName      postedAt  rating  reviewsCount  \
# 0         Associate Analyst - ERP Support   Just posted     3.9         211.0
# 1    TECH SPECIALIST, SECURITY COMPLIANCE         Today     3.7       43942.0
# 2                    Indirect Tax Analyst         Today     3.9       18023.0
# 3          Financial Data Associate - MSC         Today     3.6         505.0
# 4                 Quant Analytics Analyst         Today     3.9       18023.0
# ..                                    ...           ...     ...           ...
# 497                  Front End Developers  30+ days ago     NaN           NaN
# 498             iOS Application Developer  30+ days ago     NaN           NaN
# 499  Senior Software Engineer (Wordpress)  30+ days ago     NaN           NaN
# 500                           QA Engineer  30+ days ago     NaN           NaN
# 501                  Blockchain Developer  30+ days ago     NaN           NaN
#
#                             salary  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 497                            NaN
# 498  ₹5,00,000 - ₹15,00,000 a year
# 499                            NaN
# 500                            NaN
# 501      ₹30,000 - ₹50,000 a month
#
#                                                    url
# 0    https://www.indeed.co.in/rc/clk?jk=cc96b538634...
# 1    https://www.indeed.co.in/rc/clk?jk=5922b50e707...
# 2    https://www.indeed.co.in/rc/clk?jk=fdcc6c28924...
# 3    https://www.indeed.co.in/rc/clk?jk=21d74dd3fd5...
# 4    https://www.indeed.co.in/rc/clk?jk=0236f8792c8...
# ..                                                 ...
# 497  https://www.indeed.co.in/rc/clk?jk=6f09cfb2c5e...
# 498  https://www.indeed.co.in/company/APP-INCUBATOR...
# 499  https://www.indeed.co.in/rc/clk?jk=05a01b83b38...
# 500  https://www.indeed.co.in/company/DIfX-Technolo...
# 501  https://www.indeed.co.in/company/Parsh-Technol...
#
# [5502 rows x 10 columns]

# %%
data_frame.columns
# Out:
# Index(['company', 'description', 'externalApplyLink', 'location',
#        'positionName', 'postedAt', 'rating', 'reviewsCount', 'salary', 'url'],
#       dtype='object')

# %%
df = data_frame.reindex(columns=['company','positionName','description','salary','location','rating','reviewsCount','postedAt','externalApplyLink','url'])

# %%
df
# Out:
#                                         company  \
# 0                                       Rambøll
# 1                                          AT&T
# 2                     JPMorgan Chase Bank, N.A.
# 3                           Moody's Corporation
# 4                     JPMorgan Chase Bank, N.A.
# ..                                          ...
# 497                                      Emurgo
# 498  App Incubator Technologies Private Limited
# 499                                       ZigUp
# 500                         DIFX Technology LLC
# 501                      Parsh Technologies LLP
#
#                              positionName  \
# 0         Associate Analyst - ERP Support
# 1    TECH SPECIALIST, SECURITY COMPLIANCE
# 2                    Indirect Tax Analyst
# 3          Financial Data Associate - MSC
# 4                 Quant Analytics Analyst
# ..                                    ...
# 497                  Front End Developers
# 498             iOS Application Developer
# 499  Senior Software Engineer (Wordpress)
# 500                           QA Engineer
# 501                  Blockchain Developer
#
#                                            description  \
# 0    \n\n \n  \n   Company Description\n  \n  \n   ...
# 1    Security and compliance analyst that supports ...
# 2    \n Primary Responsibilities: \n \n \n  Run mul...
# 3    \n \n  \n   \n    \n     As a Financial Data A...
# 4    \n Description for Internal & External Candida...
# ..                                                 ...
# 497  \n **We are hiring for Front End Mid-Level and...
# 498  AppIncubator Technologies  - is an award-winni...
# 499  \n\n PlotX New Delhi | 4~8y \n \n  \n   Full S...
# 500  Job Opportunity – QA Engineer\nDIFX\nDIFX is t...
# 501  We are looking for a highly capable blockchain...
#
#                             salary              location  rating  \
# 0                              NaN      Gurgaon, Haryana     3.9
# 1                              NaN  Hyderabad, Telangana     3.7
# 2                              NaN   Mumbai, Maharashtra     3.9
# 3                              NaN      Gurgaon, Haryana     3.6
# 4                              NaN  Bengaluru, Karnataka     3.9
# ..                             ...                   ...     ...
# 497                            NaN  Bengaluru, Karnataka     NaN
# 498  ₹5,00,000 - ₹15,00,000 a year  Hyderabad, Telangana     NaN
# 499                            NaN      New Delhi, Delhi     NaN
# 500                            NaN  Bengaluru, Karnataka     NaN
# 501      ₹30,000 - ₹50,000 a month       Rajkot, Gujarat     NaN
#
#      reviewsCount      postedAt  \
# 0           211.0   Just posted
# 1         43942.0         Today
# 2         18023.0         Today
# 3           505.0         Today
# 4         18023.0         Today
# ..            ...           ...
# 497           NaN  30+ days ago
# 498           NaN  30+ days ago
# 499           NaN  30+ days ago
# 500           NaN  30+ days ago
# 501           NaN  30+ days ago
#
#                                      externalApplyLink  \
# 0    https://in.indeed.com/applystart?jk=cc96b53863...
# 1    https://in.indeed.com/applystart?jk=5922b50e70...
# 2    https://in.indeed.com/applystart?jk=fdcc6c2892...
# 3    https://in.indeed.com/applystart?jk=21d74dd3fd...
# 4    https://in.indeed.com/applystart?jk=0236f8792c...
# ..                                                 ...
# 497                                                NaN
# 498                                                NaN
# 499  https://in.indeed.com/applystart?jk=05a01b83b3...
# 500                                                NaN
# 501                                                NaN
#
#                                                    url
# 0    https://www.indeed.co.in/rc/clk?jk=cc96b538634...
# 1    https://www.indeed.co.in/rc/clk?jk=5922b50e707...
# 2    https://www.indeed.co.in/rc/clk?jk=fdcc6c28924...
# 3    https://www.indeed.co.in/rc/clk?jk=21d74dd3fd5...
# 4    https://www.indeed.co.in/rc/clk?jk=0236f8792c8...
# ..                                                 ...
# 497  https://www.indeed.co.in/rc/clk?jk=6f09cfb2c5e...
# 498  https://www.indeed.co.in/company/APP-INCUBATOR...
# 499  https://www.indeed.co.in/rc/clk?jk=05a01b83b38...
# 500  https://www.indeed.co.in/company/DIfX-Technolo...
# 501  https://www.indeed.co.in/company/Parsh-Technol...
#
# [5502 rows x 10 columns]

# %%
df.to_csv("data.csv",index=False)
