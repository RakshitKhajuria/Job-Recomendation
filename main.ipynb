# %%
# import pdfplumber
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict
import pandas as pd 
from nltk.collocations import *
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')

# %%
# Import CV
f=open('textfile.txt','r', errors = 'ignore')
text=f.read()

# %%
def nlp(x):
    word_sent = word_tokenize(x.lower().replace("\n",""))
    _stopwords = set(stopwords.words('english') + list(punctuation)+list("●")+list('–')+list('’'))
    word_sent=[word for word in word_sent if word not in _stopwords]
    lemmatizer = WordNetLemmatizer()
    NLP_Processed_CV = [lemmatizer.lemmatize(word) for word in word_tokenize(" ".join(word_sent))]
#     return " ".join(NLP_Processed_CV)
    return NLP_Processed_CV

# %%
def get_key_word(x):
    finder = BigramCollocationFinder.from_words(x)
    lst = []
    Key_word_from_CV = []
    for i in sorted(finder.ngram_fd.items()):
    # if a double word appears more than once, then print it out.
        if i[1] > 1:
            print(i)
            lst.append(i[0])
        else:
            pass

    # print("************************")
    for j in lst:
    #     print(" ".join(j))
        Key_word_from_CV.append(" ".join(j))
    return Key_word_from_CV

# %%
NLP_Processed_CV = nlp(text)
# NLP_Processed_CV=' '.join(NLP_Processed_CV)
NLP_Processed_CV
# Out:
# ['rakshit',
#  'khajuriamachine',
#  'learning',
#  'engineertalab',
#  'tillo',
#  'gole',
#  'gujral',
#  '180002',
#  'jammu',
#  'india',
#  'rakshitraina1234',
#  'gmail.com',
#  '914955615514',
#  'aug',
#  '2001',
#  'http',
#  '//www.linkedin.com/in/rakshit-khajuria-3627781b8/',
#  'http',
#  '//github.com/ryzxxl9149556155summaryskilled',
#  'developing',
#  'implementing',
#  'data-driven',
#  'solution',
#  'real-world',
#  'problem',
#  'utilizing',
#  'range',
#  'tool',
#  'andtechniques',
#  'extract',
#  'valuable',
#  'insight',
#  'large',
#  'complex',
#  'data',
#  'set',
#  'posse',
#  'diverse',
#  'experience',
#  'cleaningand',
#  'analyzing',
#  'data',
#  'enhancing',
#  'existing',
#  'model',
#  'continuously',
#  'seeking',
#  'enhance',
#  'skill',
#  'broaden',
#  'myknowledge',
#  'dynamic',
#  '\x00eld',
#  'data',
#  'science.skillstools',
#  'python',
#  'git',
#  'github',
#  'jupyter',
#  'notebook',
#  'anaconda',
#  'v',
#  'codepackages',
#  'scikit-learn',
#  'numpy',
#  'panda',
#  'matplotlib',
#  'nltk',
#  'tensorflow',
#  'flask',
#  'streamlit',
#  'spacy',
#  'text',
#  'blob',
#  'vader.machine',
#  'learning',
#  'supervised',
#  'learning',
#  'unsupervised',
#  'learning',
#  'clustering',
#  'algorithm',
#  'decision',
#  'tree',
#  'randomforests',
#  'neural',
#  'networks.nlp',
#  'sentiment',
#  'analysis',
#  'text',
#  'classi\x00cation',
#  'named',
#  'entity',
#  'recognition',
#  'word',
#  'embedding',
#  'topic',
#  'modeling',
#  'deeplearning',
#  'nlp',
#  'model',
#  'e.g',
#  '.',
#  'transformer',
#  'bert',
#  'lstms',
#  'soft',
#  'skillstime',
#  'management',
#  'problem-solving',
#  'leadership',
#  'teamwork',
#  'presentation',
#  'skill',
#  'con\x00denceprofessional',
#  'experienceresearch',
#  'intern',
#  'jul',
#  '2022',
#  'presentjammu',
#  'indiadeveloped',
#  'implemented',
#  'sentiment',
#  'analysis',
#  'model',
#  'extract',
#  'classifyemotional',
#  'context',
#  'scraped',
#  'reddit',
#  'data',
#  'suicidal',
#  'discussions.utilized',
#  'advanced',
#  'technique',
#  'including',
#  'unsupervised',
#  'pre-trained',
#  'model',
#  'e.g',
#  'vader',
#  'textblob',
#  'clustering',
#  'algorithm',
#  'e.g',
#  'kmeans',
#  'dbscan',
#  'accurately',
#  'analyze',
#  'andinterpret',
#  'sentiment.enhanced',
#  'model',
#  'performance',
#  'use',
#  'deep',
#  'learning',
#  'technique',
#  'aslstm',
#  'bilstm',
#  'etc',
#  '\x00ne-tuning',
#  'pre-trained',
#  'word',
#  'embeddings',
#  'e.g',
#  'glove',
#  '.improved',
#  'model',
#  'accuracy',
#  'applying',
#  'different',
#  'bert',
#  'models.machine',
#  'learning',
#  'tarinee',
#  'nov',
#  '2020',
#  'aug',
#  '2021became',
#  'pro\x00cient',
#  'wide',
#  'range',
#  'machine',
#  'learning',
#  'algorithm',
#  'including',
#  'bangalore',
#  'indiaunderlying',
#  'mathematical',
#  'principles.hands-on',
#  'experience',
#  'end-to-end',
#  'machine',
#  'learning',
#  'project',
#  'development',
#  'dataacquisition',
#  'model',
#  'deployment.demonstrated',
#  'expertise',
#  'using',
#  'cloud',
#  'platform',
#  'heroku',
#  'streamlit',
#  'aws',
#  'ef\x00ciently',
#  'deploy',
#  'machine',
#  'learning',
#  'model',
#  'solutions.rakshitraina1234',
#  'gmail.com',
#  '1',
#  '2rakshit',
#  'khajuriamachine',
#  'learning',
#  'engineertalab',
#  'tillo',
#  'gole',
#  'gujral',
#  '180002',
#  'jammu',
#  'india',
#  'rakshitraina1234',
#  'gmail.com',
#  '914955615514',
#  'aug',
#  '2001',
#  'http',
#  '//www.linkedin.com/in/rakshit-khajuria-3627781b8/',
#  'http',
#  '//github.com/ryzxxl9149556155summaryskilled',
#  'developing',
#  'implementing',
#  'data-driven',
#  'solution',
#  'real-world',
#  'problem',
#  'utilizing',
#  'range',
#  'tool',
#  'andtechniques',
#  'extract',
#  'valuable',
#  'insight',
#  'large',
#  'complex',
#  'data',
#  'set',
#  'posse',
#  'diverse',
#  'experience',
#  'cleaningand',
#  'analyzing',
#  'data',
#  'enhancing',
#  'existing',
#  'model',
#  'continuously',
#  'seeking',
#  'enhance',
#  'skill',
#  'broaden',
#  'myknowledge',
#  'dynamic',
#  '\x00eld',
#  'data',
#  'science.skillstools',
#  'python',
#  'git',
#  'github',
#  'jupyter',
#  'notebook',
#  'anaconda',
#  'v',
#  'codepackages',
#  'scikit-learn',
#  'numpy',
#  'panda',
#  'matplotlib',
#  'nltk',
#  'tensorflow',
#  'flask',
#  'streamlit',
#  'spacy',
#  'text',
#  'blob',
#  'vader.machine',
#  'learning',
#  'supervised',
#  'learning',
#  'unsupervised',
#  'learning',
#  'clustering',
#  'algorithm',
#  'decision',
#  'tree',
#  'randomforests',
#  'neural',
#  'networks.nlp',
#  'sentiment',
#  'analysis',
#  'text',
#  'classi\x00cation',
#  'named',
#  'entity',
#  'recognition',
#  'word',
#  'embedding',
#  'topic',
#  'modeling',
#  'deeplearning',
#  'nlp',
#  'model',
#  'e.g',
#  '.',
#  'transformer',
#  'bert',
#  'lstms',
#  'soft',
#  'skillstime',
#  'management',
#  'problem-solving',
#  'leadership',
#  'teamwork',
#  'presentation',
#  'skill',
#  'con\x00denceprofessional',
#  'experienceresearch',
#  'intern',
#  'jul',
#  '2022',
#  'presentjammu',
#  'indiadeveloped',
#  'implemented',
#  'sentiment',
#  'analysis',
#  'model',
#  'extract',
#  'classifyemotional',
#  'context',
#  'scraped',
#  'reddit',
#  'data',
#  'suicidal',
#  'discussions.utilized',
#  'advanced',
#  'technique',
#  'including',
#  'unsupervised',
#  'pre-trained',
#  'model',
#  'e.g',
#  'vader',
#  'textblob',
#  'clustering',
#  'algorithm',
#  'e.g',
#  'kmeans',
#  'dbscan',
#  'accurately',
#  'analyze',
#  'andinterpret',
#  'sentiment.enhanced',
#  'model',
#  'performance',
#  'use',
#  'deep',
#  'learning',
#  'technique',
#  'aslstm',
#  'bilstm',
#  'etc',
#  '\x00ne-tuning',
#  'pre-trained',
#  'word',
#  'embeddings',
#  'e.g',
#  'glove',
#  '.improved',
#  'model',
#  'accuracy',
#  'applying',
#  'different',
#  'bert',
#  'models.machine',
#  'learning',
#  'tarinee',
#  'nov',
#  '2020',
#  'aug',
#  '2021became',
#  'pro\x00cient',
#  'wide',
#  'range',
#  'machine',
#  'learning',
#  'algorithm',
#  'including',
#  'bangalore',
#  'indiaunderlying',
#  'mathematical',
#  'principles.hands-on',
#  'experience',
#  'end-to-end',
#  'machine',
#  'learning',
#  'project',
#  'development',
#  'dataacquisition',
#  'model',
#  'deployment.demonstrated',
#  'expertise',
#  'using',
#  'cloud',
#  'platform',
#  'heroku',
#  'streamlit',
#  'aws',
#  'ef\x00ciently',
#  'deploy',
#  'machine',
#  'learning',
#  'model',
#  'solutions.rakshitraina1234',
#  'gmail.com',
#  '1',
#  '2projectsmulti',
#  'purpose',
#  'nlp',
#  'application',
#  'nlpify',
#  'nov',
#  '2022',
#  'nov',
#  '2022developed',
#  'sophisticated',
#  'ai',
#  'platform',
#  'extract',
#  'various',
#  'nlp',
#  'feature',
#  'includingsentiment',
#  'analysis',
#  'named',
#  'entity',
#  'recognition',
#  'text',
#  'summarization',
#  'appreview',
#  'data.performed',
#  'extensive',
#  'data',
#  'preprocessing',
#  'using',
#  'technique',
#  'tokenization',
#  'lemmatization',
#  'vectorization',
#  'transform',
#  'raw',
#  'data',
#  'machine-readableformat.createda',
#  'multi-class',
#  'classi\x00cation',
#  'model',
#  'using',
#  'logistic',
#  'regression',
#  'textvectorization',
#  'pipeline',
#  'predict',
#  'sentiment',
#  'deployed',
#  'platform',
#  'user-friendly',
#  'web',
#  'app',
#  'using',
#  'streamlit',
#  'framework.political',
#  'spectrum',
#  'detection',
#  'medium',
#  'news',
#  'using',
#  'deep-learning',
#  'shap',
#  'oct',
#  '2022',
#  'oct',
#  '2022pythonbuilta',
#  'political',
#  'spectrum',
#  'detection',
#  'deep',
#  'learning',
#  'sequential',
#  'model.performed',
#  'nlp',
#  'based',
#  'tokenization',
#  'lemmatization',
#  'vectorization',
#  'processed',
#  'datausing',
#  'neattext',
#  'machine',
#  'understandable',
#  'language.simpli\x00ed',
#  'code',
#  'library',
#  'shap',
#  'built',
#  'theoretic',
#  'approach',
#  'explain',
#  'output',
#  'ofsequential',
#  'deep',
#  'learning',
#  'model.diabetes',
#  'prediction',
#  'using',
#  'flask',
#  'dec',
#  '2021',
#  'jan',
#  '2022conducted',
#  'in-depth',
#  'data',
#  'analysis',
#  'national',
#  'institute',
#  'diabetes',
#  'digestiveand',
#  'kidney',
#  'disease',
#  'datasetbuilt',
#  'multiple',
#  'machine',
#  'learning',
#  'model',
#  'including',
#  'random',
#  'forest',
#  'logistic',
#  'regression',
#  'knn',
#  'svm',
#  'prediction',
#  'various',
#  'onset',
#  'type',
#  '2',
#  'diabetescreated',
#  'full-stack',
#  'application',
#  'using',
#  'flask',
#  'deployed',
#  'heroku',
#  'publicaccess',
#  'http',
#  '//diabetes-prediction-app02.herokuapp.com/certificatesibm',
#  'data',
#  'science',
#  'specialization',
#  'machine',
#  'learning',
#  'deep',
#  'learning',
#  'traineeineuron.aimathematics',
#  'machine',
#  'learningdata',
#  'sciencestatistics',
#  'foundation',
#  'linkedinmachine',
#  'learning',
#  'pythoneducationelectronics',
#  'communication',
#  'engineering',
#  'smvd',
#  'university',
#  'reasi',
#  'j',
#  'k',
#  'jul',
#  '2019',
#  'jul',
#  '2023jammu',
#  'indiaorganisationsa.i',
#  'circleactivelyparticipated',
#  'a.i',
#  'circle',
#  'collaborating',
#  'team',
#  'member',
#  'machine',
#  'learning',
#  'project',
#  'mentoringjunior',
#  'member',
#  'machine',
#  'learning',
#  'potential',
#  'applicationsinterestscoding',
#  'football',
#  'sketching',
#  'machine',
#  'learning',
#  'deep',
#  'learning',
#  'mathematicsrakshitraina1234',
#  'gmail.com',
#  '2',
#  '2']

# %%
key_word = get_key_word(NLP_Processed_CV)
key_word
# Out:
# (('\x00eld', 'data'), 2)
# (('\x00ne-tuning', 'pre-trained'), 2)
# (('.', 'transformer'), 2)
# (('.improved', 'model'), 2)
# (('//github.com/ryzxxl9149556155summaryskilled', 'developing'), 2)
# (('//www.linkedin.com/in/rakshit-khajuria-3627781b8/', 'http'), 2)
# (('180002', 'jammu'), 2)
# (('2001', 'http'), 2)
# (('2020', 'aug'), 2)
# (('2021became', 'pro\x00cient'), 2)
# (('2022', 'presentjammu'), 2)
# (('914955615514', 'aug'), 2)
# (('accuracy', 'applying'), 2)
# (('accurately', 'analyze'), 2)
# (('advanced', 'technique'), 2)
# (('algorithm', 'decision'), 2)
# (('algorithm', 'e.g'), 2)
# (('algorithm', 'including'), 2)
# (('anaconda', 'v'), 2)
# (('analysis', 'model'), 2)
# (('analysis', 'text'), 2)
# (('analyze', 'andinterpret'), 2)
# (('analyzing', 'data'), 2)
# (('andinterpret', 'sentiment.enhanced'), 2)
# (('andtechniques', 'extract'), 2)
# (('applying', 'different'), 2)
# (('aslstm', 'bilstm'), 2)
# (('aug', '2001'), 2)
# (('aug', '2021became'), 2)
# (('aws', 'ef\x00ciently'), 2)
# (('bangalore', 'indiaunderlying'), 2)
# (('bert', 'lstms'), 2)
# (('bert', 'models.machine'), 2)
# (('bilstm', 'etc'), 2)
# (('blob', 'vader.machine'), 2)
# (('broaden', 'myknowledge'), 2)
# (('classi\x00cation', 'named'), 2)
# (('classifyemotional', 'context'), 2)
# (('cleaningand', 'analyzing'), 2)
# (('cloud', 'platform'), 2)
# (('clustering', 'algorithm'), 4)
# (('codepackages', 'scikit-learn'), 2)
# (('complex', 'data'), 2)
# (('con\x00denceprofessional', 'experienceresearch'), 2)
# (('context', 'scraped'), 2)
# (('continuously', 'seeking'), 2)
# (('data', 'enhancing'), 2)
# (('data', 'science.skillstools'), 2)
# (('data', 'set'), 2)
# (('data', 'suicidal'), 2)
# (('data-driven', 'solution'), 2)
# (('dataacquisition', 'model'), 2)
# (('dbscan', 'accurately'), 2)
# (('decision', 'tree'), 2)
# (('deep', 'learning'), 6)
# (('deeplearning', 'nlp'), 2)
# (('deploy', 'machine'), 2)
# (('deployment.demonstrated', 'expertise'), 2)
# (('developing', 'implementing'), 2)
# (('development', 'dataacquisition'), 2)
# (('different', 'bert'), 2)
# (('discussions.utilized', 'advanced'), 2)
# (('diverse', 'experience'), 2)
# (('dynamic', '\x00eld'), 2)
# (('e.g', '.'), 2)
# (('e.g', 'glove'), 2)
# (('e.g', 'kmeans'), 2)
# (('e.g', 'vader'), 2)
# (('ef\x00ciently', 'deploy'), 2)
# (('embedding', 'topic'), 2)
# (('embeddings', 'e.g'), 2)
# (('end-to-end', 'machine'), 2)
# (('engineertalab', 'tillo'), 2)
# (('enhance', 'skill'), 2)
# (('enhancing', 'existing'), 2)
# (('entity', 'recognition'), 3)
# (('etc', '\x00ne-tuning'), 2)
# (('existing', 'model'), 2)
# (('experience', 'cleaningand'), 2)
# (('experience', 'end-to-end'), 2)
# (('experienceresearch', 'intern'), 2)
# (('expertise', 'using'), 2)
# (('extract', 'classifyemotional'), 2)
# (('extract', 'valuable'), 2)
# (('flask', 'streamlit'), 2)
# (('git', 'github'), 2)
# (('github', 'jupyter'), 2)
# (('glove', '.improved'), 2)
# (('gmail.com', '1'), 2)
# (('gmail.com', '914955615514'), 2)
# (('gole', 'gujral'), 2)
# (('gujral', '180002'), 2)
# (('heroku', 'streamlit'), 2)
# (('http', '//github.com/ryzxxl9149556155summaryskilled'), 2)
# (('http', '//www.linkedin.com/in/rakshit-khajuria-3627781b8/'), 2)
# (('implemented', 'sentiment'), 2)
# (('implementing', 'data-driven'), 2)
# (('including', 'bangalore'), 2)
# (('including', 'unsupervised'), 2)
# (('india', 'rakshitraina1234'), 2)
# (('indiadeveloped', 'implemented'), 2)
# (('indiaunderlying', 'mathematical'), 2)
# (('insight', 'large'), 2)
# (('intern', 'jul'), 2)
# (('jammu', 'india'), 2)
# (('jul', '2022'), 2)
# (('jupyter', 'notebook'), 2)
# (('khajuriamachine', 'learning'), 2)
# (('kmeans', 'dbscan'), 2)
# (('large', 'complex'), 2)
# (('leadership', 'teamwork'), 2)
# (('learning', 'algorithm'), 2)
# (('learning', 'clustering'), 2)
# (('learning', 'deep'), 2)
# (('learning', 'engineertalab'), 2)
# (('learning', 'model'), 3)
# (('learning', 'project'), 3)
# (('learning', 'supervised'), 2)
# (('learning', 'tarinee'), 2)
# (('learning', 'technique'), 2)
# (('learning', 'unsupervised'), 2)
# (('lemmatization', 'vectorization'), 2)
# (('logistic', 'regression'), 2)
# (('lstms', 'soft'), 2)
# (('machine', 'learning'), 11)
# (('management', 'problem-solving'), 2)
# (('mathematical', 'principles.hands-on'), 2)
# (('matplotlib', 'nltk'), 2)
# (('member', 'machine'), 2)
# (('model', 'accuracy'), 2)
# (('model', 'continuously'), 2)
# (('model', 'deployment.demonstrated'), 2)
# (('model', 'e.g'), 4)
# (('model', 'extract'), 2)
# (('model', 'performance'), 2)
# (('model', 'solutions.rakshitraina1234'), 2)
# (('modeling', 'deeplearning'), 2)
# (('models.machine', 'learning'), 2)
# (('myknowledge', 'dynamic'), 2)
# (('named', 'entity'), 3)
# (('networks.nlp', 'sentiment'), 2)
# (('neural', 'networks.nlp'), 2)
# (('nlp', 'model'), 2)
# (('nltk', 'tensorflow'), 2)
# (('notebook', 'anaconda'), 2)
# (('nov', '2020'), 2)
# (('numpy', 'panda'), 2)
# (('panda', 'matplotlib'), 2)
# (('performance', 'use'), 2)
# (('platform', 'heroku'), 2)
# (('posse', 'diverse'), 2)
# (('pre-trained', 'model'), 2)
# (('pre-trained', 'word'), 2)
# (('presentation', 'skill'), 2)
# (('presentjammu', 'indiadeveloped'), 2)
# (('principles.hands-on', 'experience'), 2)
# (('pro\x00cient', 'wide'), 2)
# (('problem', 'utilizing'), 2)
# (('problem-solving', 'leadership'), 2)
# (('project', 'development'), 2)
# (('python', 'git'), 2)
# (('rakshitraina1234', 'gmail.com'), 2)
# (('randomforests', 'neural'), 2)
# (('range', 'machine'), 2)
# (('range', 'tool'), 2)
# (('real-world', 'problem'), 2)
# (('recognition', 'word'), 2)
# (('reddit', 'data'), 2)
# (('science.skillstools', 'python'), 2)
# (('scikit-learn', 'numpy'), 2)
# (('scraped', 'reddit'), 2)
# (('seeking', 'enhance'), 2)
# (('sentiment', 'analysis'), 4)
# (('sentiment.enhanced', 'model'), 2)
# (('set', 'posse'), 2)
# (('skill', 'broaden'), 2)
# (('skill', 'con\x00denceprofessional'), 2)
# (('skillstime', 'management'), 2)
# (('soft', 'skillstime'), 2)
# (('solution', 'real-world'), 2)
# (('solutions.rakshitraina1234', 'gmail.com'), 2)
# (('spacy', 'text'), 2)
# (('spectrum', 'detection'), 2)
# (('streamlit', 'aws'), 2)
# (('streamlit', 'spacy'), 2)
# (('suicidal', 'discussions.utilized'), 2)
# (('supervised', 'learning'), 2)
# (('tarinee', 'nov'), 2)
# (('teamwork', 'presentation'), 2)
# (('technique', 'aslstm'), 2)
# (('technique', 'including'), 2)
# (('tensorflow', 'flask'), 2)
# (('text', 'blob'), 2)
# (('text', 'classi\x00cation'), 2)
# (('textblob', 'clustering'), 2)
# (('tillo', 'gole'), 2)
# (('tokenization', 'lemmatization'), 2)
# (('tool', 'andtechniques'), 2)
# (('topic', 'modeling'), 2)
# (('transformer', 'bert'), 2)
# (('tree', 'randomforests'), 2)
# (('unsupervised', 'learning'), 2)
# (('unsupervised', 'pre-trained'), 2)
# (('use', 'deep'), 2)
# (('using', 'cloud'), 2)
# (('using', 'flask'), 2)
# (('utilizing', 'range'), 2)
# (('v', 'codepackages'), 2)
# (('vader', 'textblob'), 2)
# (('vader.machine', 'learning'), 2)
# (('valuable', 'insight'), 2)
# (('wide', 'range'), 2)
# (('word', 'embedding'), 2)
# (('word', 'embeddings'), 2)
# ['\x00eld data',
#  '\x00ne-tuning pre-trained',
#  '. transformer',
#  '.improved model',
#  '//github.com/ryzxxl9149556155summaryskilled developing',
#  '//www.linkedin.com/in/rakshit-khajuria-3627781b8/ http',
#  '180002 jammu',
#  '2001 http',
#  '2020 aug',
#  '2021became pro\x00cient',
#  '2022 presentjammu',
#  '914955615514 aug',
#  'accuracy applying',
#  'accurately analyze',
#  'advanced technique',
#  'algorithm decision',
#  'algorithm e.g',
#  'algorithm including',
#  'anaconda v',
#  'analysis model',
#  'analysis text',
#  'analyze andinterpret',
#  'analyzing data',
#  'andinterpret sentiment.enhanced',
#  'andtechniques extract',
#  'applying different',
#  'aslstm bilstm',
#  'aug 2001',
#  'aug 2021became',
#  'aws ef\x00ciently',
#  'bangalore indiaunderlying',
#  'bert lstms',
#  'bert models.machine',
#  'bilstm etc',
#  'blob vader.machine',
#  'broaden myknowledge',
#  'classi\x00cation named',
#  'classifyemotional context',
#  'cleaningand analyzing',
#  'cloud platform',
#  'clustering algorithm',
#  'codepackages scikit-learn',
#  'complex data',
#  'con\x00denceprofessional experienceresearch',
#  'context scraped',
#  'continuously seeking',
#  'data enhancing',
#  'data science.skillstools',
#  'data set',
#  'data suicidal',
#  'data-driven solution',
#  'dataacquisition model',
#  'dbscan accurately',
#  'decision tree',
#  'deep learning',
#  'deeplearning nlp',
#  'deploy machine',
#  'deployment.demonstrated expertise',
#  'developing implementing',
#  'development dataacquisition',
#  'different bert',
#  'discussions.utilized advanced',
#  'diverse experience',
#  'dynamic \x00eld',
#  'e.g .',
#  'e.g glove',
#  'e.g kmeans',
#  'e.g vader',
#  'ef\x00ciently deploy',
#  'embedding topic',
#  'embeddings e.g',
#  'end-to-end machine',
#  'engineertalab tillo',
#  'enhance skill',
#  'enhancing existing',
#  'entity recognition',
#  'etc \x00ne-tuning',
#  'existing model',
#  'experience cleaningand',
#  'experience end-to-end',
#  'experienceresearch intern',
#  'expertise using',
#  'extract classifyemotional',
#  'extract valuable',
#  'flask streamlit',
#  'git github',
#  'github jupyter',
#  'glove .improved',
#  'gmail.com 1',
#  'gmail.com 914955615514',
#  'gole gujral',
#  'gujral 180002',
#  'heroku streamlit',
#  'http //github.com/ryzxxl9149556155summaryskilled',
#  'http //www.linkedin.com/in/rakshit-khajuria-3627781b8/',
#  'implemented sentiment',
#  'implementing data-driven',
#  'including bangalore',
#  'including unsupervised',
#  'india rakshitraina1234',
#  'indiadeveloped implemented',
#  'indiaunderlying mathematical',
#  'insight large',
#  'intern jul',
#  'jammu india',
#  'jul 2022',
#  'jupyter notebook',
#  'khajuriamachine learning',
#  'kmeans dbscan',
#  'large complex',
#  'leadership teamwork',
#  'learning algorithm',
#  'learning clustering',
#  'learning deep',
#  'learning engineertalab',
#  'learning model',
#  'learning project',
#  'learning supervised',
#  'learning tarinee',
#  'learning technique',
#  'learning unsupervised',
#  'lemmatization vectorization',
#  'logistic regression',
#  'lstms soft',
#  'machine learning',
#  'management problem-solving',
#  'mathematical principles.hands-on',
#  'matplotlib nltk',
#  'member machine',
#  'model accuracy',
#  'model continuously',
#  'model deployment.demonstrated',
#  'model e.g',
#  'model extract',
#  'model performance',
#  'model solutions.rakshitraina1234',
#  'modeling deeplearning',
#  'models.machine learning',
#  'myknowledge dynamic',
#  'named entity',
#  'networks.nlp sentiment',
#  'neural networks.nlp',
#  'nlp model',
#  'nltk tensorflow',
#  'notebook anaconda',
#  'nov 2020',
#  'numpy panda',
#  'panda matplotlib',
#  'performance use',
#  'platform heroku',
#  'posse diverse',
#  'pre-trained model',
#  'pre-trained word',
#  'presentation skill',
#  'presentjammu indiadeveloped',
#  'principles.hands-on experience',
#  'pro\x00cient wide',
#  'problem utilizing',
#  'problem-solving leadership',
#  'project development',
#  'python git',
#  'rakshitraina1234 gmail.com',
#  'randomforests neural',
#  'range machine',
#  'range tool',
#  'real-world problem',
#  'recognition word',
#  'reddit data',
#  'science.skillstools python',
#  'scikit-learn numpy',
#  'scraped reddit',
#  'seeking enhance',
#  'sentiment analysis',
#  'sentiment.enhanced model',
#  'set posse',
#  'skill broaden',
#  'skill con\x00denceprofessional',
#  'skillstime management',
#  'soft skillstime',
#  'solution real-world',
#  'solutions.rakshitraina1234 gmail.com',
#  'spacy text',
#  'spectrum detection',
#  'streamlit aws',
#  'streamlit spacy',
#  'suicidal discussions.utilized',
#  'supervised learning',
#  'tarinee nov',
#  'teamwork presentation',
#  'technique aslstm',
#  'technique including',
#  'tensorflow flask',
#  'text blob',
#  'text classi\x00cation',
#  'textblob clustering',
#  'tillo gole',
#  'tokenization lemmatization',
#  'tool andtechniques',
#  'topic modeling',
#  'transformer bert',
#  'tree randomforests',
#  'unsupervised learning',
#  'unsupervised pre-trained',
#  'use deep',
#  'using cloud',
#  'using flask',
#  'utilizing range',
#  'v codepackages',
#  'vader textblob',
#  'vader.machine learning',
#  'valuable insight',
#  'wide range',
#  'word embedding',
#  'word embeddings']

# %% [markdown]
# # Importing scapped df

# %%
DF_PATH = "data.csv"

# %%
df = pd.read_csv(DF_PATH)
df
# Out:
#                                          company  \
# 0                                        Rambøll
# 1                                           AT&T
# 2                      JPMorgan Chase Bank, N.A.
# 3                            Moody's Corporation
# 4                      JPMorgan Chase Bank, N.A.
# ...                                          ...
# 5497                                      Emurgo
# 5498  App Incubator Technologies Private Limited
# 5499                                       ZigUp
# 5500                         DIFX Technology LLC
# 5501                      Parsh Technologies LLP
#
#                               positionName  \
# 0          Associate Analyst - ERP Support
# 1     TECH SPECIALIST, SECURITY COMPLIANCE
# 2                     Indirect Tax Analyst
# 3           Financial Data Associate - MSC
# 4                  Quant Analytics Analyst
# ...                                    ...
# 5497                  Front End Developers
# 5498             iOS Application Developer
# 5499  Senior Software Engineer (Wordpress)
# 5500                           QA Engineer
# 5501                  Blockchain Developer
#
#                                             description  \
# 0     \n\n \n  \n   Company Description\n  \n  \n   ...
# 1     Security and compliance analyst that supports ...
# 2     \n Primary Responsibilities: \n \n \n  Run mul...
# 3     \n \n  \n   \n    \n     As a Financial Data A...
# 4     \n Description for Internal & External Candida...
# ...                                                 ...
# 5497  \n **We are hiring for Front End Mid-Level and...
# 5498  AppIncubator Technologies  - is an award-winni...
# 5499  \n\n PlotX New Delhi | 4~8y \n \n  \n   Full S...
# 5500  Job Opportunity – QA Engineer\nDIFX\nDIFX is t...
# 5501  We are looking for a highly capable blockchain...
#
#                              salary              location  rating  \
# 0                               NaN      Gurgaon, Haryana     3.9
# 1                               NaN  Hyderabad, Telangana     3.7
# 2                               NaN   Mumbai, Maharashtra     3.9
# 3                               NaN      Gurgaon, Haryana     3.6
# 4                               NaN  Bengaluru, Karnataka     3.9
# ...                             ...                   ...     ...
# 5497                            NaN  Bengaluru, Karnataka     NaN
# 5498  ₹5,00,000 - ₹15,00,000 a year  Hyderabad, Telangana     NaN
# 5499                            NaN      New Delhi, Delhi     NaN
# 5500                            NaN  Bengaluru, Karnataka     NaN
# 5501      ₹30,000 - ₹50,000 a month       Rajkot, Gujarat     NaN
#
#       reviewsCount      postedAt  \
# 0            211.0   Just posted
# 1          43942.0         Today
# 2          18023.0         Today
# 3            505.0         Today
# 4          18023.0         Today
# ...            ...           ...
# 5497           NaN  30+ days ago
# 5498           NaN  30+ days ago
# 5499           NaN  30+ days ago
# 5500           NaN  30+ days ago
# 5501           NaN  30+ days ago
#
#                                       externalApplyLink  \
# 0     https://in.indeed.com/applystart?jk=cc96b53863...
# 1     https://in.indeed.com/applystart?jk=5922b50e70...
# 2     https://in.indeed.com/applystart?jk=fdcc6c2892...
# 3     https://in.indeed.com/applystart?jk=21d74dd3fd...
# 4     https://in.indeed.com/applystart?jk=0236f8792c...
# ...                                                 ...
# 5497                                                NaN
# 5498                                                NaN
# 5499  https://in.indeed.com/applystart?jk=05a01b83b3...
# 5500                                                NaN
# 5501                                                NaN
#
#                                                     url
# 0     https://www.indeed.co.in/rc/clk?jk=cc96b538634...
# 1     https://www.indeed.co.in/rc/clk?jk=5922b50e707...
# 2     https://www.indeed.co.in/rc/clk?jk=fdcc6c28924...
# 3     https://www.indeed.co.in/rc/clk?jk=21d74dd3fd5...
# 4     https://www.indeed.co.in/rc/clk?jk=0236f8792c8...
# ...                                                 ...
# 5497  https://www.indeed.co.in/rc/clk?jk=6f09cfb2c5e...
# 5498  https://www.indeed.co.in/company/APP-INCUBATOR...
# 5499  https://www.indeed.co.in/rc/clk?jk=05a01b83b38...
# 5500  https://www.indeed.co.in/company/DIfX-Technolo...
# 5501  https://www.indeed.co.in/company/Parsh-Technol...
#
# [5502 rows x 10 columns]

# %%
df.shape
# Out:
# (5502, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5502 entries, 0 to 5501
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   company            5408 non-null   object
#  1   positionName       5502 non-null   object
#  2   description        5502 non-null   object
#  3   salary             1248 non-null   object
#  4   location           5502 non-null   object
#  5   rating             3128 non-null   float64
#  6   reviewsCount       3128 non-null   float64
#  7   postedAt           5502 non-null   object
#  8   externalApplyLink  4044 non-null   object
#  9   url                5502 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 430.0+ KB

# %%
df['All'] = df[df.columns[0:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# %%
df
# Out:
#                                          company  \
# 0                                        Rambøll
# 1                                           AT&T
# 2                      JPMorgan Chase Bank, N.A.
# 3                            Moody's Corporation
# 4                      JPMorgan Chase Bank, N.A.
# ...                                          ...
# 5497                                      Emurgo
# 5498  App Incubator Technologies Private Limited
# 5499                                       ZigUp
# 5500                         DIFX Technology LLC
# 5501                      Parsh Technologies LLP
#
#                               positionName  \
# 0          Associate Analyst - ERP Support
# 1     TECH SPECIALIST, SECURITY COMPLIANCE
# 2                     Indirect Tax Analyst
# 3           Financial Data Associate - MSC
# 4                  Quant Analytics Analyst
# ...                                    ...
# 5497                  Front End Developers
# 5498             iOS Application Developer
# 5499  Senior Software Engineer (Wordpress)
# 5500                           QA Engineer
# 5501                  Blockchain Developer
#
#                                             description  \
# 0     \n\n \n  \n   Company Description\n  \n  \n   ...
# 1     Security and compliance analyst that supports ...
# 2     \n Primary Responsibilities: \n \n \n  Run mul...
# 3     \n \n  \n   \n    \n     As a Financial Data A...
# 4     \n Description for Internal & External Candida...
# ...                                                 ...
# 5497  \n **We are hiring for Front End Mid-Level and...
# 5498  AppIncubator Technologies  - is an award-winni...
# 5499  \n\n PlotX New Delhi | 4~8y \n \n  \n   Full S...
# 5500  Job Opportunity – QA Engineer\nDIFX\nDIFX is t...
# 5501  We are looking for a highly capable blockchain...
#
#                              salary              location  rating  \
# 0                               NaN      Gurgaon, Haryana     3.9
# 1                               NaN  Hyderabad, Telangana     3.7
# 2                               NaN   Mumbai, Maharashtra     3.9
# 3                               NaN      Gurgaon, Haryana     3.6
# 4                               NaN  Bengaluru, Karnataka     3.9
# ...                             ...                   ...     ...
# 5497                            NaN  Bengaluru, Karnataka     NaN
# 5498  ₹5,00,000 - ₹15,00,000 a year  Hyderabad, Telangana     NaN
# 5499                            NaN      New Delhi, Delhi     NaN
# 5500                            NaN  Bengaluru, Karnataka     NaN
# 5501      ₹30,000 - ₹50,000 a month       Rajkot, Gujarat     NaN
#
#       reviewsCount      postedAt  \
# 0            211.0   Just posted
# 1          43942.0         Today
# 2          18023.0         Today
# 3            505.0         Today
# 4          18023.0         Today
# ...            ...           ...
# 5497           NaN  30+ days ago
# 5498           NaN  30+ days ago
# 5499           NaN  30+ days ago
# 5500           NaN  30+ days ago
# 5501           NaN  30+ days ago
#
#                                       externalApplyLink  \
# 0     https://in.indeed.com/applystart?jk=cc96b53863...
# 1     https://in.indeed.com/applystart?jk=5922b50e70...
# 2     https://in.indeed.com/applystart?jk=fdcc6c2892...
# 3     https://in.indeed.com/applystart?jk=21d74dd3fd...
# 4     https://in.indeed.com/applystart?jk=0236f8792c...
# ...                                                 ...
# 5497                                                NaN
# 5498                                                NaN
# 5499  https://in.indeed.com/applystart?jk=05a01b83b3...
# 5500                                                NaN
# 5501                                                NaN
#
#                                                     url  \
# 0     https://www.indeed.co.in/rc/clk?jk=cc96b538634...
# 1     https://www.indeed.co.in/rc/clk?jk=5922b50e707...
# 2     https://www.indeed.co.in/rc/clk?jk=fdcc6c28924...
# 3     https://www.indeed.co.in/rc/clk?jk=21d74dd3fd5...
# 4     https://www.indeed.co.in/rc/clk?jk=0236f8792c8...
# ...                                                 ...
# 5497  https://www.indeed.co.in/rc/clk?jk=6f09cfb2c5e...
# 5498  https://www.indeed.co.in/company/APP-INCUBATOR...
# 5499  https://www.indeed.co.in/rc/clk?jk=05a01b83b38...
# 5500  https://www.indeed.co.in/company/DIfX-Technolo...
# 5501  https://www.indeed.co.in/company/Parsh-Technol...
#
#                                                     All
# 0     Rambøll,Associate Analyst - ERP Support,\n\n \...
# 1     AT&T,TECH SPECIALIST, SECURITY COMPLIANCE,Secu...
# 2     JPMorgan Chase Bank, N.A.,Indirect Tax Analyst...
# 3     Moody's Corporation,Financial Data Associate -...
# 4     JPMorgan Chase Bank, N.A.,Quant Analytics Anal...
# ...                                                 ...
# 5497  Emurgo,Front End Developers,\n **We are hiring...
# 5498  App Incubator Technologies Private Limited,iOS...
# 5499  ZigUp,Senior Software Engineer (Wordpress),\n\...
# 5500  DIFX Technology LLC,QA Engineer,Job Opportunit...
# 5501  Parsh Technologies LLP,Blockchain Developer,We...
#
# [5502 rows x 11 columns]

# %%
df['All']
# Out:
# 0       Rambøll,Associate Analyst - ERP Support,\n\n \...
# 1       AT&T,TECH SPECIALIST, SECURITY COMPLIANCE,Secu...
# 2       JPMorgan Chase Bank, N.A.,Indirect Tax Analyst...
# 3       Moody's Corporation,Financial Data Associate -...
# 4       JPMorgan Chase Bank, N.A.,Quant Analytics Anal...
#                               ...
# 5497    Emurgo,Front End Developers,\n **We are hiring...
# 5498    App Incubator Technologies Private Limited,iOS...
# 5499    ZigUp,Senior Software Engineer (Wordpress),\n\...
# 5500    DIFX Technology LLC,QA Engineer,Job Opportunit...
# 5501    Parsh Technologies LLP,Blockchain Developer,We...
# Name: All, Length: 5502, dtype: object

# %%
df = df.replace(r'\n','', regex=True) 
df = df.replace(' ', '')
df.description = df.description.str.strip()
df.All = df.All.str.strip()

# %%
df
# Out:
#                                          company  \
# 0                                        Rambøll
# 1                                           AT&T
# 2                      JPMorgan Chase Bank, N.A.
# 3                            Moody's Corporation
# 4                      JPMorgan Chase Bank, N.A.
# ...                                          ...
# 5497                                      Emurgo
# 5498  App Incubator Technologies Private Limited
# 5499                                       ZigUp
# 5500                         DIFX Technology LLC
# 5501                      Parsh Technologies LLP
#
#                               positionName  \
# 0          Associate Analyst - ERP Support
# 1     TECH SPECIALIST, SECURITY COMPLIANCE
# 2                     Indirect Tax Analyst
# 3           Financial Data Associate - MSC
# 4                  Quant Analytics Analyst
# ...                                    ...
# 5497                  Front End Developers
# 5498             iOS Application Developer
# 5499  Senior Software Engineer (Wordpress)
# 5500                           QA Engineer
# 5501                  Blockchain Developer
#
#                                             description  \
# 0     Company Description        Ramboll has more th...
# 1     Security and compliance analyst that supports ...
# 2     Primary Responsibilities:     Run multiple rep...
# 3     As a Financial Data Associate, you will work i...
# 4     Description for Internal & External Candidates...
# ...                                                 ...
# 5497  **We are hiring for Front End Mid-Level and Le...
# 5498  AppIncubator Technologies  - is an award-winni...
# 5499  PlotX New Delhi | 4~8y       Full Stack       ...
# 5500  Job Opportunity – QA EngineerDIFXDIFX is the w...
# 5501  We are looking for a highly capable blockchain...
#
#                              salary              location  rating  \
# 0                               NaN      Gurgaon, Haryana     3.9
# 1                               NaN  Hyderabad, Telangana     3.7
# 2                               NaN   Mumbai, Maharashtra     3.9
# 3                               NaN      Gurgaon, Haryana     3.6
# 4                               NaN  Bengaluru, Karnataka     3.9
# ...                             ...                   ...     ...
# 5497                            NaN  Bengaluru, Karnataka     NaN
# 5498  ₹5,00,000 - ₹15,00,000 a year  Hyderabad, Telangana     NaN
# 5499                            NaN      New Delhi, Delhi     NaN
# 5500                            NaN  Bengaluru, Karnataka     NaN
# 5501      ₹30,000 - ₹50,000 a month       Rajkot, Gujarat     NaN
#
#       reviewsCount      postedAt  \
# 0            211.0   Just posted
# 1          43942.0         Today
# 2          18023.0         Today
# 3            505.0         Today
# 4          18023.0         Today
# ...            ...           ...
# 5497           NaN  30+ days ago
# 5498           NaN  30+ days ago
# 5499           NaN  30+ days ago
# 5500           NaN  30+ days ago
# 5501           NaN  30+ days ago
#
#                                       externalApplyLink  \
# 0     https://in.indeed.com/applystart?jk=cc96b53863...
# 1     https://in.indeed.com/applystart?jk=5922b50e70...
# 2     https://in.indeed.com/applystart?jk=fdcc6c2892...
# 3     https://in.indeed.com/applystart?jk=21d74dd3fd...
# 4     https://in.indeed.com/applystart?jk=0236f8792c...
# ...                                                 ...
# 5497                                                NaN
# 5498                                                NaN
# 5499  https://in.indeed.com/applystart?jk=05a01b83b3...
# 5500                                                NaN
# 5501                                                NaN
#
#                                                     url  \
# 0     https://www.indeed.co.in/rc/clk?jk=cc96b538634...
# 1     https://www.indeed.co.in/rc/clk?jk=5922b50e707...
# 2     https://www.indeed.co.in/rc/clk?jk=fdcc6c28924...
# 3     https://www.indeed.co.in/rc/clk?jk=21d74dd3fd5...
# 4     https://www.indeed.co.in/rc/clk?jk=0236f8792c8...
# ...                                                 ...
# 5497  https://www.indeed.co.in/rc/clk?jk=6f09cfb2c5e...
# 5498  https://www.indeed.co.in/company/APP-INCUBATOR...
# 5499  https://www.indeed.co.in/rc/clk?jk=05a01b83b38...
# 5500  https://www.indeed.co.in/company/DIfX-Technolo...
# 5501  https://www.indeed.co.in/company/Parsh-Technol...
#
#                                                     All
# 0     Rambøll,Associate Analyst - ERP Support,      ...
# 1     AT&T,TECH SPECIALIST, SECURITY COMPLIANCE,Secu...
# 2     JPMorgan Chase Bank, N.A.,Indirect Tax Analyst...
# 3     Moody's Corporation,Financial Data Associate -...
# 4     JPMorgan Chase Bank, N.A.,Quant Analytics Anal...
# ...                                                 ...
# 5497  Emurgo,Front End Developers, **We are hiring f...
# 5498  App Incubator Technologies Private Limited,iOS...
# 5499  ZigUp,Senior Software Engineer (Wordpress), Pl...
# 5500  DIFX Technology LLC,QA Engineer,Job Opportunit...
# 5501  Parsh Technologies LLP,Blockchain Developer,We...
#
# [5502 rows x 11 columns]

# %% [markdown]
# # Put keywords of the CV into a dataframe

# %%
df2 = pd.DataFrame()
# append columns to an empty DataFrame
df2['title'] = ["I"]
df2['job highlights'] = ["I"]
df2['job description'] = ["I"]
df2['company overview'] = ["I"]
df2['industry'] = ["I"]

# Compare with the key words from CV only
df2['All'] = " ".join(key_word)

# %%
df2
# Out:
#   title job highlights job description company overview industry  \
# 0     I              I               I                I        I
#
#                                                  All
# 0  eld data ne-tuning pre-trained . transformer...

# %%
df.columns
# Out:
# Index(['company', 'positionName', 'description', 'salary', 'location',
#        'rating', 'reviewsCount', 'postedAt', 'externalApplyLink', 'url',
#        'All'],
#       dtype='object')

# %% [markdown]
# # Recomendation Function

# %% [markdown]
# #klnsdsd

# %%
def get_recommendation(top, df_all, scores):
    recommendation = pd.DataFrame(columns = ['positionName', 'company',"location", 'rating' 'description','score'])
    count = 0
    for i in top:
#         recommendation.at[count, 'ApplicantID'] = u
        
        recommendation.at[count, 'positionName'] = df['positionName'][i]
        recommendation.at[count, 'company'] = df['company'][i]
        recommendation.at[count, 'location'] = df['location'][i]
        recommendation.at[count, 'rating'] = df['rating'][i]
        recommendation.at[count, 'description'] = df['description'][i]
        recommendation.at[count, 'score'] =  scores[count]
        count += 1
    return recommendation

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer


def TFIDF(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # TF-IDF Scraped data
    tfidf_jobid = tfidf_vectorizer.fit_transform(scraped_data)

    # TF-IDF CV
    user_tfidf = tfidf_vectorizer.transform(cv)

    # Using cosine_similarity on (Scraped data) & (CV)
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)

    output2 = list(cos_similarity_tfidf)
    return output2
    
output2 = TFIDF(df['All'], df2['All'])

# %%
output2
# Out:
# [array([[0.02514581]]),
#  array([[0.02499205]]),
#  array([[0.02500962]]),
#  array([[0.0310437]]),
#  array([[0.03355642]]),
#  array([[0.0962123]]),
#  array([[0.01743493]]),
#  array([[0.03305435]]),
#  array([[0.04056072]]),
#  array([[0.0316218]]),
#  array([[0.01100881]]),
#  array([[0.03062406]]),
#  array([[0.02879082]]),
#  array([[0.05634831]]),
#  array([[0.03093038]]),
#  array([[0.03119468]]),
#  array([[0.06054285]]),
#  array([[0.03905109]]),
#  array([[0.07699498]]),
#  array([[0.0266674]]),
#  array([[0.02688439]]),
#  array([[0.01767505]]),
#  array([[0.03166086]]),
#  array([[0.0347697]]),
#  array([[0.03173996]]),
#  array([[0.03885379]]),
#  array([[0.01767192]]),
#  array([[0.02104544]]),
#  array([[0.0279169]]),
#  array([[0.04800697]]),
#  array([[0.03339547]]),
#  array([[0.02581638]]),
#  array([[0.02774557]]),
#  array([[0.04270864]]),
#  array([[0.01939521]]),
#  array([[0.10005561]]),
#  array([[0.03673633]]),
#  array([[0.02822499]]),
#  array([[0.00651427]]),
#  array([[0.02318502]]),
#  array([[0.03626335]]),
#  array([[0.03161337]]),
#  array([[0.04210522]]),
#  array([[0.0336087]]),
#  array([[0.02421598]]),
#  array([[0.02107883]]),
#  array([[0.01264785]]),
#  array([[0.03481509]]),
#  array([[0.06252662]]),
#  array([[0.02783145]]),
#  array([[0.02849412]]),
#  array([[0.04445446]]),
#  array([[0.01768103]]),
#  array([[0.02297996]]),
#  array([[0.02644195]]),
#  array([[0.02815667]]),
#  array([[0.03899064]]),
#  array([[0.02483279]]),
#  array([[0.01501606]]),
#  array([[0.0160863]]),
#  array([[0.03489102]]),
#  array([[0.02827223]]),
#  array([[0.03295708]]),
#  array([[0.02702395]]),
#  array([[0.0366478]]),
#  array([[0.03924125]]),
#  array([[0.04127532]]),
#  array([[0.02339135]]),
#  array([[0.03205898]]),
#  array([[0.02838109]]),
#  array([[0.01387954]]),
#  array([[0.02537908]]),
#  array([[0.02823175]]),
#  array([[0.01891228]]),
#  array([[0.01651419]]),
#  array([[0.02147425]]),
#  array([[0.04892677]]),
#  array([[0.04495528]]),
#  array([[0.02782202]]),
#  array([[0.03777129]]),
#  array([[0.03804989]]),
#  array([[0.02793293]]),
#  array([[0.00736535]]),
#  array([[0.02054978]]),
#  array([[0.02467549]]),
#  array([[0.01817073]]),
#  array([[0.02039931]]),
#  array([[0.03545894]]),
#  array([[0.01980587]]),
#  array([[0.02800176]]),
#  array([[0.05640418]]),
#  array([[0.01344883]]),
#  array([[0.03128626]]),
#  array([[0.03800549]]),
#  array([[0.0101659]]),
#  array([[0.03224272]]),
#  array([[0.0159715]]),
#  array([[0.06432358]]),
#  array([[0.03391417]]),
#  array([[0.0406195]]),
#  array([[0.02500815]]),
#  array([[0.02817529]]),
#  array([[0.02239604]]),
#  array([[0.024833]]),
#  array([[0.01848377]]),
#  array([[0.01741976]]),
#  array([[0.02073694]]),
#  array([[0.01871169]]),
#  array([[0.03126512]]),
#  array([[0.02756906]]),
#  array([[0.0088567]]),
#  array([[0.03970416]]),
#  array([[0.02783464]]),
#  array([[0.02363308]]),
#  array([[0.01938989]]),
#  array([[0.00784692]]),
#  array([[0.04779136]]),
#  array([[0.04968748]]),
#  array([[0.02959199]]),
#  array([[0.01590828]]),
#  array([[0.0379773]]),
#  array([[0.0379186]]),
#  array([[0.02595086]]),
#  array([[0.01628265]]),
#  array([[0.02779694]]),
#  array([[0.04061653]]),
#  array([[0.01842944]]),
#  array([[0.11885465]]),
#  array([[0.0228796]]),
#  array([[0.04162291]]),
#  array([[0.04421033]]),
#  array([[0.05821751]]),
#  array([[0.00996592]]),
#  array([[0.03164195]]),
#  array([[0.03737252]]),
#  array([[0.03504411]]),
#  array([[0.01421268]]),
#  array([[0.04315148]]),
#  array([[0.01572893]]),
#  array([[0.02390598]]),
#  array([[0.03822758]]),
#  array([[0.02099757]]),
#  array([[0.0232164]]),
#  array([[0.03980081]]),
#  array([[0.02900948]]),
#  array([[0.0159871]]),
#  array([[0.03409529]]),
#  array([[0.02326073]]),
#  array([[0.05167888]]),
#  array([[0.04015926]]),
#  array([[0.02394131]]),
#  array([[0.02321829]]),
#  array([[0.0220253]]),
#  array([[0.02413216]]),
#  array([[0.02847987]]),
#  array([[0.0154566]]),
#  array([[0.03664897]]),
#  array([[0.02106449]]),
#  array([[0.02543339]]),
#  array([[0.12468505]]),
#  array([[0.02735566]]),
#  array([[0.03401861]]),
#  array([[0.02498629]]),
#  array([[0.03618357]]),
#  array([[0.03414111]]),
#  array([[0.06191257]]),
#  array([[0.04171479]]),
#  array([[0.05157979]]),
#  array([[0.06327297]]),
#  array([[0.02503446]]),
#  array([[0.02524207]]),
#  array([[0.01780346]]),
#  array([[0.01292942]]),
#  array([[0.0335422]]),
#  array([[0.04531088]]),
#  array([[0.01062952]]),
#  array([[0.01947404]]),
#  array([[0.04017002]]),
#  array([[0.02351399]]),
#  array([[0.02678093]]),
#  array([[0.02062672]]),
#  array([[0.05820025]]),
#  array([[0.0284365]]),
#  array([[0.04296347]]),
#  array([[0.0192423]]),
#  array([[0.01938007]]),
#  array([[0.03172283]]),
#  array([[0.01219952]]),
#  array([[0.03850002]]),
#  array([[0.0182546]]),
#  array([[0.02461408]]),
#  array([[0.0318194]]),
#  array([[0.02346876]]),
#  array([[0.0316568]]),
#  array([[0.02180115]]),
#  array([[0.02495387]]),
#  array([[0.01276636]]),
#  array([[0.02508639]]),
#  array([[0.02316203]]),
#  array([[0.02418403]]),
#  array([[0.03164803]]),
#  array([[0.03292778]]),
#  array([[0.03324303]]),
#  array([[0.02898426]]),
#  array([[0.03003206]]),
#  array([[0.02375498]]),
#  array([[0.02216986]]),
#  array([[0.0303429]]),
#  array([[0.02429923]]),
#  array([[0.05596482]]),
#  array([[0.02809277]]),
#  array([[0.00979649]]),
#  array([[0.02271363]]),
#  array([[0.02120039]]),
#  array([[0.04105283]]),
#  array([[0.03638599]]),
#  array([[0.02111435]]),
#  array([[0.0463363]]),
#  array([[0.037025]]),
#  array([[0.02437798]]),
#  array([[0.0181568]]),
#  array([[0.0088088]]),
#  array([[0.04579936]]),
#  array([[0.02023548]]),
#  array([[0.02382335]]),
#  array([[0.02346471]]),
#  array([[0.08264171]]),
#  array([[0.0229329]]),
#  array([[0.08631029]]),
#  array([[0.02980447]]),
#  array([[0.02647093]]),
#  array([[0.03469351]]),
#  array([[0.03086883]]),
#  array([[0.0150666]]),
#  array([[0.02463475]]),
#  array([[0.02673714]]),
#  array([[0.02896687]]),
#  array([[0.03864061]]),
#  array([[0.05089102]]),
#  array([[0.02106069]]),
#  array([[0.02453103]]),
#  array([[0.02988056]]),
#  array([[0.01620457]]),
#  array([[0.01228474]]),
#  array([[0.0124909]]),
#  array([[0.04192348]]),
#  array([[0.02062971]]),
#  array([[0.01076781]]),
#  array([[0.02049594]]),
#  array([[0.01878502]]),
#  array([[0.02702054]]),
#  array([[0.05492958]]),
#  array([[0.0434128]]),
#  array([[0.00814547]]),
#  array([[0.03128547]]),
#  array([[0.0470928]]),
#  array([[0.01889475]]),
#  array([[0.02428565]]),
#  array([[0.02832518]]),
#  array([[0.03780096]]),
#  array([[0.02527519]]),
#  array([[0.03275189]]),
#  array([[0.08525478]]),
#  array([[0.03061561]]),
#  array([[0.0082501]]),
#  array([[0.0530858]]),
#  array([[0.02862166]]),
#  array([[0.01401568]]),
#  array([[0.02206163]]),
#  array([[0.04403775]]),
#  array([[0.03923405]]),
#  array([[0.02175956]]),
#  array([[0.04634575]]),
#  array([[0.01755963]]),
#  array([[0.02513082]]),
#  array([[0.02992691]]),
#  array([[0.04195305]]),
#  array([[0.02470813]]),
#  array([[0.04777627]]),
#  array([[0.03166912]]),
#  array([[0.08168199]]),
#  array([[0.02632148]]),
#  array([[0.02493058]]),
#  array([[0.02727777]]),
#  array([[0.03377375]]),
#  array([[0.01736002]]),
#  array([[0.02929646]]),
#  array([[0.04426493]]),
#  array([[0.05212097]]),
#  array([[0.05719288]]),
#  array([[0.0441657]]),
#  array([[0.05918611]]),
#  array([[0.03246261]]),
#  array([[0.04468542]]),
#  array([[0.02562233]]),
#  array([[0.0319433]]),
#  array([[0.02110102]]),
#  array([[0.0386127]]),
#  array([[0.03133613]]),
#  array([[0.01929358]]),
#  array([[0.06565626]]),
#  array([[0.04122772]]),
#  array([[0.03350788]]),
#  array([[0.04136106]]),
#  array([[0.03119212]]),
#  array([[0.07578853]]),
#  array([[0.01867215]]),
#  array([[0.0254725]]),
#  array([[0.02597259]]),
#  array([[0.03322722]]),
#  array([[0.06646433]]),
#  array([[0.08485129]]),
#  array([[0.06609928]]),
#  array([[0.03573125]]),
#  array([[0.0315507]]),
#  array([[0.03639237]]),
#  array([[0.04818467]]),
#  array([[0.01337286]]),
#  array([[0.02067175]]),
#  array([[0.03755888]]),
#  array([[0.08720742]]),
#  array([[0.02206048]]),
#  array([[0.01565592]]),
#  array([[0.02689403]]),
#  array([[0.01783337]]),
#  array([[0.02053358]]),
#  array([[0.01510571]]),
#  array([[0.01636439]]),
#  array([[0.0309041]]),
#  array([[0.10785071]]),
#  array([[0.03382037]]),
#  array([[0.02999512]]),
#  array([[0.03810077]]),
#  array([[0.02512328]]),
#  array([[0.02187994]]),
#  array([[0.03344113]]),
#  array([[0.02013925]]),
#  array([[0.05853453]]),
#  array([[0.00939889]]),
#  array([[0.03059675]]),
#  array([[0.03231695]]),
#  array([[0.10365056]]),
#  array([[0.02393938]]),
#  array([[0.04288878]]),
#  array([[0.03877541]]),
#  array([[0.02223981]]),
#  array([[0.04283148]]),
#  array([[0.05438506]]),
#  array([[0.03504824]]),
#  array([[0.01214187]]),
#  array([[0.03751799]]),
#  array([[0.02666471]]),
#  array([[0.05008862]]),
#  array([[0.04039144]]),
#  array([[0.04592003]]),
#  array([[0.02698304]]),
#  array([[0.06329242]]),
#  array([[0.03036636]]),
#  array([[0.01975013]]),
#  array([[0.02911539]]),
#  array([[0.02795804]]),
#  array([[0.02434253]]),
#  array([[0.02021511]]),
#  array([[0.12573565]]),
#  array([[0.03655086]]),
#  array([[0.03768818]]),
#  array([[0.04830788]]),
#  array([[0.02206543]]),
#  array([[0.01752812]]),
#  array([[0.00847773]]),
#  array([[0.02433698]]),
#  array([[0.0391799]]),
#  array([[0.02312718]]),
#  array([[0.02646845]]),
#  array([[0.0285082]]),
#  array([[0.02204126]]),
#  array([[0.02273337]]),
#  array([[0.03816463]]),
#  array([[0.0427659]]),
#  array([[0.02008457]]),
#  array([[0.04037129]]),
#  array([[0.01717497]]),
#  array([[0.04345686]]),
#  array([[0.00677546]]),
#  array([[0.03426176]]),
#  array([[0.09044221]]),
#  array([[0.03151274]]),
#  array([[0.02387077]]),
#  array([[0.0264098]]),
#  array([[0.03356032]]),
#  array([[0.02421223]]),
#  array([[0.02744355]]),
#  array([[0.03040216]]),
#  array([[0.01614346]]),
#  array([[0.02927699]]),
#  array([[0.02913047]]),
#  array([[0.03271044]]),
#  array([[0.03539477]]),
#  array([[0.0377515]]),
#  array([[0.02297403]]),
#  array([[0.07568902]]),
#  array([[0.02729334]]),
#  array([[0.17268689]]),
#  array([[0.03233102]]),
#  array([[0.027189]]),
#  array([[0.03415716]]),
#  array([[0.0302591]]),
#  array([[0.02849171]]),
#  array([[0.03263442]]),
#  array([[0.03675298]]),
#  array([[0.0176049]]),
#  array([[0.03097645]]),
#  array([[0.02464485]]),
#  array([[0.05095715]]),
#  array([[0.01751486]]),
#  array([[0.01996564]]),
#  array([[0.0262244]]),
#  array([[0.03440316]]),
#  array([[0.02458802]]),
#  array([[0.03644515]]),
#  array([[0.00912217]]),
#  array([[0.07163641]]),
#  array([[0.03162788]]),
#  array([[0.01588591]]),
#  array([[0.08177768]]),
#  array([[0.04244047]]),
#  array([[0.09655211]]),
#  array([[0.03374885]]),
#  array([[0.03610917]]),
#  array([[0.03062282]]),
#  array([[0.05562494]]),
#  array([[0.02074884]]),
#  array([[0.03402475]]),
#  array([[0.02537452]]),
#  array([[0.05187345]]),
#  array([[0.06569112]]),
#  array([[0.03650206]]),
#  array([[0.07847511]]),
#  array([[0.03049556]]),
#  array([[0.045393]]),
#  array([[0.03403112]]),
#  array([[0.01395352]]),
#  array([[0.05138931]]),
#  array([[0.02060006]]),
#  array([[0.04451419]]),
#  array([[0.05103674]]),
#  array([[0.02809153]]),
#  array([[0.02820149]]),
#  array([[0.04244728]]),
#  array([[0.03039942]]),
#  array([[0.01979303]]),
#  array([[0.04213334]]),
#  array([[0.03104314]]),
#  array([[0.04936266]]),
#  array([[0.02752553]]),
#  array([[0.02358615]]),
#  array([[0.02316504]]),
#  array([[0.0600441]]),
#  array([[0.02503519]]),
#  array([[0.04854773]]),
#  array([[0.02672402]]),
#  array([[0.05699389]]),
#  array([[0.02016794]]),
#  array([[0.06558339]]),
#  array([[0.03384041]]),
#  array([[0.04001118]]),
#  array([[0.05740436]]),
#  array([[0.05326502]]),
#  array([[0.05636465]]),
#  array([[0.08209779]]),
#  array([[0.01958228]]),
#  array([[0.05176569]]),
#  array([[0.05404811]]),
#  array([[0.03150834]]),
#  array([[0.02011033]]),
#  array([[0.022289]]),
#  array([[0.02425389]]),
#  array([[0.01590632]]),
#  array([[0.0215195]]),
#  array([[0.05709659]]),
#  array([[0.04056736]]),
#  array([[0.01436364]]),
#  array([[0.01920658]]),
#  array([[0.02477277]]),
#  array([[0.02231042]]),
#  array([[0.02693434]]),
#  array([[0.0140929]]),
#  array([[0.02707198]]),
#  array([[0.01725115]]),
#  array([[0.02386469]]),
#  array([[0.03336225]]),
#  array([[0.02471933]]),
#  array([[0.0323062]]),
#  array([[0.02978387]]),
#  array([[0.05438499]]),
#  array([[0.04662848]]),
#  array([[0.01428649]]),
#  array([[0.0170878]]),
#  array([[0.02035418]]),
#  array([[0.01445286]]),
#  array([[0.0269284]]),
#  array([[0.01930851]]),
#  array([[0.02382813]]),
#  array([[0.02783997]]),
#  array([[0.01452215]]),
#  array([[0.01760858]]),
#  array([[0.03277736]]),
#  array([[0.03305688]]),
#  array([[0.01661509]]),
#  array([[0.00792199]]),
#  array([[0.02846548]]),
#  array([[0.02885748]]),
#  array([[0.00694789]]),
#  array([[0.01487303]]),
#  array([[0.02399546]]),
#  array([[0.01552277]]),
#  array([[0.01794135]]),
#  array([[0.04741841]]),
#  array([[0.0347697]]),
#  array([[0.0291926]]),
#  array([[0.02027119]]),
#  array([[0.03282464]]),
#  array([[0.01163797]]),
#  array([[0.02184624]]),
#  array([[0.02211305]]),
#  array([[0.01451174]]),
#  array([[0.02141138]]),
#  array([[0.0185788]]),
#  array([[0.02123213]]),
#  array([[0.02865794]]),
#  array([[0.03527391]]),
#  array([[0.00966824]]),
#  array([[0.01737512]]),
#  array([[0.01764526]]),
#  array([[0.0151818]]),
#  array([[0.01888543]]),
#  array([[0.04383757]]),
#  array([[0.00609213]]),
#  array([[0.01028612]]),
#  array([[0.00231119]]),
#  array([[0.0332307]]),
#  array([[0.03112404]]),
#  array([[0.00137042]]),
#  array([[0.03307089]]),
#  array([[0.0174388]]),
#  array([[0.04076051]]),
#  array([[0.03173996]]),
#  array([[0.0404822]]),
#  array([[0.02782293]]),
#  array([[0.00644783]]),
#  array([[0.02275945]]),
#  array([[0.01026874]]),
#  array([[0.02825005]]),
#  array([[0.02418472]]),
#  array([[0.02106521]]),
#  array([[0.03498799]]),
#  array([[0.01653355]]),
#  array([[0.02414498]]),
#  array([[0.01795749]]),
#  array([[0.03579654]]),
#  array([[0.01096497]]),
#  array([[0.00587761]]),
#  array([[0.01438096]]),
#  array([[0.01119979]]),
#  array([[0.03161337]]),
#  array([[0.00520858]]),
#  array([[0.02498312]]),
#  array([[0.0300258]]),
#  array([[0.01470636]]),
#  array([[0.02104395]]),
#  array([[0.03396769]]),
#  array([[0.01798708]]),
#  array([[0.0374778]]),
#  array([[0.00512081]]),
#  array([[0.02055538]]),
#  array([[0.02422782]]),
#  array([[0.04714999]]),
#  array([[0.03784318]]),
#  array([[0.01542576]]),
#  array([[0.03896137]]),
#  array([[0.03358879]]),
#  array([[0.01649296]]),
#  array([[0.02237967]]),
#  array([[0.01686208]]),
#  array([[0.03820958]]),
#  array([[0.01787536]]),
#  array([[0.00319872]]),
#  array([[0.02080988]]),
#  array([[0.03815964]]),
#  array([[0.01402503]]),
#  array([[0.01541206]]),
#  array([[0.02494225]]),
#  array([[0.01183289]]),
#  array([[0.04581288]]),
#  array([[0.14194861]]),
#  array([[0.0290188]]),
#  array([[0.04358642]]),
#  array([[0.0327605]]),
#  array([[0.01140443]]),
#  array([[0.02267986]]),
#  array([[0.0386133]]),
#  array([[0.0421039]]),
#  array([[0.00661647]]),
#  array([[0.0320155]]),
#  array([[0.03199631]]),
#  array([[0.045731]]),
#  array([[0.04450467]]),
#  array([[0.02903515]]),
#  array([[0.03673633]]),
#  array([[0.03312831]]),
#  array([[0.04472435]]),
#  array([[0.03339547]]),
#  array([[0.03678917]]),
#  array([[0.02515215]]),
#  array([[0.00751231]]),
#  array([[0.03478462]]),
#  array([[0.03497402]]),
#  array([[0.10008624]]),
#  array([[0.00568832]]),
#  array([[0.01598589]]),
#  array([[0.02570445]]),
#  array([[0.00862838]]),
#  array([[0.01796856]]),
#  array([[0.03187388]]),
#  array([[0.02326725]]),
#  array([[0.02849412]]),
#  array([[0.01720435]]),
#  array([[0.02161812]]),
#  array([[0.02783464]]),
#  array([[0.02849077]]),
#  array([[0.02203525]]),
#  array([[0.01863666]]),
#  array([[0.00690943]]),
#  array([[0.04710952]]),
#  array([[0.01545103]]),
#  array([[0.03676173]]),
#  array([[0.00661501]]),
#  array([[0.05197325]]),
#  array([[0.02949211]]),
#  array([[0.02848]]),
#  array([[0.01911444]]),
#  array([[0.02816246]]),
#  array([[0.03555616]]),
#  array([[0.0350746]]),
#  array([[0.02739071]]),
#  array([[0.02252509]]),
#  array([[0.02350038]]),
#  array([[0.01861213]]),
#  array([[0.02108529]]),
#  array([[0.0232721]]),
#  array([[0.02940375]]),
#  array([[0.02962947]]),
#  array([[0.02849199]]),
#  array([[0.00843338]]),
#  array([[0.01494013]]),
#  array([[0.0104804]]),
#  array([[0.02625664]]),
#  array([[0.02188172]]),
#  array([[0.02620462]]),
#  array([[0.00804096]]),
#  array([[0.01872916]]),
#  array([[0.01308851]]),
#  array([[0.03803225]]),
#  array([[0.03498194]]),
#  array([[0.03759342]]),
#  array([[0.0317925]]),
#  array([[0.04421033]]),
#  array([[0.01559354]]),
#  array([[0.01074641]]),
#  array([[0.0129792]]),
#  array([[0.02764693]]),
#  array([[0.03855125]]),
#  array([[0.03411127]]),
#  array([[0.03126201]]),
#  array([[0.03294945]]),
#  array([[0.01303768]]),
#  array([[0.02996058]]),
#  array([[0.0144838]]),
#  array([[0.02340873]]),
#  array([[0.01176904]]),
#  array([[0.0254962]]),
#  array([[0.01778381]]),
#  array([[0.03307414]]),
#  array([[0.01722908]]),
#  array([[0.01204945]]),
#  array([[0.02816445]]),
#  array([[0.01709455]]),
#  array([[0.02068648]]),
#  array([[0.01019832]]),
#  array([[0.03400801]]),
#  array([[0.02691551]]),
#  array([[0.05815429]]),
#  array([[0.02255923]]),
#  array([[0.02645615]]),
#  array([[0.01352395]]),
#  array([[0.04316402]]),
#  array([[0.0168221]]),
#  array([[0.02053365]]),
#  array([[0.03077494]]),
#  array([[0.0175002]]),
#  array([[0.02140859]]),
#  array([[0.0368476]]),
#  array([[0.03128626]]),
#  array([[0.01768953]]),
#  array([[0.00878027]]),
#  array([[0.00900984]]),
#  array([[0.00849312]]),
#  array([[0.02517099]]),
#  array([[0.0210651]]),
#  array([[0.02633747]]),
#  array([[0.01507327]]),
#  array([[0.01753501]]),
#  array([[0.02157211]]),
#  array([[0.02444673]]),
#  array([[0.02099757]]),
#  array([[0.02150463]]),
#  array([[0.0266129]]),
#  array([[0.01328486]]),
#  array([[0.02404521]]),
#  array([[0.02470084]]),
#  array([[0.02530761]]),
#  array([[0.02908134]]),
#  array([[0.04133877]]),
#  array([[0.01811016]]),
#  array([[0.03898628]]),
#  array([[0.01896111]]),
#  array([[0.06403308]]),
#  array([[0.02371691]]),
#  array([[0.03322676]]),
#  array([[0.00802664]]),
#  array([[0.03149194]]),
#  array([[0.04994119]]),
#  array([[0.03863099]]),
#  array([[0.02537908]]),
#  array([[0.00811224]]),
#  array([[0.02900948]]),
#  array([[0.02491184]]),
#  array([[0.03169633]]),
#  array([[0.01899327]]),
#  array([[0.02086139]]),
#  array([[0.04015926]]),
#  array([[0.02565565]]),
#  array([[0.03547581]]),
#  array([[0.01966926]]),
#  array([[0.02426231]]),
#  array([[0.03692949]]),
#  array([[0.03704413]]),
#  array([[0.02814982]]),
#  array([[0.01806079]]),
#  array([[0.0140867]]),
#  array([[0.02499025]]),
#  array([[0.04276008]]),
#  array([[0.01320416]]),
#  array([[0.01767615]]),
#  array([[0.04642876]]),
#  array([[0.00827736]]),
#  array([[0.01217838]]),
#  array([[0.01226673]]),
#  array([[0.02273242]]),
#  array([[0.02463502]]),
#  array([[0.03261273]]),
#  array([[0.01892458]]),
#  array([[0.01349511]]),
#  array([[0.02126833]]),
#  array([[0.01815102]]),
#  array([[0.02413415]]),
#  array([[0.00391722]]),
#  array([[0.02492335]]),
#  array([[0.03967814]]),
#  array([[0.0224099]]),
#  array([[0.02140124]]),
#  array([[0.01671404]]),
#  array([[0.03575378]]),
#  array([[0.02929645]]),
#  array([[0.01238351]]),
#  array([[0.0402156]]),
#  array([[0.02504514]]),
#  array([[0.01813893]]),
#  array([[0.01920152]]),
#  array([[0.01855972]]),
#  array([[0.00934074]]),
#  array([[0.02882527]]),
#  array([[0.01863846]]),
#  array([[0.01687488]]),
#  array([[0.02575892]]),
#  array([[0.02503623]]),
#  array([[0.0026566]]),
#  array([[0.01812275]]),
#  array([[0.02262789]]),
#  array([[0.01279897]]),
#  array([[0.0274298]]),
#  array([[0.00575353]]),
#  array([[0.06188446]]),
#  array([[0.0366478]]),
#  array([[0.15467678]]),
#  array([[0.00983821]]),
#  array([[0.02582448]]),
#  array([[0.02469189]]),
#  array([[0.01148465]]),
#  array([[0.02694495]]),
#  array([[0.03345113]]),
#  array([[0.02447824]]),
#  array([[0.03355196]]),
#  array([[0.01766573]]),
#  array([[0.01228755]]),
#  array([[0.01337329]]),
#  array([[0.02462724]]),
#  array([[0.02779008]]),
#  array([[0.01971485]]),
#  array([[0.01984845]]),
#  array([[0.01133928]]),
#  array([[0.03451384]]),
#  array([[0.02764308]]),
#  array([[0.0126161]]),
#  array([[0.02203229]]),
#  array([[0.02166786]]),
#  array([[0.01978706]]),
#  array([[0.01050819]]),
#  array([[0.0307759]]),
#  array([[0.02142101]]),
#  array([[0.03188541]]),
#  array([[0.03440886]]),
#  array([[0.05487372]]),
#  array([[0.01468312]]),
#  array([[0.00908055]]),
#  array([[0.01380058]]),
#  array([[0.0151036]]),
#  array([[0.02823175]]),
#  array([[0.01507074]]),
#  array([[0.02807375]]),
#  array([[0.03459034]]),
#  array([[0.04246034]]),
#  array([[0.02949819]]),
#  array([[0.02029373]]),
#  array([[0.04079673]]),
#  array([[0.02139497]]),
#  array([[0.0325517]]),
#  array([[0.03849179]]),
#  array([[0.01431798]]),
#  array([[0.01965444]]),
#  array([[0.01296217]]),
#  array([[0.01825719]]),
#  array([[0.02281926]]),
#  array([[0.02204166]]),
#  array([[0.02595086]]),
#  array([[0.02571625]]),
#  array([[0.00707911]]),
#  array([[0.02321209]]),
#  array([[0.03003955]]),
#  array([[0.03496381]]),
#  array([[0.06657818]]),
#  array([[0.01795199]]),
#  array([[0.04073953]]),
#  array([[0.02346054]]),
#  array([[0.00474104]]),
#  array([[0.01444787]]),
#  array([[0.01645022]]),
#  array([[0.02392275]]),
#  array([[0.00841916]]),
#  array([[0.03318898]]),
#  array([[0.02152795]]),
#  array([[0.0330619]]),
#  array([[0.04972145]]),
#  array([[0.0294442]]),
#  array([[0.01400306]]),
#  array([[0.03065035]]),
#  array([[0.03309632]]),
#  array([[0.04200299]]),
#  array([[0.01059042]]),
#  array([[0.01319322]]),
#  array([[0.03543894]]),
#  array([[0.01215823]]),
#  array([[0.03542743]]),
#  array([[0.01377156]]),
#  array([[0.0361925]]),
#  array([[0.04062239]]),
#  array([[0.02092966]]),
#  array([[0.00564191]]),
#  array([[0.0168197]]),
#  array([[0.04392533]]),
#  array([[0.03520925]]),
#  array([[0.02939258]]),
#  array([[0.00682422]]),
#  array([[0.04018366]]),
#  array([[0.01304855]]),
#  array([[0.0379773]]),
#  array([[0.03825327]]),
#  array([[0.01438698]]),
#  array([[0.06252662]]),
#  array([[0.02692741]]),
#  array([[0.02604292]]),
#  array([[0.02744726]]),
#  array([[0.01228279]]),
#  array([[0.02382357]]),
#  array([[0.03663969]]),
#  array([[0.02523655]]),
#  array([[0.03928764]]),
#  array([[0.02410505]]),
#  array([[0.0152512]]),
#  array([[0.04426825]]),
#  array([[0.02642108]]),
#  array([[0.0237749]]),
#  array([[0.03948741]]),
#  array([[0.0293091]]),
#  array([[0.01774322]]),
#  array([[0.0262353]]),
#  array([[0.04842965]]),
#  array([[0.03490408]]),
#  array([[0.02545901]]),
#  array([[0.02800176]]),
#  array([[0.01743115]]),
#  array([[0.03391017]]),
#  array([[0.03147629]]),
#  array([[0.01379022]]),
#  array([[0.01241895]]),
#  array([[0.04820055]]),
#  array([[0.03414111]]),
#  array([[0.01648867]]),
#  array([[0.01951627]]),
#  array([[0.01355726]]),
#  array([[0.0433266]]),
#  array([[0.02506238]]),
#  array([[0.06506237]]),
#  array([[0.03312252]]),
#  array([[0.02892344]]),
#  array([[0.02431328]]),
#  array([[0.02429627]]),
#  array([[0.01947144]]),
#  array([[0.01775679]]),
#  array([[0.02158686]]),
#  array([[0.02890723]]),
#  array([[0.00504255]]),
#  array([[0.02992903]]),
#  array([[0.02931345]]),
#  array([[0.04923406]]),
#  array([[0.00275253]]),
#  array([[0.05445406]]),
#  array([[0.0316568]]),
#  array([[0.04137212]]),
#  array([[0.03466737]]),
#  array([[0.01844659]]),
#  array([[0.03013389]]),
#  array([[0.03271864]]),
#  array([[0.05954488]]),
#  array([[0.0259188]]),
#  array([[0.01869699]]),
#  array([[0.02179734]]),
#  array([[0.02638331]]),
#  array([[0.01292523]]),
#  array([[0.03036434]]),
#  array([[0.02207975]]),
#  array([[0.01268989]]),
#  array([[0.05208588]]),
#  array([[0.03485589]]),
#  array([[0.05596482]]),
#  array([[0.0300027]]),
#  array([[0.02492587]]),
#  array([[0.03230843]]),
#  array([[0.04085951]]),
#  array([[0.02130677]]),
#  array([[0.04319988]]),
#  array([[0.04060623]]),
#  array([[0.03416041]]),
#  array([[0.05567569]]),
#  array([[0.01276636]]),
#  array([[0.00761923]]),
#  array([[0.0114972]]),
#  array([[0.02269413]]),
#  array([[0.02899867]]),
#  array([[0.00552239]]),
#  array([[0.03549767]]),
#  array([[0.02746312]]),
#  array([[0.02936042]]),
#  array([[0.05165677]]),
#  array([[0.01875625]]),
#  array([[0.01584779]]),
#  array([[0.0201358]]),
#  array([[0.04194457]]),
#  array([[0.03192763]]),
#  array([[0.01987745]]),
#  array([[0.02432947]]),
#  array([[0.04410136]]),
#  array([[0.01636503]]),
#  array([[0.0182218]]),
#  array([[0.05531117]]),
#  array([[0.00444263]]),
#  array([[0.02916011]]),
#  array([[0.02358012]]),
#  array([[0.03299806]]),
#  array([[0.03035849]]),
#  array([[0.0492909]]),
#  array([[0.01656563]]),
#  array([[0.0321482]]),
#  array([[0.02318188]]),
#  array([[0.02785657]]),
#  array([[0.01595464]]),
#  array([[0.01466038]]),
#  array([[0.02397031]]),
#  array([[0.02123376]]),
#  array([[0.06821199]]),
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(df['All']) #fitting and transforming the vector
count_jobid
# Out:
# <5502x49440 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1650467 stored elements in Compressed Sparse Row format>

# %%
# print(count_jobid)

# %%
user_count = count_vectorizer.transform(df2['All'])
user_count
# Out:
# <1x49440 sparse matrix of type '<class 'numpy.int64'>'
# 	with 153 stored elements in Compressed Sparse Row format>

# %%
print(user_count)
# Out:
#   (0, 2301)	2
#   (0, 2355)	2
#   (0, 2358)	2
#   (0, 12685)	2
#   (0, 12687)	2
#   (0, 13040)	2
#   (0, 13460)	5
#   (0, 13689)	2
#   (0, 13700)	3
#   (0, 13739)	2
#   (0, 13744)	2
#   (0, 13817)	2
#   (0, 14080)	2
#   (0, 14683)	4
#   (0, 14858)	2
#   (0, 15490)	2
#   (0, 15931)	4
#   (0, 16229)	2
#   (0, 19801)	2
#   (0, 21803)	2
#   (0, 21855)	3
#   (0, 22099)	8
#   (0, 22315)	2
#   (0, 22414)	2
#   (0, 22704)	2
#   :	:
#   (0, 44882)	4
#   (0, 45151)	2
#   (0, 45704)	2
#   (0, 45744)	4
#   (0, 45929)	2
#   (0, 46025)	4
#   (0, 46026)	2
#   (0, 46403)	2
#   (0, 46436)	1
#   (0, 46466)	2
#   (0, 46497)	2
#   (0, 46625)	4
#   (0, 46670)	2
#   (0, 46753)	2
#   (0, 46911)	2
#   (0, 47349)	4
#   (0, 47463)	2
#   (0, 47484)	3
#   (0, 47514)	2
#   (0, 47516)	2
#   (0, 47609)	2
#   (0, 48557)	2
#   (0, 48709)	4
#   (0, 48793)	2
#   (0, 48885)	2

# %%
cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
output3 = list(cos_similarity_countv)
#output3

# %%
output3
# Out:
# [array([[0.08271119]]),
#  array([[0.10474688]]),
#  array([[0.09482028]]),
#  array([[0.10372172]]),
#  array([[0.09783041]]),
#  array([[0.18869465]]),
#  array([[0.071908]]),
#  array([[0.07243559]]),
#  array([[0.12712436]]),
#  array([[0.09186617]]),
#  array([[0.05881143]]),
#  array([[0.09186005]]),
#  array([[0.07384546]]),
#  array([[0.10853658]]),
#  array([[0.0739589]]),
#  array([[0.08130643]]),
#  array([[0.1874395]]),
#  array([[0.09807573]]),
#  array([[0.20438331]]),
#  array([[0.06336599]]),
#  array([[0.09557771]]),
#  array([[0.08841008]]),
#  array([[0.0962981]]),
#  array([[0.07025144]]),
#  array([[0.07744288]]),
#  array([[0.09484655]]),
#  array([[0.05825042]]),
#  array([[0.0735303]]),
#  array([[0.08867963]]),
#  array([[0.11213047]]),
#  array([[0.08981903]]),
#  array([[0.05987752]]),
#  array([[0.08147986]]),
#  array([[0.10329604]]),
#  array([[0.06910303]]),
#  array([[0.15773034]]),
#  array([[0.09526771]]),
#  array([[0.0718194]]),
#  array([[0.05071934]]),
#  array([[0.06632803]]),
#  array([[0.11721705]]),
#  array([[0.07980482]]),
#  array([[0.09375262]]),
#  array([[0.10056865]]),
#  array([[0.04957083]]),
#  array([[0.07781828]]),
#  array([[0.09054188]]),
#  array([[0.09679334]]),
#  array([[0.1569488]]),
#  array([[0.05446411]]),
#  array([[0.10920945]]),
#  array([[0.12331046]]),
#  array([[0.06009999]]),
#  array([[0.11773273]]),
#  array([[0.05952468]]),
#  array([[0.06339925]]),
#  array([[0.06733201]]),
#  array([[0.10731661]]),
#  array([[0.07940354]]),
#  array([[0.07289746]]),
#  array([[0.0753091]]),
#  array([[0.08667593]]),
#  array([[0.0959953]]),
#  array([[0.05503062]]),
#  array([[0.11413603]]),
#  array([[0.12260718]]),
#  array([[0.13665317]]),
#  array([[0.06581172]]),
#  array([[0.06921085]]),
#  array([[0.06244512]]),
#  array([[0.0631532]]),
#  array([[0.07219028]]),
#  array([[0.06769627]]),
#  array([[0.07615937]]),
#  array([[0.08290649]]),
#  array([[0.06160893]]),
#  array([[0.11478655]]),
#  array([[0.12457544]]),
#  array([[0.11254158]]),
#  array([[0.07757923]]),
#  array([[0.06355722]]),
#  array([[0.07869437]]),
#  array([[0.05158397]]),
#  array([[0.08165172]]),
#  array([[0.08009394]]),
#  array([[0.06982783]]),
#  array([[0.07768185]]),
#  array([[0.08540905]]),
#  array([[0.06045462]]),
#  array([[0.07719039]]),
#  array([[0.11145381]]),
#  array([[0.08495219]]),
#  array([[0.10088438]]),
#  array([[0.09098712]]),
#  array([[0.06763192]]),
#  array([[0.06533989]]),
#  array([[0.05911437]]),
#  array([[0.1170781]]),
#  array([[0.09833047]]),
#  array([[0.06869111]]),
#  array([[0.07236692]]),
#  array([[0.09237011]]),
#  array([[0.06450603]]),
#  array([[0.10039936]]),
#  array([[0.06483823]]),
#  array([[0.06075876]]),
#  array([[0.08060068]]),
#  array([[0.05381398]]),
#  array([[0.06963023]]),
#  array([[0.08914281]]),
#  array([[0.04546474]]),
#  array([[0.06962244]]),
#  array([[0.08197946]]),
#  array([[0.06911724]]),
#  array([[0.1176919]]),
#  array([[0.05305113]]),
#  array([[0.14808241]]),
#  array([[0.14585989]]),
#  array([[0.13730908]]),
#  array([[0.05037113]]),
#  array([[0.10527329]]),
#  array([[0.10858811]]),
#  array([[0.05082959]]),
#  array([[0.06571828]]),
#  array([[0.10133031]]),
#  array([[0.08927556]]),
#  array([[0.06378067]]),
#  array([[0.13170009]]),
#  array([[0.06151341]]),
#  array([[0.09033806]]),
#  array([[0.08567712]]),
#  array([[0.11517629]]),
#  array([[0.06528206]]),
#  array([[0.06935496]]),
#  array([[0.08401756]]),
#  array([[0.08120817]]),
#  array([[0.05978267]]),
#  array([[0.10602315]]),
#  array([[0.0634454]]),
#  array([[0.10327318]]),
#  array([[0.0893435]]),
#  array([[0.08366795]]),
#  array([[0.07759351]]),
#  array([[0.08290902]]),
#  array([[0.10006394]]),
#  array([[0.05965447]]),
#  array([[0.0869127]]),
#  array([[0.07670381]]),
#  array([[0.10742244]]),
#  array([[0.08205201]]),
#  array([[0.06675119]]),
#  array([[0.06379702]]),
#  array([[0.05041969]]),
#  array([[0.06999894]]),
#  array([[0.08535334]]),
#  array([[0.0721599]]),
#  array([[0.07971246]]),
#  array([[0.07193184]]),
#  array([[0.08678739]]),
#  array([[0.17674742]]),
#  array([[0.08469313]]),
#  array([[0.09277882]]),
#  array([[0.05831207]]),
#  array([[0.0791449]]),
#  array([[0.07640317]]),
#  array([[0.15628449]]),
#  array([[0.07177941]]),
#  array([[0.10244078]]),
#  array([[0.18543892]]),
#  array([[0.0719009]]),
#  array([[0.06896014]]),
#  array([[0.06606536]]),
#  array([[0.05644169]]),
#  array([[0.08049507]]),
#  array([[0.08799106]]),
#  array([[0.05479708]]),
#  array([[0.0590745]]),
#  array([[0.09316304]]),
#  array([[0.08160762]]),
#  array([[0.10098447]]),
#  array([[0.0650239]]),
#  array([[0.13579993]]),
#  array([[0.09946607]]),
#  array([[0.10565212]]),
#  array([[0.06558072]]),
#  array([[0.06146872]]),
#  array([[0.0815144]]),
#  array([[0.05277142]]),
#  array([[0.06884166]]),
#  array([[0.07656333]]),
#  array([[0.07403385]]),
#  array([[0.06750455]]),
#  array([[0.09361018]]),
#  array([[0.06801144]]),
#  array([[0.06899875]]),
#  array([[0.07227805]]),
#  array([[0.06476895]]),
#  array([[0.07215218]]),
#  array([[0.1287283]]),
#  array([[0.05866311]]),
#  array([[0.069357]]),
#  array([[0.06935923]]),
#  array([[0.0839552]]),
#  array([[0.08629199]]),
#  array([[0.09523789]]),
#  array([[0.06855962]]),
#  array([[0.09002212]]),
#  array([[0.08671234]]),
#  array([[0.07688905]]),
#  array([[0.09182042]]),
#  array([[0.06806066]]),
#  array([[0.0470742]]),
#  array([[0.07736645]]),
#  array([[0.07174775]]),
#  array([[0.09906742]]),
#  array([[0.06692073]]),
#  array([[0.05272316]]),
#  array([[0.09873978]]),
#  array([[0.11824482]]),
#  array([[0.09114718]]),
#  array([[0.05986695]]),
#  array([[0.04549368]]),
#  array([[0.09815674]]),
#  array([[0.07879958]]),
#  array([[0.08108679]]),
#  array([[0.06605932]]),
#  array([[0.18628688]]),
#  array([[0.06079631]]),
#  array([[0.19386868]]),
#  array([[0.07312232]]),
#  array([[0.05903186]]),
#  array([[0.08264378]]),
#  array([[0.0784165]]),
#  array([[0.07722558]]),
#  array([[0.0903708]]),
#  array([[0.09784495]]),
#  array([[0.08625134]]),
#  array([[0.085868]]),
#  array([[0.10149095]]),
#  array([[0.05558524]]),
#  array([[0.08754996]]),
#  array([[0.1485304]]),
#  array([[0.05567443]]),
#  array([[0.0746213]]),
#  array([[0.07123697]]),
#  array([[0.08091661]]),
#  array([[0.08372848]]),
#  array([[0.06122423]]),
#  array([[0.06707863]]),
#  array([[0.08244281]]),
#  array([[0.13476601]]),
#  array([[0.1462577]]),
#  array([[0.10578498]]),
#  array([[0.04959522]]),
#  array([[0.10806878]]),
#  array([[0.09967329]]),
#  array([[0.08220768]]),
#  array([[0.06493667]]),
#  array([[0.08091591]]),
#  array([[0.0886548]]),
#  array([[0.07896443]]),
#  array([[0.10964885]]),
#  array([[0.18576717]]),
#  array([[0.06643228]]),
#  array([[0.06750034]]),
#  array([[0.1001648]]),
#  array([[0.14909903]]),
#  array([[0.06547784]]),
#  array([[0.05447112]]),
#  array([[0.12261864]]),
#  array([[0.08093677]]),
#  array([[0.07143037]]),
#  array([[0.11412777]]),
#  array([[0.05199463]]),
#  array([[0.08024379]]),
#  array([[0.11544207]]),
#  array([[0.1147401]]),
#  array([[0.11955598]]),
#  array([[0.10004631]]),
#  array([[0.06361104]]),
#  array([[0.22464587]]),
#  array([[0.06622592]]),
#  array([[0.07914817]]),
#  array([[0.06366647]]),
#  array([[0.08738587]]),
#  array([[0.05503334]]),
#  array([[0.08232663]]),
#  array([[0.09426689]]),
#  array([[0.15984183]]),
#  array([[0.14896408]]),
#  array([[0.10336573]]),
#  array([[0.15923197]]),
#  array([[0.08487327]]),
#  array([[0.09614664]]),
#  array([[0.05827375]]),
#  array([[0.06504067]]),
#  array([[0.05761092]]),
#  array([[0.12089346]]),
#  array([[0.11963332]]),
#  array([[0.06204828]]),
#  array([[0.11012143]]),
#  array([[0.07513323]]),
#  array([[0.09552253]]),
#  array([[0.08307193]]),
#  array([[0.06346957]]),
#  array([[0.16005694]]),
#  array([[0.11792518]]),
#  array([[0.04468125]]),
#  array([[0.08362969]]),
#  array([[0.10399456]]),
#  array([[0.16980867]]),
#  array([[0.162242]]),
#  array([[0.12838565]]),
#  array([[0.08720326]]),
#  array([[0.0682641]]),
#  array([[0.06584985]]),
#  array([[0.12770815]]),
#  array([[0.0899881]]),
#  array([[0.0796078]]),
#  array([[0.15971762]]),
#  array([[0.20140444]]),
#  array([[0.07130766]]),
#  array([[0.05886055]]),
#  array([[0.06634295]]),
#  array([[0.07573845]]),
#  array([[0.06795231]]),
#  array([[0.09632703]]),
#  array([[0.05332298]]),
#  array([[0.0753354]]),
#  array([[0.16266741]]),
#  array([[0.07405844]]),
#  array([[0.08477874]]),
#  array([[0.15310401]]),
#  array([[0.0719684]]),
#  array([[0.09588142]]),
#  array([[0.08763196]]),
#  array([[0.08182106]]),
#  array([[0.10593461]]),
#  array([[0.05362786]]),
#  array([[0.10730482]]),
#  array([[0.0854016]]),
#  array([[0.16012556]]),
#  array([[0.06579145]]),
#  array([[0.13001652]]),
#  array([[0.07234475]]),
#  array([[0.08269511]]),
#  array([[0.09137519]]),
#  array([[0.09430324]]),
#  array([[0.11096297]]),
#  array([[0.05361111]]),
#  array([[0.09445982]]),
#  array([[0.12848792]]),
#  array([[0.09826893]]),
#  array([[0.07467132]]),
#  array([[0.13209867]]),
#  array([[0.0820457]]),
#  array([[0.12694127]]),
#  array([[0.08371041]]),
#  array([[0.0690164]]),
#  array([[0.08447724]]),
#  array([[0.09869796]]),
#  array([[0.07104127]]),
#  array([[0.06929951]]),
#  array([[0.17615168]]),
#  array([[0.09176457]]),
#  array([[0.06648891]]),
#  array([[0.08346185]]),
#  array([[0.0959006]]),
#  array([[0.06453395]]),
#  array([[0.05084317]]),
#  array([[0.05481809]]),
#  array([[0.08663386]]),
#  array([[0.08005415]]),
#  array([[0.05991745]]),
#  array([[0.08879011]]),
#  array([[0.06986028]]),
#  array([[0.064193]]),
#  array([[0.06863887]]),
#  array([[0.08515219]]),
#  array([[0.07648652]]),
#  array([[0.09814051]]),
#  array([[0.06254562]]),
#  array([[0.11283622]]),
#  array([[0.06121736]]),
#  array([[0.08686597]]),
#  array([[0.16962183]]),
#  array([[0.0900987]]),
#  array([[0.06627792]]),
#  array([[0.06750813]]),
#  array([[0.08728106]]),
#  array([[0.06291074]]),
#  array([[0.05994648]]),
#  array([[0.06391177]]),
#  array([[0.06484696]]),
#  array([[0.07840112]]),
#  array([[0.07199154]]),
#  array([[0.06621207]]),
#  array([[0.08022682]]),
#  array([[0.14394145]]),
#  array([[0.07100447]]),
#  array([[0.14548923]]),
#  array([[0.08965909]]),
#  array([[0.20522505]]),
#  array([[0.10615358]]),
#  array([[0.06037647]]),
#  array([[0.11975654]]),
#  array([[0.08450102]]),
#  array([[0.06597518]]),
#  array([[0.0637479]]),
#  array([[0.0761109]]),
#  array([[0.06051378]]),
#  array([[0.08032293]]),
#  array([[0.06118366]]),
#  array([[0.11778976]]),
#  array([[0.07084243]]),
#  array([[0.05916967]]),
#  array([[0.06196984]]),
#  array([[0.07406686]]),
#  array([[0.07302282]]),
#  array([[0.08317025]]),
#  array([[0.05887386]]),
#  array([[0.21633983]]),
#  array([[0.07128678]]),
#  array([[0.06346474]]),
#  array([[0.16203128]]),
#  array([[0.10666986]]),
#  array([[0.18533856]]),
#  array([[0.08455715]]),
#  array([[0.07160439]]),
#  array([[0.07861971]]),
#  array([[0.12138248]]),
#  array([[0.06881444]]),
#  array([[0.10386926]]),
#  array([[0.08878591]]),
#  array([[0.14095293]]),
#  array([[0.11016851]]),
#  array([[0.09227608]]),
#  array([[0.18515019]]),
#  array([[0.08106108]]),
#  array([[0.10517146]]),
#  array([[0.08597686]]),
#  array([[0.06161791]]),
#  array([[0.1039808]]),
#  array([[0.09534919]]),
#  array([[0.08788471]]),
#  array([[0.15562532]]),
#  array([[0.08239299]]),
#  array([[0.13949975]]),
#  array([[0.06505776]]),
#  array([[0.08487327]]),
#  array([[0.06945769]]),
#  array([[0.13033698]]),
#  array([[0.07309838]]),
#  array([[0.1103098]]),
#  array([[0.0896117]]),
#  array([[0.07603853]]),
#  array([[0.07023801]]),
#  array([[0.09621891]]),
#  array([[0.1122725]]),
#  array([[0.13556235]]),
#  array([[0.10797098]]),
#  array([[0.14906757]]),
#  array([[0.0660748]]),
#  array([[0.16098935]]),
#  array([[0.09531645]]),
#  array([[0.1007972]]),
#  array([[0.14969251]]),
#  array([[0.14131437]]),
#  array([[0.12446139]]),
#  array([[0.1867786]]),
#  array([[0.06174876]]),
#  array([[0.13438515]]),
#  array([[0.13251705]]),
#  array([[0.12933103]]),
#  array([[0.07928334]]),
#  array([[0.05618519]]),
#  array([[0.07056438]]),
#  array([[0.05759948]]),
#  array([[0.06460153]]),
#  array([[0.14905462]]),
#  array([[0.08361589]]),
#  array([[0.05553146]]),
#  array([[0.11792612]]),
#  array([[0.06933239]]),
#  array([[0.06957819]]),
#  array([[0.07539662]]),
#  array([[0.06168535]]),
#  array([[0.09609107]]),
#  array([[0.06677868]]),
#  array([[0.07042419]]),
#  array([[0.08794727]]),
#  array([[0.0651943]]),
#  array([[0.14343206]]),
#  array([[0.10189091]]),
#  array([[0.07968688]]),
#  array([[0.14566098]]),
#  array([[0.05505312]]),
#  array([[0.05624717]]),
#  array([[0.09502049]]),
#  array([[0.07296825]]),
#  array([[0.11171132]]),
#  array([[0.07972104]]),
#  array([[0.08624832]]),
#  array([[0.06063303]]),
#  array([[0.05935108]]),
#  array([[0.0583681]]),
#  array([[0.0793095]]),
#  array([[0.07243559]]),
#  array([[0.06064893]]),
#  array([[0.05293593]]),
#  array([[0.06678763]]),
#  array([[0.06486812]]),
#  array([[0.06883222]]),
#  array([[0.0662202]]),
#  array([[0.0501029]]),
#  array([[0.09457885]]),
#  array([[0.0667935]]),
#  array([[0.08178645]]),
#  array([[0.07025144]]),
#  array([[0.06261853]]),
#  array([[0.06632801]]),
#  array([[0.06508835]]),
#  array([[0.06662981]]),
#  array([[0.09811325]]),
#  array([[0.06535455]]),
#  array([[0.08596328]]),
#  array([[0.07852828]]),
#  array([[0.05039951]]),
#  array([[0.065852]]),
#  array([[0.074842]]),
#  array([[0.07494979]]),
#  array([[0.06347487]]),
#  array([[0.06051085]]),
#  array([[0.06453416]]),
#  array([[0.04246674]]),
#  array([[0.08311273]]),
#  array([[0.10251744]]),
#  array([[0.03496614]]),
#  array([[0.04772677]]),
#  array([[0.04677463]]),
#  array([[0.09294943]]),
#  array([[0.07271827]]),
#  array([[0.03318692]]),
#  array([[0.09297866]]),
#  array([[0.071908]]),
#  array([[0.09001934]]),
#  array([[0.07744288]]),
#  array([[0.09250121]]),
#  array([[0.07381122]]),
#  array([[0.08254899]]),
#  array([[0.06305113]]),
#  array([[0.04742258]]),
#  array([[0.08667593]]),
#  array([[0.07734594]]),
#  array([[0.06165844]]),
#  array([[0.08758715]]),
#  array([[0.07143589]]),
#  array([[0.05839523]]),
#  array([[0.06517714]]),
#  array([[0.06965919]]),
#  array([[0.05332928]]),
#  array([[0.06085103]]),
#  array([[0.05924387]]),
#  array([[0.07394008]]),
#  array([[0.07980482]]),
#  array([[0.05669213]]),
#  array([[0.0551575]]),
#  array([[0.08943499]]),
#  array([[0.06884636]]),
#  array([[0.08890582]]),
#  array([[0.08254192]]),
#  array([[0.06442057]]),
#  array([[0.09317214]]),
#  array([[0.03888097]]),
#  array([[0.06016013]]),
#  array([[0.08942116]]),
#  array([[0.09288374]]),
#  array([[0.09007572]]),
#  array([[0.04925351]]),
#  array([[0.10307689]]),
#  array([[0.08051846]]),
#  array([[0.05789324]]),
#  array([[0.08806609]]),
#  array([[0.05845869]]),
#  array([[0.11297677]]),
#  array([[0.10954542]]),
#  array([[0.04990379]]),
#  array([[0.1027993]]),
#  array([[0.07278572]]),
#  array([[0.05812752]]),
#  array([[0.06585449]]),
#  array([[0.05677164]]),
#  array([[0.05325846]]),
#  array([[0.0851784]]),
#  array([[0.20122787]]),
#  array([[0.07183884]]),
#  array([[0.08374391]]),
#  array([[0.08109367]]),
#  array([[0.04942153]]),
#  array([[0.06938916]]),
#  array([[0.08398402]]),
#  array([[0.09375262]]),
#  array([[0.04581256]]),
#  array([[0.10205324]]),
#  array([[0.07426834]]),
#  array([[0.09364008]]),
#  array([[0.08653904]]),
#  array([[0.10095118]]),
#  array([[0.09526771]]),
#  array([[0.07859467]]),
#  array([[0.08822286]]),
#  array([[0.08981903]]),
#  array([[0.07909861]]),
#  array([[0.07415475]]),
#  array([[0.06462603]]),
#  array([[0.07109148]]),
#  array([[0.0753091]]),
#  array([[0.15773034]]),
#  array([[0.04179317]]),
#  array([[0.07048581]]),
#  array([[0.07410408]]),
#  array([[0.05376856]]),
#  array([[0.06424587]]),
#  array([[0.0699066]]),
#  array([[0.06456085]]),
#  array([[0.10920945]]),
#  array([[0.05832929]]),
#  array([[0.07147962]]),
#  array([[0.08197946]]),
#  array([[0.07203983]]),
#  array([[0.0571443]]),
#  array([[0.086671]]),
#  array([[0.04269739]]),
#  array([[0.10508626]]),
#  array([[0.04940453]]),
#  array([[0.09750255]]),
#  array([[0.0382037]]),
#  array([[0.12982572]]),
#  array([[0.07595969]]),
#  array([[0.08175905]]),
#  array([[0.04975642]]),
#  array([[0.0669432]]),
#  array([[0.07609403]]),
#  array([[0.07362223]]),
#  array([[0.0731813]]),
#  array([[0.05944015]]),
#  array([[0.07346113]]),
#  array([[0.08198052]]),
#  array([[0.06492292]]),
#  array([[0.06891412]]),
#  array([[0.10574189]]),
#  array([[0.08720784]]),
#  array([[0.08535334]]),
#  array([[0.05888925]]),
#  array([[0.05422658]]),
#  array([[0.04924032]]),
#  array([[0.0524732]]),
#  array([[0.06989396]]),
#  array([[0.05370261]]),
#  array([[0.05365075]]),
#  array([[0.06521601]]),
#  array([[0.05505586]]),
#  array([[0.09155275]]),
#  array([[0.0687895]]),
#  array([[0.14668931]]),
#  array([[0.06790661]]),
#  array([[0.08567712]]),
#  array([[0.0644622]]),
#  array([[0.05465561]]),
#  array([[0.05767802]]),
#  array([[0.09503156]]),
#  array([[0.13449412]]),
#  array([[0.07969739]]),
#  array([[0.06963023]]),
#  array([[0.0959953]]),
#  array([[0.06252297]]),
#  array([[0.06540981]]),
#  array([[0.06411298]]),
#  array([[0.09362023]]),
#  array([[0.05035197]]),
#  array([[0.08097232]]),
#  array([[0.05968952]]),
#  array([[0.06406602]]),
#  array([[0.0539069]]),
#  array([[0.05945515]]),
#  array([[0.06339925]]),
#  array([[0.05224647]]),
#  array([[0.06542549]]),
#  array([[0.08445589]]),
#  array([[0.08295135]]),
#  array([[0.06023972]]),
#  array([[0.13579993]]),
#  array([[0.0718736]]),
#  array([[0.0739313]]),
#  array([[0.05968553]]),
#  array([[0.10602315]]),
#  array([[0.05712267]]),
#  array([[0.0777327]]),
#  array([[0.06655272]]),
#  array([[0.0677475]]),
#  array([[0.05995619]]),
#  array([[0.06723011]]),
#  array([[0.10088438]]),
#  array([[0.06320939]]),
#  array([[0.05607423]]),
#  array([[0.04808299]]),
#  array([[0.0336054]]),
#  array([[0.06349813]]),
#  array([[0.07781828]]),
#  array([[0.07871688]]),
#  array([[0.06107205]]),
#  array([[0.06196765]]),
#  array([[0.05164074]]),
#  array([[0.05976594]]),
#  array([[0.08366795]]),
#  array([[0.06312073]]),
#  array([[0.05941645]]),
#  array([[0.08731838]]),
#  array([[0.08135138]]),
#  array([[0.05670809]]),
#  array([[0.06093576]]),
#  array([[0.08387458]]),
#  array([[0.11930829]]),
#  array([[0.07575859]]),
#  array([[0.06733201]]),
#  array([[0.07267297]]),
#  array([[0.13084256]]),
#  array([[0.07196244]]),
#  array([[0.07593765]]),
#  array([[0.05786615]]),
#  array([[0.08078802]]),
#  array([[0.12042985]]),
#  array([[0.08551844]]),
#  array([[0.07219028]]),
#  array([[0.04969165]]),
#  array([[0.10006394]]),
#  array([[0.08886719]]),
#  array([[0.07426986]]),
#  array([[0.07900341]]),
#  array([[0.06080024]]),
#  array([[0.08205201]]),
#  array([[0.08383592]]),
#  array([[0.07485304]]),
#  array([[0.09225046]]),
#  array([[0.06251278]]),
#  array([[0.08734781]]),
#  array([[0.07177494]]),
#  array([[0.06434118]]),
#  array([[0.08016609]]),
#  array([[0.07201128]]),
#  array([[0.08489752]]),
#  array([[0.09217051]]),
#  array([[0.07485894]]),
#  array([[0.06009999]]),
#  array([[0.10756737]]),
#  array([[0.04343637]]),
#  array([[0.07118149]]),
#  array([[0.05904222]]),
#  array([[0.07590352]]),
#  array([[0.08114523]]),
#  array([[0.07625386]]),
#  array([[0.07615937]]),
#  array([[0.0711942]]),
#  array([[0.08426899]]),
#  array([[0.05545456]]),
#  array([[0.06997387]]),
#  array([[0.0323356]]),
#  array([[0.07095832]]),
#  array([[0.06962244]]),
#  array([[0.06450603]]),
#  array([[0.06950944]]),
#  array([[0.07106464]]),
#  array([[0.09398673]]),
#  array([[0.08413489]]),
#  array([[0.07362401]]),
#  array([[0.13707836]]),
#  array([[0.07437408]]),
#  array([[0.06412758]]),
#  array([[0.05240708]]),
#  array([[0.05731388]]),
#  array([[0.0487363]]),
#  array([[0.06817931]]),
#  array([[0.05198181]]),
#  array([[0.05814387]]),
#  array([[0.07121439]]),
#  array([[0.07655053]]),
#  array([[0.03653589]]),
#  array([[0.06298038]]),
#  array([[0.04176093]]),
#  array([[0.07100302]]),
#  array([[0.06672999]]),
#  array([[0.05074778]]),
#  array([[0.10159295]]),
#  array([[0.11413603]]),
#  array([[0.23409849]]),
#  array([[0.07346828]]),
#  array([[0.06110107]]),
#  array([[0.06109921]]),
#  array([[0.06093824]]),
#  array([[0.05979881]]),
#  array([[0.06630655]]),
#  array([[0.06457247]]),
#  array([[0.08049507]]),
#  array([[0.05394978]]),
#  array([[0.07281639]]),
#  array([[0.06171342]]),
#  array([[0.06217476]]),
#  array([[0.0879739]]),
#  array([[0.06615972]]),
#  array([[0.05184509]]),
#  array([[0.06083059]]),
#  array([[0.07775103]]),
#  array([[0.06639604]]),
#  array([[0.0594199]]),
#  array([[0.05041969]]),
#  array([[0.05848183]]),
#  array([[0.0751197]]),
#  array([[0.06513257]]),
#  array([[0.0807529]]),
#  array([[0.06099417]]),
#  array([[0.08281427]]),
#  array([[0.07616747]]),
#  array([[0.11422683]]),
#  array([[0.06048494]]),
#  array([[0.04823803]]),
#  array([[0.07518525]]),
#  array([[0.07218188]]),
#  array([[0.06769627]]),
#  array([[0.06203607]]),
#  array([[0.10190939]]),
#  array([[0.08573215]]),
#  array([[0.10047543]]),
#  array([[0.08044957]]),
#  array([[0.05050042]]),
#  array([[0.07976536]]),
#  array([[0.0712042]]),
#  array([[0.07186578]]),
#  array([[0.06884166]]),
#  array([[0.05570504]]),
#  array([[0.08054671]]),
#  array([[0.07004302]]),
#  array([[0.05584923]]),
#  array([[0.07836961]]),
#  array([[0.07101301]]),
#  array([[0.05082959]]),
#  array([[0.06571952]]),
#  array([[0.03298731]]),
#  array([[0.07867964]]),
#  array([[0.09054821]]),
#  array([[0.06934745]]),
#  array([[0.13336729]]),
#  array([[0.09593249]]),
#  array([[0.10689772]]),
#  array([[0.09361018]]),
#  array([[0.04578646]]),
#  array([[0.07158827]]),
#  array([[0.05588347]]),
#  array([[0.071079]]),
#  array([[0.08351222]]),
#  array([[0.06882328]]),
#  array([[0.06944913]]),
#  array([[0.10039954]]),
#  array([[0.1207623]]),
#  array([[0.06310323]]),
#  array([[0.06240117]]),
#  array([[0.07467118]]),
#  array([[0.0973567]]),
#  array([[0.11109547]]),
#  array([[0.06009512]]),
#  array([[0.06334798]]),
#  array([[0.10549948]]),
#  array([[0.07891994]]),
#  array([[0.08540905]]),
#  array([[0.04590039]]),
#  array([[0.0791449]]),
#  array([[0.08927556]]),
#  array([[0.0684456]]),
#  array([[0.04808192]]),
#  array([[0.07933066]]),
#  array([[0.09660344]]),
#  array([[0.08232147]]),
#  array([[0.07449139]]),
#  array([[0.05470251]]),
#  array([[0.08113861]]),
#  array([[0.04140937]]),
#  array([[0.10527329]]),
#  array([[0.11782976]]),
#  array([[0.07267998]]),
#  array([[0.1569488]]),
#  array([[0.06042325]]),
#  array([[0.06503623]]),
#  array([[0.0672578]]),
#  array([[0.0592967]]),
#  array([[0.05999006]]),
#  array([[0.07971246]]),
#  array([[0.08299993]]),
#  array([[0.08656452]]),
#  array([[0.06256182]]),
#  array([[0.07649822]]),
#  array([[0.10702469]]),
#  array([[0.07954283]]),
#  array([[0.06715344]]),
#  array([[0.07923933]]),
#  array([[0.06386253]]),
#  array([[0.07317858]]),
#  array([[0.0564761]]),
#  array([[0.11613511]]),
#  array([[0.06912801]]),
#  array([[0.09495446]]),
#  array([[0.07719039]]),
#  array([[0.06801725]]),
#  array([[0.08086111]]),
#  array([[0.06844846]]),
#  array([[0.0691441]]),
#  array([[0.0650922]]),
#  array([[0.09833606]]),
#  array([[0.07640317]]),
#  array([[0.0714402]]),
#  array([[0.07650099]]),
#  array([[0.05398782]]),
#  array([[0.12069628]]),
#  array([[0.07013506]]),
#  array([[0.09504375]]),
#  array([[0.10103739]]),
#  array([[0.05801504]]),
#  array([[0.06425767]]),
#  array([[0.07688905]]),
#  array([[0.05292032]]),
#  array([[0.07208455]]),
#  array([[0.07482576]]),
#  array([[0.06750742]]),
#  array([[0.05351478]]),
#  array([[0.11291915]]),
#  array([[0.07540688]]),
#  array([[0.11016257]]),
#  array([[0.04224209]]),
#  array([[0.11457098]]),
#  array([[0.06801144]]),
#  array([[0.07098094]]),
#  array([[0.07252098]]),
#  array([[0.07302144]]),
#  array([[0.09307212]]),
#  array([[0.06762098]]),
#  array([[0.12705136]]),
#  array([[0.10189859]]),
#  array([[0.07334279]]),
#  array([[0.0741706]]),
#  array([[0.0719596]]),
#  array([[0.08091796]]),
#  array([[0.08100591]]),
#  array([[0.07655322]]),
#  array([[0.06502553]]),
#  array([[0.09054818]]),
#  array([[0.09296583]]),
#  array([[0.09182042]]),
#  array([[0.06736911]]),
#  array([[0.05676718]]),
#  array([[0.07116689]]),
#  array([[0.08818269]]),
#  array([[0.06997182]]),
#  array([[0.09629457]]),
#  array([[0.10126613]]),
#  array([[0.08488498]]),
#  array([[0.093618]]),
#  array([[0.06476895]]),
#  array([[0.04957426]]),
#  array([[0.06657591]]),
#  array([[0.08058779]]),
#  array([[0.08661243]]),
#  array([[0.04402879]]),
#  array([[0.087926]]),
#  array([[0.07771116]]),
#  array([[0.07410728]]),
#  array([[0.12267212]]),
#  array([[0.07951049]]),
#  array([[0.06222417]]),
#  array([[0.06308577]]),
#  array([[0.09734225]]),
#  array([[0.07723744]]),
#  array([[0.06681081]]),
#  array([[0.05488334]]),
#  array([[0.08165608]]),
#  array([[0.07425464]]),
#  array([[0.08691579]]),
#  array([[0.11734312]]),
#  array([[0.04763453]]),
#  array([[0.09251632]]),
#  array([[0.06403748]]),
#  array([[0.08045526]]),
#  array([[0.0767449]]),
#  array([[0.1097863]]),
#  array([[0.06314612]]),
#  array([[0.06851214]]),
#  array([[0.07107187]]),
#  array([[0.08874133]]),
#  array([[0.06719433]]),
#  array([[0.06047011]]),
#  array([[0.06715618]]),
#  array([[0.08574879]]),
#  array([[0.13122413]]),
#  ...]

# %%
df.rating
# Out:
# 0       3.9
# 1       3.7
# 2       3.9
# 3       3.6
# 4       3.9
#        ...
# 5497    NaN
# 5498    NaN
# 5499    NaN
# 5500    NaN
# 5501    NaN
# Name: rating, Length: 5502, dtype: float64

# %%
top = sorted(range(len(output3)), key=lambda i: output3[i], reverse=True)[:100]
list_scores = [output3[i][0][0] for i in top]
cv=get_recommendation(top, df, list_scores)
cv
# Out:
#                                     positionName  \
# 0                      MACHINE LEARNING ENGINEER
# 1                      MACHINE LEARNING ENGINEER
# 2                  Data Scientist (India Remote)
# 3                  Data Scientist (India Remote)
# 4               Python Machine Learning Engineer
# ..                                           ...
# 95  Lead Machine Learning Firmware Test Engineer
# 96  Lead Machine Learning Firmware Test Engineer
# 97                     Machine Learning Engineer
# 98                     Machine Learning Engineer
# 99                                   ML Engineer
#
#                           company              location ratingdescription  \
# 0             Amanzi Technologies  Noida, Uttar Pradesh               NaN
# 1             Amanzi Technologies  Noida, Uttar Pradesh               NaN
# 2                   Token Metrics  Bengaluru, Karnataka               NaN
# 3                   Token Metrics  Bengaluru, Karnataka               NaN
# 4          Vingsfire HRIM Pvt Ltd   Madurai, Tamil Nadu               NaN
# ..                            ...                   ...               ...
# 95                         Axiado  Hyderabad, Telangana               NaN
# 96                         Axiado  Hyderabad, Telangana               NaN
# 97                          Apple  Bengaluru, Karnataka               NaN
# 98                          Apple  Bengaluru, Karnataka               NaN
# 99  krtrimaIQ Cognitive Solutions  Bengaluru, Karnataka               NaN
#
#        score  rating                                        description
# 0   0.358269     NaN  Amanzi Technologies Pvt. Ltd.                 ...
# 1   0.358269     NaN  Amanzi Technologies Pvt. Ltd.                 ...
# 2   0.356535     NaN  Token Metrics is searching for a highly capabl...
# 3   0.356535     NaN  Token Metrics is searching for a highly capabl...
# 4   0.354861     NaN  Role : Senior Python DeveloperExperience: 5+ Y...
# ..       ...     ...                                                ...
# 95  0.237843     NaN  Company Description  Axiado is an AI-enhanced ...
# 96  0.237843     NaN  Company Description  Axiado is an AI-enhanced ...
# 97  0.236957     4.1  Summary                Posted: Dec 7, 2022    ...
# 98  0.236957     4.1  Summary                Posted: Dec 7, 2022    ...
# 99  0.236566     NaN  Job Description:ML Engineer for NLP domain.Res...
#
# [100 rows x 7 columns]

# %%
cv.description[1]
# Out:
# 'Amanzi Technologies Pvt. Ltd.                              Permanent                              Noida                              Posted 3 weeks ago                          Out of the box solution          Responsibilities:      Designing and developing machine learning and deep learning systems.    Running machine learning tests and experiments.    Implementing appropriate ML algorithms.        Job brief:   We are looking for a Machine Learning (ML) Engineer to help us create artificial intelligence products.   Machine Learning Engineer responsibilities include creating machine learning models and retraining systems. To do this job successfully, you need exceptional skills in statistics and programming. If you also have knowledge of data science and software engineering, we’d like to meet you.   Your ultimate goal will be to shape and build efficient self-learning applications.   Responsibilities:      Study and transform data science prototypes.    Design machine learning systemsResearch and implement appropriate ML algorithms and tools.    Develop machine learning applications according to requirements.    Select appropriate datasets and data representation methodsRun machine learning tests and experiments.    Perform statistical analysis and fine-tuning using test resultsTrain and retrain systems when necessary.    Extend existing ML libraries and frameworks.    Keep abreast of developments in the field        Mandatory skills:      Bachelor’s degree in computer science, data science, mathematics, or a related field. (B.E / MCA / B. tech / P. hd).    4-7 years of experience as a machine learning engineer.    Extensive knowledge of ML frameworks, libraries, data structures, data modelling, and software architecture.    In-depth knowledge of mathematics, statistics, and algorithms.    Proficiency with a deep learning framework such as TensorFlow or Keras.    Proficiency with Python(Mandate) and basic libraries for machine learning such as scikit-learn and pandas.    Ability to select hardware to run an ML model with the required latency.    Proficiency in Artificial neural networks, RNN, LSTM.    Hands-on Autoencoders, GAN’s, Convolution neural networks and Deep learning models.    Experience with at least one cloud provider solution (AWS, GCP, Azure).        Job Features                     Job Category                 Information Technology'

# %%
from sklearn.neighbors import NearestNeighbors

def KNN(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    n_neighbors = 100
    KNN = NearestNeighbors(n_neighbors, p=2)
    KNN.fit(tfidf_vectorizer.fit_transform(scraped_data))
#     NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv), return_distance=True)
    NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv))
    top = NNs[1][0][1:]
    index_score = NNs[0][0][1:]

    knn = get_recommendation(top, df, index_score)
    return knn

knn = KNN(df['All'], df2['All'])
knn
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 17
#      14     knn = get_recommendation(top, df, index_score)
#      15     return knn
# ---> 17 knn = KNN(df['All'], df2['All'])
#      18 knn
#
# Cell In[101], line 7, in KNN(scraped_data, cv)
#       4     tfidf_vectorizer = TfidfVectorizer(stop_words='english')
#       6     n_neighbors = 100
# ----> 7     KNN = NearestNeighbors(n_neighbors, p=2)
#       8     KNN.fit(tfidf_vectorizer.fit_transform(scraped_data))
#       9 #     NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv), return_distance=True)
#
# TypeError: __init__() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
